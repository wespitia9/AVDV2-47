# %% [markdown]
# # Integración de datos de diversas fuentes y formatos.

# %% [markdown]
# En ciencia de datos, la integración de datos de diversas fuentes y formatos es el proceso de combinar datos de diferentes orígenes para crear un conjunto de datos cohesivo y unificado. Este proceso es crucial para obtener una vista completa y precisa de los datos, lo que a su vez permite un análisis más preciso y la toma de decisiones más informadas.
#
# Las diversas fuentes de datos pueden incluir:
#
# - Bases de datos: Las bases de datos relacionales, NoSQL y otras pueden almacenar información en diferentes formatos y estructuras.
# - Archivos: Los archivos CSV, Excel, JSON y otros pueden contener datos estructurados o semiestructurados.
# - Sensores: Los dispositivos IoT y otros sensores pueden generar datos en tiempo real.
# - Redes sociales: Las plataformas de redes sociales como Twitter, Facebook y LinkedIn pueden proporcionar información sobre las tendencias, los comportamientos y las opiniones del público.

# %% [markdown]
# Los formatos de datos también pueden variar considerablemente, lo que dificulta la integración de datos de diferentes fuentes. Algunos de los formatos de datos más comunes incluyen:
#
# - Datos estructurados: Los datos estructurados se organizan en filas y columnas, como en una hoja de cálculo.
# - Datos semiestructurados: Los datos semiestructurados tienen una estructura flexible, como los datos JSON.
# - Datos no estructurados: Los datos no estructurados no tienen una estructura definida, como el texto libre o las imágenes.
#
# La integración de datos de diversas fuentes y formatos implica varios pasos:
#
# 1. Extracción: El primer paso es extraer datos de las diferentes fuentes. Esto puede implicar la descarga de archivos, la consulta de bases de datos o la conexión a APIs.
#
# 2. Limpieza: Los datos extraídos a menudo contienen errores, valores inconsistentes y formatos incompatibles. El proceso de limpieza implica identificar y corregir estos problemas para garantizar la calidad de los datos.
#
# 3. Transformación: Los datos limpios deben transformarse a un formato común para que puedan ser integrados. Esto puede implicar convertir los datos a un formato estándar, como CSV o JSON, o realizar transformaciones más complejas como la normalización de datos.
#
# 4. Carga: Los datos transformados se cargan en un almacén de datos centralizado, donde pueden ser analizados y utilizados para la toma de decisiones.
#
# Existen diversas herramientas y plataformas que pueden facilitar la integración de datos, como:
#
# Herramientas ETL: Las herramientas ETL (Extracción, Transformación y Carga) automatizan el proceso de integración de datos.
# Plataformas de integración de datos: Estas plataformas proporcionan una interfaz gráfica para la gestión y el procesamiento de datos de diversas fuentes.
# La integración de datos de diversas fuentes y formatos es un proceso complejo y desafiante, pero es fundamental para el éxito de la ciencia de datos. Al integrar datos de manera efectiva, los científicos de datos pueden obtener una vista completa y precisa de los datos, lo que les permite tomar decisiones más informadas y crear soluciones más efectivas.
#
# Recursos adicionales:
#
# - https://cloud.google.com/learn/what-is-data-integration?hl=es-419
# - https://dataspurs.com/blog/data-integration-las-mejores-practicas-para-integrar-datos-de-diferentes-fuentes/
# - https://blogs.imf-formacion.com/blog/tecnologia/10-herramientas-integracion-datos-201907/

# %% [markdown]
# Algunos de los más comunes:
#
# 1. Encuestas y cuestionarios: Se utilizan para recopilar datos a través de preguntas estructuradas. Pueden ser administrados en papel, en línea o mediante entrevistas.
#
# 2. Entrevistas: Permiten obtener información más detallada y contextual mediante conversaciones cara a cara o telefónicas. Pueden ser estructuradas, semiestructuradas o no estructuradas.
#
# 3. Datos transaccionales: Recopilación de datos a partir de transacciones comerciales, registros de clientes, registros de ventas, entre otros.
#
# 4. Sensores y dispositivos IoT: En entornos digitales, los sensores y dispositivos de Internet de las cosas (IoT) pueden recopilar datos automáticamente sobre variables específicas.
#
# 5. Datos administrativos y registros: Utilización de registros existentes, como datos de salud, registros académicos o bases de datos de organizaciones.
#
# 6. Extracción de datos web: Recopilación de datos de páginas web mediante técnicas como web scraping.
#
# 7. Análisis de redes sociales: Recopilación de datos de plataformas de redes sociales para comprender las interacciones y relaciones entre individuos o entidades.
#
# Es importante considerar la `validez`, la `confiabilidad` y la `ética` en la recolección de datos para garantizar la calidad y la integridad de la información recopilada. Además, el análisis de datos y la toma de decisiones en ciencia de datos dependen en gran medida de la calidad de los datos recopilados.

# %% [markdown]
# Para trabajar con datos transaccionales en Python, es posible utilizar varias librerías que facilitan la manipulación y análisis de datos. A continuación, algunas de las más comunes:
#
# 1. [Pandas](https://pandas.pydata.org/): Manipulación y análisis de datos que proporciona estructuras de datos flexibles y eficientes, por ejemplo, DataFrame, que es especialmente útil para trabajar con datos tabulares.
#
# 2. [Numpy](https://numpy.org/): Realizar operaciones matemáticas y numéricas en Python. Se utiliza comúnmente para trabajar con matrices y arreglos
#
# 3. [Matplotlib](https://matplotlib.org/) y [Seaborn](https://seaborn.pydata.org/): Estas bibliotecas son excelentes para la visualización de datos. Matplotlib proporciona funciones para crear gráficos básicos, mientras que Seaborn simplifica la creación de gráficos estadísticos atractivos.

# %% [markdown]
# ## Preparación y configuración del entorno de trabajo

# %% [markdown]
# ### Librerias en Python

# %% [markdown]
# Las librerías de Python son elementos fundamentales dentro del ecosistema del lenguaje. Estas librerías permiten a los desarrolladores acceder a una amplia gama de funcionalidades especializadas. Desde la manipulación de cadenas de texto y operaciones matemáticas hasta el acceso a bases de datos, manipulación de archivos, creación de interfaces gráficas, procesamiento de datos científicos y desarrollo web, las librerías de Python ofrecen soluciones para una gran variedad de necesidades y aplicaciones. Su versatilidad y extensa documentación hacen que sean una herramienta indispensable para los programadores en todo tipo de proyectos y campos de aplicación.

# %%
# Instalar de librerias necesarias

#!pip install pyodbc pandas altair seaborn altair_viewer matplotlib

# %%
# Importar librerias

import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
import warnings
import sqlite3

# %% [markdown]
# ## Conexión a fuente de datos: CSV

# %% [markdown]
# Las fuentes de datos en formato CSV (valores separados por comas) son una forma común de almacenar datos tabulares en archivos de texto plano. CSV es un formato sencillo y ampliamente utilizado para intercambiar datos entre diferentes sistemas, ya que es fácil de leer y escribir tanto para humanos como para programas informáticos.
#
# En un archivo CSV, cada línea representa una fila de datos y los valores en cada fila están separados por un delimitador, que suelen ser:
#
# - Una coma (,),
# - Un punto y coma (;)
# - Un tabulador (\t)
# - otro carácter específico

# %% [markdown]
# En este ejemplo, cada fila tiene tres campos separados por comas: Nombre, Edad y Ciudad. El primer registro es Juan, de 25 años, de Barcelona; y el segundo es María, de 30 años, de Madrid.
#
# - Las fuentes de datos en formato CSV son muy versátiles y se utilizan en una amplia gama de aplicaciones, desde la gestión de bases de datos hasta el análisis de datos en ciencia de datos y aprendizaje automático.
#
# - Son particularmente útiles cuando se necesita intercambiar datos entre diferentes sistemas o trabajar con datos en aplicaciones que no admiten formatos más complejos.

# %% [markdown]
# ### Información del conjunto de datos: Saber 11° 2020-2

# %% [markdown]
# - Objetivo: Consumir y construir un DataFrame con resultados de las pruebas saber 11° correspondientes al segundo semestre del año 2019.
#
# - Esta fuente de datos es extraida de [Datos Abiertos Colombia](https://www.datos.gov.co/) , Los datos abiertos son información pública dispuesta en formatos que permiten su uso y reutilización bajo licencia abierta y sin restricciones legales para su aprovechamiento.
#
# - Este conjunto de datos, está compuesto por datos anonimizados sobre los resultados y características de los resultados de las pruebas saber 11 correspondientes al segundo semestre del año 2020

# %% [markdown]
# ### Ficha técnica:

# %% [markdown]
# Información General:
#
# - Fuente de datos: [Datos abiertos Colombia - Saber 11° 2020-2](https://www.datos.gov.co/Educaci-n/Saber-11-2020-2/rnvb-vnyh/about_data)
# - Fecha de creación: 15 de marzo de 2021
# - Filas: 504.872
# - Columnas: 81
# - Vistas: 13,6k (a la fecha de descarga)
# - Descargas: 5221 (a la fecha de descarga)
#
# Información de la entidad:
#
# - Área o dependencia: Oficina Asesora de Planeación
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# ### Conexión y consulta a la fuente de datos

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_resultados_2020_2 = pd.read_csv('C:/Users/espit/OneDrive/Documentos/Cymetria Bootcamps/AVDV2-47/Fuentes de datos/Saber_11_2020-2.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e:
    
    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:
    
    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# El dataset se cargó exitosamente.

# %% [markdown]
# Un "DataFrame" y un "dataset" son conceptos relacionados, pero tienen significados ligeramente diferentes en el contexto de la programación y el análisis de datos:
#
# `Dataset`:
#
# - Un dataset, o conjunto de datos en español, es simplemente una colección de datos organizados que se utiliza para algún propósito específico.
# - Puede ser cualquier conjunto de datos, ya sea en forma de tabla, texto, imágenes, audios, etc., que se recopila y organiza para su análisis o procesamiento.
# - Un dataset puede representar datos de cualquier dominio, como datos financieros, datos de ventas, datos de encuestas, datos científicos, entre otros.
# -
#
# `DataFrame`:
#
# - Un DataFrame es una estructura de datos bidimensional que se utiliza comúnmente en el análisis de datos, especialmente en el lenguaje de programación Python con la librería pandas.
# - Se organiza en filas y columnas, similar a una tabla en una base de datos o una hoja de cálculo.
# - ada columna en un DataFrame puede tener un tipo de datos diferente (como números, cadenas de texto, fechas, etc.), y cada fila representa un registro o una observación.
# - Los DataFrames son extremadamente útiles para manipular y analizar datos de forma eficiente debido a las numerosas funciones y métodos que proporcionan las librerías como pandas.
#
# En resumen, un `DataFrame` es una estructura específica utilizada para representar datos tabulares en Python, mientras que un `dataset` es una colección más general de datos que puede tener cualquier forma o tipo, y que se utiliza en diversas aplicaciones de análisis y procesamiento de datos.

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2020_2 = pd.DataFrame(df_resultados_2020_2)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2020_2.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 504872 filas y 81 columnas.

# %%
#  Imprimir el dataframe
df_resultados_2020_2
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI             SUIZA           F
# 1                     PEP         VENEZUELA           M
# 2                      TI         VENEZUELA           F
# 3                      CE         VENEZUELA           M
# 4                      TI          COLOMBIA           F
# ...                   ...               ...         ...
# 504867                 TI          COLOMBIA           M
# 504868                 CC          COLOMBIA           M
# 504869                 TI          COLOMBIA           F
# 504870                 TI          COLOMBIA           M
# 504871                 TI          COLOMBIA           F
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0       03/03/2003 12:00:00 AM    20204  SB11202040211436      ESTUDIANTE
# 1       05/10/2002 12:00:00 AM    20204  SB11202040433216      ESTUDIANTE
# 2       12/14/2003 12:00:00 AM    20204  SB11202040244180      ESTUDIANTE
# 3       04/12/2003 12:00:00 AM    20204  SB11202040210971      ESTUDIANTE
# 4       03/03/2004 12:00:00 AM    20204  SB11202040235382      ESTUDIANTE
# ...                        ...      ...               ...             ...
# 504867  12/26/2003 12:00:00 AM    20204  SB11202040105446      ESTUDIANTE
# 504868  10/27/1996 12:00:00 AM    20204  SB11202040168415      ESTUDIANTE
# 504869  01/14/2005 12:00:00 AM    20204  SB11202040185843      ESTUDIANTE
# 504870  06/14/2002 12:00:00 AM    20204  SB11202040168607      ESTUDIANTE
# 504871  02/20/2002 12:00:00 AM    20204  SB11202040525571      ESTUDIANTE
#
#        ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  ...  PUNT_INGLES  \
# 0                 SUIZA              No      CUNDINAMARCA  ...         55.0
# 1             VENEZUELA              No      CUNDINAMARCA  ...         33.0
# 2             VENEZUELA              No      CUNDINAMARCA  ...         59.0
# 3             VENEZUELA              No      CUNDINAMARCA  ...         47.0
# 4              COLOMBIA              No      CUNDINAMARCA  ...         43.0
# ...                 ...             ...               ...  ...          ...
# 504867         COLOMBIA              No            BOGOTÁ  ...         45.0
# 504868         COLOMBIA              No            BOGOTÁ  ...         54.0
# 504869         COLOMBIA              No            BOGOTÁ  ...         67.0
# 504870         COLOMBIA              No            BOGOTÁ  ...         52.0
# 504871         COLOMBIA              No            BOGOTÁ  ...         48.0
#
#        PERCENTIL_INGLES  DESEMP_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                    81             A1         244               49
# 1                     6             A-         238               44
# 2                    87             A2         325               94
# 3                    58             A-         238               45
# 4                    40             A-         202               19
# ...                 ...            ...         ...              ...
# 504867               52             A-         282               75
# 504868               79             A1         257               59
# 504869               93             A2         330               95
# 504870               75             A1         290               80
# 504871               63             A1         261               61
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO  \
# 0                 54.882365                 3.0                      3.0
# 1                 49.252311                 2.0                      2.0
# 2                 40.733672                 1.0                      3.0
# 3                 48.217953                 2.0                      3.0
# 4                 60.912192                 3.0                      3.0
# ...                     ...                 ...                      ...
# 504867            45.311449                 2.0                      2.0
# 504868            38.124729                 1.0                      3.0
# 504869            53.586443                 3.0                      3.0
# 504870            58.316936                 3.0                      3.0
# 504871            57.375730                 3.0                      3.0
#
#        ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                      PUBLICAR                        NO
# 1                      PUBLICAR                        NO
# 2                      PUBLICAR  GENERACION E - GRATUIDAD
# 3                      PUBLICAR                        NO
# 4                      PUBLICAR                        NO
# ...                         ...                       ...
# 504867                 PUBLICAR                        NO
# 504868                 PUBLICAR                        NO
# 504869                 PUBLICAR                        NO
# 504870                 PUBLICAR                        NO
# 504871                 PUBLICAR  GENERACION E - GRATUIDAD
#
# [504872 rows x 81 columns]

# %% [markdown]
# ## Conexión a fuente de datos: API

# %% [markdown]
# Una API (Interfaz de Programación de Aplicaciones, por sus siglas en inglés) es un conjunto de reglas y protocolos que permite que diferentes aplicaciones se comuniquen entre sí. En términos más simples, una API define cómo interactuar con un sistema o servicio informático para realizar ciertas operaciones o acceder a determinados recursos.
#
# `Nota: Recursos recomendados:`
# - https://aws.amazon.com/es/what-is/api/
# - https://dossetenta.com/que-es-una-api-rest/
#
# Una API puede ofrecer una variedad de funcionalidades, como acceder a datos, realizar operaciones específicas, controlar dispositivos o sistemas, entre otras. Por lo general, las API están diseñadas para ser utilizadas por otros programas informáticos en lugar de usuarios directamente, aunque en algunos casos también pueden ser accesibles para usuarios finales a través de interfaces de usuario específicas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para establecer una conexión a una API, generalmente se necesitan dos componentes principales:
#
# - `URL de la API:` Es la dirección web que identifica la ubicación y los recursos disponibles en la API. Esta URL incluye endpoints específicos que representan las diferentes funcionalidades o recursos que la API ofrece.
#
# - `Métodos de solicitud:` Son los diferentes tipos de acciones que se pueden realizar en la API, como obtener datos (mediante el método GET), enviar datos (mediante el método POST), actualizar datos (mediante el método PUT o PATCH), o eliminar datos (mediante el método DELETE).
#
# Al enviar una solicitud a la URL de la API utilizando uno de los métodos de solicitud, el programa espera una respuesta de la API que puede contener los datos solicitados o información sobre el éxito o fracaso de la operación realizada.

# %% [markdown]
# ### Información del conjunto de datos: Saber 11° 2020-1

# %% [markdown]
# - Objetivo: Consumir y construir un DataFrame con resultados de las pruebas saber 11° correspondientes al segundo semestre del año 2019.
#
# - Esta fuente de datos es extraida de [Datos Abiertos Colombia](https://www.datos.gov.co/) , Los datos abiertos son información pública dispuesta en formatos que permiten su uso y reutilización bajo licencia abierta y sin restricciones legales para su aprovechamiento.
#
# - Este conjunto de datos, está compuesto por datos anonimizados sobre los resultados y características de los resultados de las pruebas saber 11 correspondientes al segundo semestre del año 2021

# %% [markdown]
# Información General:
#
# - Fuente de datos: [Datos abiertos Colombia - Saber 11° 2020-1](https://www.datos.gov.co/Educaci-n/Saber-11-2020-1/a8xr-en99/about_data)
# - Fecha de creación: 15 de marzo de 2021
# - Filas: 15.435
# - Columnas: 78
# - Vistas: 2843 (a la fecha de descarga)
# - Descargas: 1222 (a la fecha de descarga)
#
# Información de la entidad:
#
# - Área o dependencia: Oficina Asesora de Planeación
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# ### Conexión y consulta a la fuente de datos

# %% [markdown]
# En algunos casos, consumir la API puede ser una buena opción (sobre todo por la actualización constante de datos desde su fuente original para tener metricas en tiempo real.), pero hay que tener la certeza de que al consumir dicho recurso, podamos contar con la totalidad de los registros, desde el equipo de Ingeniería de Datos podrían ayudar a confirmar eso.
#
# Sin embargo, al ser una fuente de datos abierta (pública), y no tener un contacto directo, podemos observar que al primer consumo, no contamos con la totalidad de los registros

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Y si realizamos la prueba, podemos ver que en si, son solo 1000 registros, no contamos con la totalidad de ellos

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_resultados_2020_1 = pd.read_json('https://www.datos.gov.co/resource/a8xr-en99.json')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e:
    
    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:
    
    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# El dataset se cargó exitosamente.

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2020_1 = pd.DataFrame(df_resultados_2020_1)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2020_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 1000 filas y 78 columnas.

# %% [markdown]
# Con la intención de remediar esta situación, ciertos portales de datos abiertos (es posible que no todos) posibilitan y facilitan el acceso directo a través de una interfaz programable. En este caso, contamos con este recurso disponible.
#
# Damos clic en la opción de `Consultar la documentación`, y nos remite a la siguiente URL: https://dev.socrata.com/foundry/www.datos.gov.co/a8xr-en99
#
# Nos dirigimos hasta la parte inferior, la parte final del menú `Code Snippets`, seleccionamos la opción de `Python Pandas` que nos entrega un script de Python que copiamos para reutilizar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Podemos observar, desde un inicio, que nos pide usar la libreria `sodapy` ¿qué es o hace esta libreria?
#
# La librería sodapy es una herramienta en Python que proporciona una forma sencilla de interactuar con la `API de Socrata`. `Socrata` es una plataforma que facilita a los gobiernos, organizaciones sin fines de lucro y empresas compartir datos de manera abierta y accesible al público a través de APIs.
#
# La librería sodapy simplifica el proceso de consulta y descarga de conjuntos de datos alojados en plataformas que utilizan Socrata. Al utilizar sodapy, los usuarios pueden realizar operaciones como:
#
# - Consultar conjuntos de datos específicos.
# - Filtrar datos basados en criterios específicos.
# - Descargar datos en formato tabular, como CSV o JSON.
# - Realizar operaciones de paginación para manejar grandes volúmenes de datos.
# - Acceder a metadatos sobre los conjuntos de datos disponibles.
#
# URL oficial: https://pypi.org/project/sodapy/

# %%
# Instalación de sodapy
# !pip install sodapy
# Out:
# Requirement already satisfied: sodapy in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\espit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.28.1->sodapy) (2023.7.22)

# %%
# Importar la clase Socrata del módulo sodapy.
    # sodapy es una biblioteca Python que facilita la interacción con la API de Socrata, que es una plataforma para la publicación de datos abiertos.
from sodapy import Socrata

# Crea una instancia de la clase Socrata con dos argumentos:
    # 1: "www.datos.gov.co": Es la URL del portal de datos de Colombia (www.datos.gov.co) al que se quiere conectar.
    # 2: None: Este argumento es utilizado para especificar un token de acceso a la API si se requiere autenticación,
        # pero en este caso se pasa como None, lo que significa que no se está usando autenticación para acceder a los datos.
client = Socrata("www.datos.gov.co", None)

# Utiliza el método get del objeto client para hacer una solicitud a la API de Socrata.
# limit=15435: Limita la cantidad de registros que se devuelven a 15,435.
results = client.get("a8xr-en99", limit=15435)

# Convierte los resultados obtenidos de la API, que están en formato de lista de diccionarios, en un DataFrame de pandas.
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2020_1 = pd.DataFrame(results)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2020_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 15435 filas y 78 columnas.

# %%
#  Imprimir el dataframe
df_resultados_2020_1
# Out:
#       estu_tipodocumento       estu_nacionalidad estu_genero  \
# 0                     CC                COLOMBIA           F
# 1                     CC                COLOMBIA           F
# 2                     CC                COLOMBIA           F
# 3                     CC                COLOMBIA           F
# 4                     CC                COLOMBIA           F
# ...                  ...                     ...         ...
# 15430                 TI                  ITALIA           F
# 15431                 TI  PAÍSES BAJOS - HOLANDA           F
# 15432                 TI               VENEZUELA           F
# 15433                 TI               VENEZUELA           F
# 15434                 TI               VENEZUELA           M
#
#           estu_fechanacimiento periodo  estu_consecutivo estu_estudiante  \
# 0      1985-01-01T00:00:00.000   20201  SB11202010045555      ESTUDIANTE
# 1      1995-01-01T00:00:00.000   20201  SB11202010045719      ESTUDIANTE
# 2      1997-01-01T00:00:00.000   20201  SB11202010070662      ESTUDIANTE
# 3      2001-01-01T00:00:00.000   20201  SB11202010069926      ESTUDIANTE
# 4      2001-02-01T00:00:00.000   20201  SB11202010023181      ESTUDIANTE
# ...                        ...     ...               ...             ...
# 15430  0003-08-24T00:00:00.000   20201  SB11202010002849      ESTUDIANTE
# 15431  2002-05-21T00:00:00.000   20201  SB11202010004430      ESTUDIANTE
# 15432  2001-12-07T00:00:00.000   20201  SB11202010008503      ESTUDIANTE
# 15433  2003-04-25T00:00:00.000   20201  SB11202010072919      ESTUDIANTE
# 15434  0001-12-27T00:00:00.000   20201  SB11202010002521      ESTUDIANTE
#
#              estu_pais_reside estu_tieneetnia estu_depto_reside  ...  \
# 0                    COLOMBIA              No             CESAR  ...
# 1                    COLOMBIA              No            NARIÑO  ...
# 2                    COLOMBIA              Si             CAUCA  ...
# 3                    COLOMBIA              No          PUTUMAYO  ...
# 4                    COLOMBIA              No         RISARALDA  ...
# ...                       ...             ...               ...  ...
# 15430                  ITALIA              No             VALLE  ...
# 15431  PAÍSES BAJOS - HOLANDA              No             VALLE  ...
# 15432               VENEZUELA              No            BOGOTÁ  ...
# 15433               VENEZUELA              No   NORTE SANTANDER  ...
# 15434               VENEZUELA              No             VALLE  ...
#
#       punt_sociales_ciudadanas percentil_sociales_ciudadanas  \
# 0                           24                             1
# 1                           44                            23
# 2                           24                             1
# 3                           33                             7
# 4                           53                            42
# ...                        ...                           ...
# 15430                       60                            60
# 15431                       70                            86
# 15432                       64                            69
# 15433                       47                            30
# 15434                       68                            81
#
#       desemp_sociales_ciudadanas punt_ingles percentil_ingles desemp_ingles  \
# 0                              1          36                7            A-
# 1                              2          30                3            A-
# 2                              1          30                3            A-
# 3                              1          37                8            A-
# 4                              2          80               80            B+
# ...                          ...         ...              ...           ...
# 15430                          3          73               62            B1
# 15431                          3         100              100            B+
# 15432                          3          79               77            B+
# 15433                          2          40               11            A-
# 15434                          3          78               74            B1
#
#       punt_global percentil_global  estu_estadoinvestigacion  \
# 0             164                2  VALIDEZ OFICINA JURÍDICA
# 1             202               10                  PUBLICAR
# 2             162                2                  PUBLICAR
# 3             188                6                  PUBLICAR
# 4             274               39                  PUBLICAR
# ...           ...              ...                       ...
# 15430         303               54                  PUBLICAR
# 15431         366               91                  PUBLICAR
# 15432         337               76                  PUBLICAR
# 15433         253               28                  PUBLICAR
# 15434         359               88                  PUBLICAR
#
#               estu_generacion_e
# 0      GENERACION E - GRATUIDAD
# 1      GENERACION E - GRATUIDAD
# 2      GENERACION E - GRATUIDAD
# 3                            NO
# 4                            NO
# ...                         ...
# 15430                        NO
# 15431                        NO
# 15432                        NO
# 15433  GENERACION E - GRATUIDAD
# 15434                        NO
#
# [15435 rows x 78 columns]

# %% [markdown]
# ## Conexión a fuente de datos: SQL Server

# %% [markdown]
# Una conexión a SQL Server es un enlace establecido entre una aplicación o programa y un servidor de base de datos SQL Server. SQL Server es un sistema de gestión de bases de datos relacional desarrollado por Microsoft, utilizado para almacenar, recuperar y administrar datos de manera eficiente y segura.
#
# Cuando una aplicación necesita interactuar con una base de datos SQL Server, debe establecer una conexión para enviar consultas y recibir resultados. Esta conexión permite que la aplicación envíe comandos SQL al servidor de base de datos y reciba los resultados de esas consultas.
#
# Una conexión a SQL Server generalmente incluye los siguientes componentes:
#
# 1. Servidor: La dirección o nombre del servidor donde se aloja la base de datos SQL Server.
#
# 2. Base de datos: El nombre de la base de datos a la que se desea acceder dentro del servidor.
#
# 3. Credenciales de autenticación: Las credenciales de usuario (nombre de usuario y contraseña) necesarias para autenticar y establecer la conexión con el servidor.
#
# 4. Opciones de configuración: Otras opciones de configuración, como el puerto de conexión, el tipo de autenticación (Windows o SQL Server), el tiempo de espera de la conexión, entre otras.
#
# Una vez que se establece la conexión, la aplicación puede enviar consultas SQL al servidor de base de datos y recibir los resultados, que pueden incluir datos recuperados, registros afectados por una operación de actualización o eliminación, mensajes de error, etc.
#
# Recursos recomendados:
#
# - https://www.astera.com/es/knowledge-center/python-to-sql-server-integration/
# - https://learn.microsoft.com/es-es/sql/connect/python/pyodbc/step-3-proof-of-concept-connecting-to-sql-using-pyodbc?view=sql-server-ver16
# - https://learn.microsoft.com/es-es/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver16

# %% [markdown]
# ### Información del conjunto de datos: Saber 11° 2019-2

# %% [markdown]
# - Objetivo: Consumir y construir un DataFrame con resultados de las pruebas saber 11° correspondientes al segundo semestre del año 2019.
#
# - Esta fuente de datos es extraida de [Datos Abiertos Colombia](https://www.datos.gov.co/) , Los datos abiertos son información pública dispuesta en formatos que permiten su uso y reutilización bajo licencia abierta y sin restricciones legales para su aprovechamiento.
#
# - Este conjunto de datos, está compuesto por datos anonimizados sobre los resultados y características de los resultados de las pruebas saber 11 correspondientes al segundo semestre del año 2019

# %% [markdown]
# #### Ficha técnica

# %% [markdown]
# Información General:
#
# - Fuente de datos: [Datos abiertos Colombia - Saber 11° 2019-2](https://www.datos.gov.co/Educaci-n/Saber-11-2019-2/ynam-yc42/about_data)
# - Fecha de creación: 23 de diciembre de 2019
# - Filas: 546.212
# - Columnas: 82
# - Vistas: 53,4K (a la fecha de descarga)
# - Descargas: 90,03K (a la fecha de descarga)
#
# Información de la entidad:
#
# - Área o dependencia: Instituto Colombiano para la Evaluación de la Educación - ICFES
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# #### Conexión y consulta a la fuente de datos

# %%
# La función filterwarnings() del módulo warnings, ignora las advertencias que puedan surgir durante la ejecución del programa.
warnings.filterwarnings('ignore')

# Configuración de la conexión a la base de datos
# Aquí se definen las variables que contienen la información para establecer la conexión a SQL Server
direccion_servidor = 'localhost'
nombre_bd = 'resultados_icfes_dev'
nombre_usuario = 'sa'
password = '1038'

# Intentar establecer la conexión
# La función connect(), intenta establecer la conexión, se pasa una cadena de conexión como argumento a esta función,
    # que incluye los detalles del servidor, la base de datos, el usuario y la contraseña.
try:
    conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=' + 
                          direccion_servidor+';DATABASE='+nombre_bd+';UID='+nombre_usuario+';PWD=' + password)
    print("Conexión exitosa")

except Exception as e:
    print("Ocurrió un error al conectar a SQL Server: ", e)
# Out:
# Conexión exitosa

# %%
# Ignora las advertencias que Python podría mostrar. En este caso, evita que se muestren advertencias en la consola.
warnings.filterwarnings('ignore')

# Define una consulta SQL en una cadena de texto triple comilla.
consulta_sql = '''
SELECT * FROM [dbo].[Saber_11_2019-2]
               '''
# Ejecuta la consulta SQL en una base de datos conectada (conn).
    # Carga los resultados de la consulta en el DataFrame
df_resultados_2019_2 = pd.read_sql(consulta_sql, conn)

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2019_2 = pd.DataFrame(df_resultados_2019_2)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2019_2.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 546212 filas y 82 columnas.

# %%
#  Imprimir el dataframe
df_resultados_2019_2
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0       02/18/2002 12:00:00 AM   20194  SB11201940031558      ESTUDIANTE
# 1       06/28/2003 12:00:00 AM   20194  SB11201940303339      ESTUDIANTE
# 2       06/02/2001 12:00:00 AM   20194  SB11201940255017      ESTUDIANTE
# 3       04/26/2002 12:00:00 AM   20194  SB11201940154799      ESTUDIANTE
# 4       02/05/2002 12:00:00 AM   20194  SB11201940280831      ESTUDIANTE
# ...                        ...     ...               ...             ...
# 546207  02/25/1999 12:00:00 AM   20194  SB11201940195862      ESTUDIANTE
# 546208  10/14/2002 12:00:00 AM   20194  SB11201940253002      ESTUDIANTE
# 546209  11/22/2002 12:00:00 AM   20194  SB11201940364767      ESTUDIANTE
# 546210  11/10/2002 12:00:00 AM   20194  SB11201940210026      ESTUDIANTE
# 546211  06/02/2002 12:00:00 AM   20194  SB11201940074679      ESTUDIANTE
#
#        ESTU_TIENEETNIA ESTU_PAIS_RESIDE ESTU_ETNIA  ... PUNT_INGLES  \
# 0                   No         COLOMBIA          -  ...          54
# 1                   No         COLOMBIA          -  ...          63
# 2                   No         COLOMBIA          -  ...          64
# 3                   Si         COLOMBIA    Ninguno  ...          53
# 4                   No         COLOMBIA          -  ...          52
# ...                ...              ...        ...  ...         ...
# 546207              No         COLOMBIA          -  ...          58
# 546208              No         COLOMBIA          -  ...          74
# 546209              No         COLOMBIA          -  ...          72
# 546210              No         COLOMBIA          -  ...          46
# 546211              No         COLOMBIA          -  ...          74
#
#        PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                    67            A1         208               25
# 1                    88            A2         299               83
# 2                    89            A2         299               84
# 3                    67            A1         309               88
# 4                    63            A1         288               78
# ...                 ...           ...         ...              ...
# 546207               79            A2         360               99
# 546208               97            B1         360               99
# 546209               96            B1         377              100
# 546210               45            A-         278               73
# 546211               97            B1         365               99
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO  \
# 0          50.9421557404314                   2                        2
# 1           59.767864431576                   3                        4
# 2          50.7642383644749                   2                        3
# 3          45.7791353123516                   2                        3
# 4          52.9109464277177                   3                        3
# ...                     ...                 ...                      ...
# 546207     47.5807720132296                   2                        2
# 546208      57.406418472062                   3                        4
# 546209     71.2254308010465                   4                        3
# 546210     38.1334451267846                   1                        2
# 546211     49.7833058735661                   2                        3
#
#        ESTU_ESTADOINVESTIGACION                        ESTU_GENERACION_E
# 0                      PUBLICAR                                       NO
# 1                      PUBLICAR                                       NO
# 2                      PUBLICAR                 GENERACION E - GRATUIDAD
# 3                      PUBLICAR                 GENERACION E - GRATUIDAD
# 4                      PUBLICAR                                       NO
# ...                         ...                                      ...
# 546207                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
# 546208                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
# 546209                 PUBLICAR  GENERACION E - EXCELENCIA DEPARTAMENTAL
# 546210                 PUBLICAR                 GENERACION E - GRATUIDAD
# 546211                 PUBLICAR       GENERACION E - EXCELENCIA NACIONAL
#
# [546212 rows x 82 columns]

# %% [markdown]
# ### Información del conjunto de datos: Saber_11_2018-1

# %% [markdown]
# - Objetivo: Consumir y construir un DataFrame con resultados de las pruebas saber 11° correspondientes al segundo semestre del año 2018.
#
# - Esta fuente de datos es extraida de [Datos Abiertos Colombia](https://www.datos.gov.co/) , Los datos abiertos son información pública dispuesta en formatos que permiten su uso y reutilización bajo licencia abierta y sin restricciones legales para su aprovechamiento.
#
# - Este conjunto de datos, está compuesto por datos anonimizados sobre los resultados y características de los resultados de las pruebas saber 11 correspondientes al segundo semestre del año 2018

# %% [markdown]
# #### Ficha técnica

# %% [markdown]
# Información General:
#
# - Fuente de datos: [Datos abiertos Colombia - Saber 11° 2018-Refinado](https://www.datos.gov.co/Educaci-n/Resultados-Saber-11-2018-1-Refinado/ptck-fi3s/about_data)
#
# - Fecha de creación: 17 de octubre de 2019
# - Filas: 19798
# - Columnas: 87
# - Vistas: 7154 (a la fecha de descarga)
# - Descargas: 575 (a la fecha de descarga)
#
# Información de la entidad:
#
# - Área o dependencia: Instituto Colombiano para la Evaluación de la Educación - ICFES
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# #### Conexión y consulta a la fuente de datos

# %%
# Ignora las advertencias que Python podría mostrar. En este caso, evita que se muestren advertencias en la consola.
warnings.filterwarnings('ignore')

# Define una consulta SQL en una cadena de texto triple comilla.
consulta_sql = '''
SELECT * FROM [dbo].[Saber_11_2018-1]
               '''
# Ejecuta la consulta SQL en una base de datos conectada (conn).
    # Carga los resultados de la consulta en el DataFrame
df_resultados_2018_1 = pd.read_sql(consulta_sql, conn)

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2018_1 = pd.DataFrame(df_resultados_2018_1)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2018_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 19798 filas y 87 columnas.

# %%
df_resultados_2018_1
# Out:
#       estu_tipodocumento estu_nacionalidad estu_genero estu_fechanacimiento  \
# 0                     CC          COLOMBIA           F           29/09/1999
# 1                     TI          COLOMBIA           M           19/03/2001
# 2                     TI          COLOMBIA           M           31/07/2000
# 3                     TI          COLOMBIA           F           20/01/2002
# 4                     TI          COLOMBIA           F           23/10/2001
# ...                  ...               ...         ...                  ...
# 19793                 TI          COLOMBIA           F           08/09/2001
# 19794                 TI          COLOMBIA           F           31/07/2001
# 19795                 TI          COLOMBIA           F           03/03/2000
# 19796                 TI          COLOMBIA           F           03/01/2000
# 19797                 TI          COLOMBIA           M           07/04/2001
#
#       periodo  estu_consecutivo estu_estudiante estu_pais_reside  \
# 0       20181  SB11201810007354      ESTUDIANTE         COLOMBIA
# 1       20181  SB11201810018765      ESTUDIANTE         COLOMBIA
# 2       20181  SB11201810028523      ESTUDIANTE         COLOMBIA
# 3       20181  SB11201810003574      ESTUDIANTE         COLOMBIA
# 4       20181  SB11201810024346      ESTUDIANTE         COLOMBIA
# ...       ...               ...             ...              ...
# 19793   20181  SB11201810007633      ESTUDIANTE         COLOMBIA
# 19794   20181  SB11201810012404      ESTUDIANTE         COLOMBIA
# 19795   20181  SB11201810000158      ESTUDIANTE         COLOMBIA
# 19796   20181  SB11201810013391      ESTUDIANTE         COLOMBIA
# 19797   20181  SB11201810059201      ESTUDIANTE         COLOMBIA
#
#       estu_tieneetnia                  estu_etnia  ...  \
# 0                  No                     Ninguno  ...
# 1                  No                     Ninguno  ...
# 2                  No                     Ninguno  ...
# 3                  No                     Ninguno  ...
# 4                  No                     Ninguno  ...
# ...               ...                         ...  ...
# 19793              No                     Ninguno  ...
# 19794              No                     Ninguno  ...
# 19795              Si  Comunidad afrodescendiente  ...
# 19796              No                     Ninguno  ...
# 19797              No                     Ninguno  ...
#
#       desemp_sociales_ciudadanas punt_ingles percentil_ingles desemp_ingles  \
# 0                              3          90               99            B+
# 1                              4          86               94            B+
# 2                              1          29                3            A-
# 3                              3          79               78            B+
# 4                              3          71               65            B1
# ...                          ...         ...              ...           ...
# 19793                          2          50               30            A1
# 19794                          3          59               46            A2
# 19795                          4          87               96            B+
# 19796                          3          85               92            B+
# 19797                          3          74               68            B1
#
#       punt_global percentil_global estu_inse_individual estu_nse_individual  \
# 0             344               78            76.391075                NSE4
# 1             417              100             65.54921                NSE4
# 2             166                2            53.659302                NSE3
# 3             336               73            80.709663                NSE4
# 4             346               79            53.908249                NSE3
# ...           ...              ...                  ...                 ...
# 19793         267               39            54.277687                NSE3
# 19794         302               55            50.641411                NSE2
# 19795         396               98             72.03582                NSE4
# 19796         332               71            65.294937                NSE4
# 19797         332               71            62.398525                NSE3
#
#        estu_estadoinvestigacion estu_pilopaga
# 0                      PUBLICAR            NO
# 1                      PUBLICAR            NO
# 2                      PUBLICAR            NO
# 3                      PUBLICAR            NO
# 4      VALIDEZ OFICINA JURÍDICA            NO
# ...                         ...           ...
# 19793                  PUBLICAR            NO
# 19794                  PUBLICAR            NO
# 19795                  PUBLICAR            NO
# 19796                  PUBLICAR            NO
# 19797                  PUBLICAR            NO
#
# [19798 rows x 87 columns]

# %% [markdown]
# ### Información del conjunto de datos: Saber_11_2021-1

# %% [markdown]
# - Objetivo: Consumir y construir un DataFrame con resultados de las pruebas saber 11° correspondientes al segundo semestre del año 2018.
#
# - Esta fuente de datos es extraida de [Datos Abiertos Colombia](https://www.datos.gov.co/) , Los datos abiertos son información pública dispuesta en formatos que permiten su uso y reutilización bajo licencia abierta y sin restricciones legales para su aprovechamiento.
#
# - Este conjunto de datos, está compuesto por datos anonimizados sobre los resultados y características de los resultados de las pruebas saber 11 correspondientes al segundo semestre del año 2018

# %% [markdown]
# #### Ficha técnica

# %% [markdown]
# Información General:
#
# - Fuente de datos:
# - Fecha de creación:
# - Filas:
# - Columnas:
# - Vistas:
# - Descargas:
#
# Información de la entidad:
#
# - Área o dependencia: Instituto Colombiano para la Evaluación de la Educación - ICFES
# - Nombre de la entidad: Instituto Colombiano para la Evaluación de la Educación
# - Departamento: Bogotá D.C.
# - Municipio: Bogotá D.C.
# - Orden: Nacional
# - Sector: Educación
#
# Información del conjunto de datos:
#
# - Idioma: Español
# - URL de documenación: http://www.icfes.gov.co/investigadores-y-estudiantes-posgrado/acceso-a-bases-de-datos
# - URL de normativa: http://www.icfes.gov.co/normatividad
#
# Temas:
#
# - Categoría: Educación
# - Etiquetas: `pruebas icfes`,`icfes`,`saber 11`,`resultados`

# %% [markdown]
# #### Conexión y consulta a la fuente de datos

# %%
### Conexión a la fuente de datos: Saber_11_2021-1

# Ignora las advertencias que Python podría mostrar. En este caso, evita que se muestren advertencias en la consola.
warnings.filterwarnings('ignore')

# Define una consulta SQL en una cadena de texto triple comilla.
consulta_sql = '''
SELECT * FROM [dbo].[Saber_11_2021-1]
               '''
# Ejecuta la consulta SQL en una base de datos conectada (conn).
    # Carga los resultados de la consulta en el DataFrame
df_resultados_2021_1 = pd.read_sql(consulta_sql, conn)

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_resultados_2021_1 = pd.DataFrame(df_resultados_2021_1)

# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2021_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 15528 filas y 40 columnas.

# %%
df_resultados_2021_1
# Out:
#       periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 0       20211            TI  SB11202110001547         RURAL             S
# 1       20211            CR  SB11202110021004        URBANO          None
# 2       20211            TI  SB11202110002427        URBANO             S
# 3       20211            TI  SB11202110002880        URBANO             N
# 4       20211            TI  SB11202110022054        URBANO             S
# ...       ...           ...               ...           ...           ...
# 15523   20211            TI  SB11202110007181        URBANO             N
# 15524   20211            CC  SB11202110065415        URBANO             N
# 15525   20211            TI  SB11202110064360        URBANO             N
# 15526   20211            CC  SB11202110002939        URBANO             N
# 15527   20211            TI  SB11202110009581        URBANO             N
#
#       cole_calendario      cole_caracter cole_depto_ubi cole_genero  \
# 0                   B          ACADÉMICO   CUNDINAMARCA       MIXTO
# 1                   A          ACADÉMICO   CUNDINAMARCA       MIXTO
# 2                   B          ACADÉMICO      MAGDALENA       MIXTO
# 3                   B  TÉCNICO/ACADÉMICO          VALLE       MIXTO
# 4                   B          ACADÉMICO         BOGOTÁ       MIXTO
# ...               ...                ...            ...         ...
# 15523               B          ACADÉMICO          VALLE       MIXTO
# 15524            OTRO          ACADÉMICO          VALLE       MIXTO
# 15525               A          ACADÉMICO         BOYACA       MIXTO
# 15526               B          ACADÉMICO          VALLE       MIXTO
# 15527               B          ACADÉMICO          VALLE       MIXTO
#
#       cole_tipo_jornada  ... fami_tiene_automovil fami_tiene_pc  \
# 0              COMPLETA  ...                   Si            Si
# 1                MAÑANA  ...                   Si            Si
# 2              COMPLETA  ...                 None          None
# 3                MAÑANA  ...                   Si            Si
# 4              COMPLETA  ...                   Si            Si
# ...                 ...  ...                  ...           ...
# 15523          COMPLETA  ...                   No            Si
# 15524             NOCHE  ...                   No            Si
# 15525            MAÑANA  ...                   No            Si
# 15526          COMPLETA  ...                   Si            Si
# 15527            MAÑANA  ...                   No            Si
#
#       fami_tiene_internet desempeno_ingles resul_ingles resul_matematicas  \
# 0                      Si               B+         83.0              74.0
# 1                      Si               A2         66.0              59.0
# 2                    None               B+         87.0              80.0
# 3                      Si               B1         70.0              69.0
# 4                      Si               B+         89.0              65.0
# ...                   ...              ...          ...               ...
# 15523                  Si               A1         57.0              61.0
# 15524                  Si               A1         51.0              29.0
# 15525                  Si               A-         45.0              33.0
# 15526                  Si               B1         75.0              46.0
# 15527                  Si               A1         50.0              47.0
#
#       resul_sociales_naturales resul_ciencias_naturales resul_lectura_critica  \
# 0                         64.0                     61.0                  69.0
# 1                         60.0                     56.0                  66.0
# 2                         74.0                     62.0                  69.0
# 3                         63.0                     71.0                  70.0
# 4                         74.0                     65.0                  71.0
# ...                        ...                      ...                   ...
# 15523                     63.0                     58.0                  60.0
# 15524                     43.0                     42.0                  39.0
# 15525                     35.0                     42.0                  40.0
# 15526                     63.0                     56.0                  60.0
# 15527                     44.0                     32.0                  50.0
#
#       resul_global
# 0            341.0
# 1            303.0
# 2            362.0
# 3            342.0
# 4            352.0
# ...            ...
# 15523        301.0
# 15524        196.0
# 15525        190.0
# 15526        288.0
# 15527        219.0
#
# [15528 rows x 40 columns]

# %% [markdown]
# # Métodos de recolección y limpieza de datos.

# %% [markdown]
# En el campo de la ciencia de datos, la recolección, limpieza y centralización de datos son procesos fundamentales para preparar los datos antes de realizar análisis y modelos predictivos.
#
# `Recolección de datos:` Es el proceso de obtener datos de diversas fuentes, como:
#
# - Bases de datos: públicas, privadas, locales o en la nube.
# - Archivos: CSV, Excel, JSON, XML, etc.
# - Sensores: dispositivos físicos que capturan información del mundo real.
# - Web scraping: extracción de datos de páginas web.
# - APIs: interfaces de programación que permiten acceder a datos de otras aplicaciones.

# %%
num_cols_2018_1 = df_resultados_2018_1.shape[1]
num_cols_2019_2 = df_resultados_2019_2.shape[1]
num_cols_2020_1 = df_resultados_2020_1.shape[1]
num_cols_2020_2 = df_resultados_2020_2.shape[1]
num_cols_2021_1 = df_resultados_2021_1.shape[1]

# Se crea un nuevo DataFrame llamado Saber_11_acumulado.
Saber_11_acumulado = pd.DataFrame({
    # Se define una columna llamada 'Año' con los años 2019-2, 2020-1 y 2020-2.
    'Año': ['2018-1','2019-2','2020-1','2020-2','2021-1'],
    # Se define una columna llamada 'Total registros por año'.
    'Total registros por año':
    # Cuenta el número de registros únicos de las columnas 'ESTU_CONSECUTIVO' de 2019_2, 2020_1 y 2020_2.
        # los suma y añade a la columna 'Total registros por año'
        [
            df_resultados_2018_1['estu_consecutivo'].count(),
            df_resultados_2019_2['ESTU_CONSECUTIVO'].count(),
            df_resultados_2020_1['estu_consecutivo'].count(),
            df_resultados_2020_2['ESTU_CONSECUTIVO'].count(),
            df_resultados_2021_1['estu_id'].count()
        ],
        # Se define una columna llamada 'Cantidad de columnas'.
        'Cantidad de columnas': [num_cols_2018_1, num_cols_2019_2, num_cols_2020_1, num_cols_2020_2, num_cols_2021_1]
})

# Muestra el DataFrame Saber_11_acumulado con la información recopilada.
Saber_11_acumulado
# Out:
#       Año  Total registros por año  Cantidad de columnas
# 0  2018-1                    19798                    87
# 1  2019-2                   546212                    82
# 2  2020-1                    15435                    78
# 3  2020-2                   504872                    81
# 4  2021-1                    15528                    40

# %%
# Visualización del comportamiento de los registros

# Se crea un diccionario llamado registros_por_annio para almacenar el número de registros de cada año.
registros_por_annio = {
                        '2018-1' : df_resultados_2018_1.shape[0],
                        '2019-2' : df_resultados_2019_2.shape[0],
                        '2020-1' : df_resultados_2020_1.shape[0],
                        '2020-2' : df_resultados_2020_2.shape[0],
                        '2021-1' : df_resultados_2021_1.shape[0]
                    }

# Crear una lista de años y una lista de la cantidad de registros 
años = list(registros_por_annio.keys()) 
registros = list(registros_por_annio.values())

# Crear el gráfico de líneas 
plt.figure(figsize=(12, 3)) 
plt.plot(años, registros, marker='o', linestyle='-', color='b')

# Agregar etiquetas de valor para cada punto 
for año, registro in zip(años, registros): 
    plt.text(año, registro, str(registro), ha='center', va='bottom') 

plt.title('Comparación de Cantidad de Registros por periodo')
plt.xlabel('Año')
plt.ylabel('Cantidad de Registros')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Limpieza

# %% [markdown]
# `Limpieza de datos:` Es el proceso de preparar los datos para su análisis, eliminando inconsistencias, errores y valores atípicos. Algunas tareas comunes de limpieza incluyen:
#
# - Eliminar filas duplicadas.
# - Corregir errores de formato.
# - Tratar valores nulos y faltantes.
# - Normalizar las variables.
# - Detectar y eliminar valores atípicos.

# %% [markdown]
# Durante el proceso de limpieza de datos, es crucial identificar y seleccionar únicamente aquellos elementos esenciales que servirán como soporte y suministro para el proceso de normalización.
#
# En este contexto, partiendo de la siguiente selección, se llevará a cabo la eliminación de las columnas que no coincidan en los DataFrame's que se han construido.

# %% [markdown]
# Antes de identificar las diferencias y similitudes entre los DataFrames, es necesario normalizar las columnas de los DataFrame `df_resultados_2018_1` y `df_resultados_2020_1`. A diferencia de los otros conjuntos de datos, todas sus columnas están en minúsculas. Es recomendable convertirlas a mayúsculas para facilitar el proceso de normalización y estandarización de nuestro conjunto de datos final.

# %%
df_resultados_2018_1.rename (columns = {
                                        'estu_tipodocumento'                : 'ESTU_TIPODOCUMENTO',
                                        'estu_nacionalidad'                 : 'ESTU_NACIONALIDAD',
                                        'estu_genero'                       : 'ESTU_GENERO',
                                        'estu_fechanacimiento'              : 'ESTU_FECHANACIMIENTO',
                                        'periodo'                           : 'PERIODO',
                                        'estu_consecutivo'                  : 'ESTU_CONSECUTIVO',
                                        'estu_estudiante'                   : 'ESTU_ESTUDIANTE',
                                        'estu_pais_reside'                  : 'ESTU_PAIS_RESIDE',
                                        'estu_tieneetnia'                   : 'ESTU_TIENEETNIA',
                                        'estu_etnia'                        : 'ESTU_ETNIA',
                                        'estu_limita_motriz'                : 'ESTU_LIMITA_MOTRIZ',
                                        'estu_limita_invidente'             : 'ESTU_LIMITA_INVIDENTE',
                                        'estu_limita_condicionespecial'     : 'ESTU_LIMITA_CONDICIONESPECIAL',
                                        'estu_limita_sordo'                 : 'ESTU_LIMITA_SORDO',
                                        'estu_limita_sdown'                 : 'ESTU_LIMITA_SDOWN',
                                        'estu_limita_autismo'               : 'ESTU_LIMITA_AUTISMO',
                                        'estu_depto_reside'                 : 'ESTU_DEPTO_RESIDE',
                                        'estu_cod_reside_depto'             : 'ESTU_COD_RESIDE_DEPTO',
                                        'estu_mcpio_reside'                 : 'ESTU_MCPIO_RESIDE',
                                        'estu_cod_reside_mcpio'             : 'ESTU_COD_RESIDE_MCPIO',
                                        'fami_estratovivienda'              : 'FAMI_ESTRATOVIVIENDA',
                                        'fami_personashogar'                : 'FAMI_PERSONASHOGAR',
                                        'fami_cuartoshogar'                 : 'FAMI_CUARTOSHOGAR',
                                        'fami_educacionpadre'               : 'FAMI_EDUCACIONPADRE',
                                        'fami_educacionmadre'               : 'FAMI_EDUCACIONMADRE',
                                        'fami_trabajolaborpadre'            : 'FAMI_TRABAJOLABORPADRE',
                                        'fami_trabajolabormadre'            : 'FAMI_TRABAJOLABORMADRE',
                                        'fami_tieneinternet'                : 'FAMI_TIENEINTERNET',
                                        'fami_tieneserviciotv'              : 'FAMI_TIENESERVICIOTV',
                                        'fami_tienecomputador'              : 'FAMI_TIENECOMPUTADOR',
                                        'fami_tienelavadora'                : 'FAMI_TIENELAVADORA',
                                        'fami_tienehornomicroogas'          : 'FAMI_TIENEHORNOMICROOGAS',
                                        'fami_tieneautomovil'               : 'FAMI_TIENEAUTOMOVIL',
                                        'fami_tienemotocicleta'             : 'FAMI_TIENEMOTOCICLETA',
                                        'fami_tieneconsolavideojuegos'      : 'FAMI_TIENECONSOLAVIDEOJUEGOS',
                                        'fami_numlibros'                    : 'FAMI_NUMLIBROS',
                                        'fami_comelechederivados'           : 'FAMI_COMELECHEDERIVADOS',
                                        'fami_comecarnepescadohuevo'        : 'FAMI_COMECARNEPESCADOHUEVO',
                                        'fami_comecerealfrutoslegumbre'     : 'FAMI_COMECEREALFRUTOSLEGUMBRE',
                                        'fami_situacioneconomica'           : 'FAMI_SITUACIONECONOMICA',
                                        'estu_dedicacionlecturadiaria'      : 'ESTU_DEDICACIONLECTURADIARIA',
                                        'estu_dedicacioninternet'           : 'ESTU_DEDICACIONINTERNET',
                                        'estu_horassemanatrabaja'           : 'ESTU_HORASSEMANATRABAJA',
                                        'estu_tiporemuneracion'             : 'ESTU_TIPOREMUNERACION',
                                        'cole_codigo_icfes'                 : 'COLE_CODIGO_ICFES',
                                        'cole_cod_dane_establecimiento'     : 'COLE_COD_DANE_ESTABLECIMIENTO',
                                        'cole_nombre_establecimiento'       : 'COLE_NOMBRE_ESTABLECIMIENTO',
                                        'cole_genero'                       : 'COLE_GENERO',
                                        'cole_naturaleza'                   : 'COLE_NATURALEZA',
                                        'cole_calendario'                   : 'COLE_CALENDARIO',
                                        'cole_bilingue'                     : 'COLE_BILINGUE',
                                        'cole_caracter'                     : 'COLE_CARACTER',
                                        'cole_cod_dane_sede'                : 'COLE_COD_DANE_SEDE',
                                        'cole_nombre_sede'                  : 'COLE_NOMBRE_SEDE',
                                        'cole_sede_principal'               : 'COLE_SEDE_PRINCIPAL',
                                        'cole_area_ubicacion'               : 'COLE_AREA_UBICACION',
                                        'cole_jornada'                      : 'COLE_JORNADA',
                                        'cole_cod_mcpio_ubicacion'          : 'COLE_COD_MCPIO_UBICACION',
                                        'cole_mcpio_ubicacion'              : 'COLE_MCPIO_UBICACION',
                                        'cole_cod_depto_ubicacion'          : 'COLE_COD_DEPTO_UBICACION',
                                        'cole_depto_ubicacion'              : 'COLE_DEPTO_UBICACION',
                                        'estu_privado_libertad'             : 'ESTU_PRIVADO_LIBERTAD',
                                        'estu_cod_mcpio_presentacion'       : 'ESTU_COD_MCPIO_PRESENTACION',
                                        'estu_mcpio_presentacion'           : 'ESTU_MCPIO_PRESENTACION',
                                        'estu_depto_presentacion'           : 'ESTU_DEPTO_PRESENTACION',
                                        'estu_cod_depto_presentacion'       : 'ESTU_COD_DEPTO_PRESENTACION',
                                        'punt_lectura_critica'              : 'PUNT_LECTURA_CRITICA',
                                        'percentil_lectura_critica'         : 'PERCENTIL_LECTURA_CRITICA',
                                        'desemp_lectura_critica'            : 'DESEMP_LECTURA_CRITICA',
                                        'punt_matematicas'                  : 'PUNT_MATEMATICAS',
                                        'percentil_matematicas'             : 'PERCENTIL_MATEMATICAS',
                                        'desemp_matematicas'                : 'DESEMP_MATEMATICAS',
                                        'punt_c_naturales'                  : 'PUNT_C_NATURALES',
                                        'percentil_c_naturales'             : 'PERCENTIL_C_NATURALES',
                                        'desemp_c_naturales'                : 'DESEMP_C_NATURALES',
                                        'punt_sociales_ciudadanas'          : 'PUNT_SOCIALES_CIUDADANAS',
                                        'percentil_sociales_ciudadanas'     : 'PERCENTIL_SOCIALES_CIUDADANAS',
                                        'desemp_sociales_ciudadanas'        : 'DESEMP_SOCIALES_CIUDADANAS',
                                        'punt_ingles'                       : 'PUNT_INGLES',
                                        'percentil_ingles'                  : 'PERCENTIL_INGLES',
                                        'desemp_ingles'                     : 'DESEMP_INGLES',
                                        'punt_global'                       : 'PUNT_GLOBAL',
                                        'percentil_global'                  : 'PERCENTIL_GLOBAL',
                                        'estu_inse_individual'              : 'ESTU_INSE_INDIVIDUAL',
                                        'estu_nse_individual'               : 'ESTU_NSE_INDIVIDUAL',
                                        'estu_estadoinvestigacion'          : 'ESTU_ESTADOINVESTIGACION',
                                        'estu_pilopaga'                     : 'ESTU_PILOPAGA',
                                    }, inplace=True)

# %%
# Validar renombramiento de columnas
df_resultados_2018_1
# Out:
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                     CC          COLOMBIA           F           29/09/1999
# 1                     TI          COLOMBIA           M           19/03/2001
# 2                     TI          COLOMBIA           M           31/07/2000
# 3                     TI          COLOMBIA           F           20/01/2002
# 4                     TI          COLOMBIA           F           23/10/2001
# ...                  ...               ...         ...                  ...
# 19793                 TI          COLOMBIA           F           08/09/2001
# 19794                 TI          COLOMBIA           F           31/07/2001
# 19795                 TI          COLOMBIA           F           03/03/2000
# 19796                 TI          COLOMBIA           F           03/01/2000
# 19797                 TI          COLOMBIA           M           07/04/2001
#
#       PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  \
# 0       20181  SB11201810007354      ESTUDIANTE         COLOMBIA
# 1       20181  SB11201810018765      ESTUDIANTE         COLOMBIA
# 2       20181  SB11201810028523      ESTUDIANTE         COLOMBIA
# 3       20181  SB11201810003574      ESTUDIANTE         COLOMBIA
# 4       20181  SB11201810024346      ESTUDIANTE         COLOMBIA
# ...       ...               ...             ...              ...
# 19793   20181  SB11201810007633      ESTUDIANTE         COLOMBIA
# 19794   20181  SB11201810012404      ESTUDIANTE         COLOMBIA
# 19795   20181  SB11201810000158      ESTUDIANTE         COLOMBIA
# 19796   20181  SB11201810013391      ESTUDIANTE         COLOMBIA
# 19797   20181  SB11201810059201      ESTUDIANTE         COLOMBIA
#
#       ESTU_TIENEETNIA                  ESTU_ETNIA  ...  \
# 0                  No                     Ninguno  ...
# 1                  No                     Ninguno  ...
# 2                  No                     Ninguno  ...
# 3                  No                     Ninguno  ...
# 4                  No                     Ninguno  ...
# ...               ...                         ...  ...
# 19793              No                     Ninguno  ...
# 19794              No                     Ninguno  ...
# 19795              Si  Comunidad afrodescendiente  ...
# 19796              No                     Ninguno  ...
# 19797              No                     Ninguno  ...
#
#       DESEMP_SOCIALES_CIUDADANAS PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES  \
# 0                              3          90               99            B+
# 1                              4          86               94            B+
# 2                              1          29                3            A-
# 3                              3          79               78            B+
# 4                              3          71               65            B1
# ...                          ...         ...              ...           ...
# 19793                          2          50               30            A1
# 19794                          3          59               46            A2
# 19795                          4          87               96            B+
# 19796                          3          85               92            B+
# 19797                          3          74               68            B1
#
#       PUNT_GLOBAL PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  \
# 0             344               78            76.391075                NSE4
# 1             417              100             65.54921                NSE4
# 2             166                2            53.659302                NSE3
# 3             336               73            80.709663                NSE4
# 4             346               79            53.908249                NSE3
# ...           ...              ...                  ...                 ...
# 19793         267               39            54.277687                NSE3
# 19794         302               55            50.641411                NSE2
# 19795         396               98             72.03582                NSE4
# 19796         332               71            65.294937                NSE4
# 19797         332               71            62.398525                NSE3
#
#        ESTU_ESTADOINVESTIGACION ESTU_PILOPAGA
# 0                      PUBLICAR            NO
# 1                      PUBLICAR            NO
# 2                      PUBLICAR            NO
# 3                      PUBLICAR            NO
# 4      VALIDEZ OFICINA JURÍDICA            NO
# ...                         ...           ...
# 19793                  PUBLICAR            NO
# 19794                  PUBLICAR            NO
# 19795                  PUBLICAR            NO
# 19796                  PUBLICAR            NO
# 19797                  PUBLICAR            NO
#
# [19798 rows x 87 columns]

# %%
df_resultados_2020_1.rename (columns = {
                                        'estu_tipodocumento'                : 'ESTU_TIPODOCUMENTO',
                                        'estu_nacionalidad'                 : 'ESTU_NACIONALIDAD',
                                        'estu_genero'                       : 'ESTU_GENERO',
                                        'estu_fechanacimiento'              : 'ESTU_FECHANACIMIENTO',
                                        'periodo'                           : 'PERIODO',
                                        'estu_consecutivo'                  : 'ESTU_CONSECUTIVO',
                                        'estu_estudiante'                   : 'ESTU_ESTUDIANTE',
                                        'estu_pais_reside'                  : 'ESTU_PAIS_RESIDE',
                                        'estu_tieneetnia'                   : 'ESTU_TIENEETNIA',
                                        'estu_depto_reside'                 : 'ESTU_DEPTO_RESIDE',
                                        'estu_cod_reside_depto'             : 'ESTU_COD_RESIDE_DEPTO',
                                        'estu_mcpio_reside'                 : 'ESTU_MCPIO_RESIDE',
                                        'estu_cod_reside_mcpio'             : 'ESTU_COD_RESIDE_MCPIO',
                                        'fami_estratovivienda'              : 'FAMI_ESTRATOVIVIENDA',
                                        'fami_personashogar'                : 'FAMI_PERSONASHOGAR',
                                        'fami_cuartoshogar'                 : 'FAMI_CUARTOSHOGAR',
                                        'fami_educacionpadre'               : 'FAMI_EDUCACIONPADRE',
                                        'fami_educacionmadre'               : 'FAMI_EDUCACIONMADRE',
                                        'fami_trabajolaborpadre'            : 'FAMI_TRABAJOLABORPADRE',
                                        'fami_trabajolabormadre'            : 'FAMI_TRABAJOLABORMADRE',
                                        'fami_tieneinternet'                : 'FAMI_TIENEINTERNET',
                                        'fami_tieneserviciotv'              : 'FAMI_TIENESERVICIOTV',
                                        'fami_tienecomputador'              : 'FAMI_TIENECOMPUTADOR',
                                        'fami_tienelavadora'                : 'FAMI_TIENELAVADORA',
                                        'fami_tienehornomicroogas'          : 'FAMI_TIENEHORNOMICROOGAS',
                                        'fami_tieneautomovil'               : 'FAMI_TIENEAUTOMOVIL',
                                        'fami_tienemotocicleta'             : 'FAMI_TIENEMOTOCICLETA',
                                        'fami_tieneconsolavideojuegos'      : 'FAMI_TIENECONSOLAVIDEOJUEGOS',
                                        'fami_numlibros'                    : 'FAMI_NUMLIBROS',
                                        'fami_comelechederivados'           : 'FAMI_COMELECHEDERIVADOS',
                                        'fami_comecarnepescadohuevo'        : 'FAMI_COMECARNEPESCADOHUEVO',
                                        'fami_comecerealfrutoslegumbre'     : 'FAMI_COMECEREALFRUTOSLEGUMBRE',
                                        'fami_situacioneconomica'           : 'FAMI_SITUACIONECONOMICA',
                                        'estu_dedicacionlecturadiaria'      : 'ESTU_DEDICACIONLECTURADIARIA',
                                        'estu_dedicacioninternet'           : 'ESTU_DEDICACIONINTERNET',
                                        'estu_horassemanatrabaja'           : 'ESTU_HORASSEMANATRABAJA',
                                        'estu_tiporemuneracion'             : 'ESTU_TIPOREMUNERACION',
                                        'cole_codigo_icfes'                 : 'COLE_CODIGO_ICFES',
                                        'cole_cod_dane_establecimiento'     : 'COLE_COD_DANE_ESTABLECIMIENTO',
                                        'cole_nombre_establecimiento'       : 'COLE_NOMBRE_ESTABLECIMIENTO',
                                        'cole_genero'                       : 'COLE_GENERO',
                                        'cole_naturaleza'                   : 'COLE_NATURALEZA',
                                        'cole_calendario'                   : 'COLE_CALENDARIO',
                                        'cole_bilingue'                     : 'COLE_BILINGUE',
                                        'cole_caracter'                     : 'COLE_CARACTER',
                                        'cole_cod_dane_sede'                : 'COLE_COD_DANE_SEDE',
                                        'cole_nombre_sede'                  : 'COLE_NOMBRE_SEDE',
                                        'cole_sede_principal'               : 'COLE_SEDE_PRINCIPAL',
                                        'cole_area_ubicacion'               : 'COLE_AREA_UBICACION',
                                        'cole_jornada'                      : 'COLE_JORNADA',
                                        'cole_cod_mcpio_ubicacion'          : 'COLE_COD_MCPIO_UBICACION',
                                        'cole_mcpio_ubicacion'              : 'COLE_MCPIO_UBICACION',
                                        'cole_cod_depto_ubicacion'          : 'COLE_COD_DEPTO_UBICACION',
                                        'cole_depto_ubicacion'              : 'COLE_DEPTO_UBICACION',
                                        'estu_privado_libertad'             : 'ESTU_PRIVADO_LIBERTAD',
                                        'estu_cod_mcpio_presentacion'       : 'ESTU_COD_MCPIO_PRESENTACION',
                                        'estu_mcpio_presentacion'           : 'ESTU_MCPIO_PRESENTACION',
                                        'estu_depto_presentacion'           : 'ESTU_DEPTO_PRESENTACION',
                                        'estu_cod_depto_presentacion'       : 'ESTU_COD_DEPTO_PRESENTACION',
                                        'punt_lectura_critica'              : 'PUNT_LECTURA_CRITICA',
                                        'percentil_lectura_critica'         : 'PERCENTIL_LECTURA_CRITICA',
                                        'desemp_lectura_critica'            : 'DESEMP_LECTURA_CRITICA',
                                        'punt_matematicas'                  : 'PUNT_MATEMATICAS',
                                        'percentil_matematicas'             : 'PERCENTIL_MATEMATICAS',
                                        'desemp_matematicas'                : 'DESEMP_MATEMATICAS',
                                        'punt_c_naturales'                  : 'PUNT_C_NATURALES',
                                        'percentil_c_naturales'             : 'PERCENTIL_C_NATURALES',
                                        'desemp_c_naturales'                : 'DESEMP_C_NATURALES',
                                        'punt_sociales_ciudadanas'          : 'PUNT_SOCIALES_CIUDADANAS',
                                        'percentil_sociales_ciudadanas'     : 'PERCENTIL_SOCIALES_CIUDADANAS',
                                        'desemp_sociales_ciudadanas'        : 'DESEMP_SOCIALES_CIUDADANAS',
                                        'punt_ingles'                       : 'PUNT_INGLES',
                                        'percentil_ingles'                  : 'PERCENTIL_INGLES',
                                        'desemp_ingles'                     : 'DESEMP_INGLES',
                                        'punt_global'                       : 'PUNT_GLOBAL',
                                        'percentil_global'                  : 'PERCENTIL_GLOBAL',
                                        'estu_estadoinvestigacion'          : 'ESTU_ESTADOINVESTIGACION',
                                        'estu_generacion_e'                 : 'ESTU_GENERACION_E'
                                    }, inplace=True)

# %%
# Validar renombramiento de columnas
df_resultados_2020_1
# Out:
#       ESTU_TIPODOCUMENTO       ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                     CC                COLOMBIA           F
# 1                     CC                COLOMBIA           F
# 2                     CC                COLOMBIA           F
# 3                     CC                COLOMBIA           F
# 4                     CC                COLOMBIA           F
# ...                  ...                     ...         ...
# 15430                 TI                  ITALIA           F
# 15431                 TI  PAÍSES BAJOS - HOLANDA           F
# 15432                 TI               VENEZUELA           F
# 15433                 TI               VENEZUELA           F
# 15434                 TI               VENEZUELA           M
#
#           ESTU_FECHANACIMIENTO PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0      1985-01-01T00:00:00.000   20201  SB11202010045555      ESTUDIANTE
# 1      1995-01-01T00:00:00.000   20201  SB11202010045719      ESTUDIANTE
# 2      1997-01-01T00:00:00.000   20201  SB11202010070662      ESTUDIANTE
# 3      2001-01-01T00:00:00.000   20201  SB11202010069926      ESTUDIANTE
# 4      2001-02-01T00:00:00.000   20201  SB11202010023181      ESTUDIANTE
# ...                        ...     ...               ...             ...
# 15430  0003-08-24T00:00:00.000   20201  SB11202010002849      ESTUDIANTE
# 15431  2002-05-21T00:00:00.000   20201  SB11202010004430      ESTUDIANTE
# 15432  2001-12-07T00:00:00.000   20201  SB11202010008503      ESTUDIANTE
# 15433  2003-04-25T00:00:00.000   20201  SB11202010072919      ESTUDIANTE
# 15434  0001-12-27T00:00:00.000   20201  SB11202010002521      ESTUDIANTE
#
#              ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  ...  \
# 0                    COLOMBIA              No             CESAR  ...
# 1                    COLOMBIA              No            NARIÑO  ...
# 2                    COLOMBIA              Si             CAUCA  ...
# 3                    COLOMBIA              No          PUTUMAYO  ...
# 4                    COLOMBIA              No         RISARALDA  ...
# ...                       ...             ...               ...  ...
# 15430                  ITALIA              No             VALLE  ...
# 15431  PAÍSES BAJOS - HOLANDA              No             VALLE  ...
# 15432               VENEZUELA              No            BOGOTÁ  ...
# 15433               VENEZUELA              No   NORTE SANTANDER  ...
# 15434               VENEZUELA              No             VALLE  ...
#
#       PUNT_SOCIALES_CIUDADANAS PERCENTIL_SOCIALES_CIUDADANAS  \
# 0                           24                             1
# 1                           44                            23
# 2                           24                             1
# 3                           33                             7
# 4                           53                            42
# ...                        ...                           ...
# 15430                       60                            60
# 15431                       70                            86
# 15432                       64                            69
# 15433                       47                            30
# 15434                       68                            81
#
#       DESEMP_SOCIALES_CIUDADANAS PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES  \
# 0                              1          36                7            A-
# 1                              2          30                3            A-
# 2                              1          30                3            A-
# 3                              1          37                8            A-
# 4                              2          80               80            B+
# ...                          ...         ...              ...           ...
# 15430                          3          73               62            B1
# 15431                          3         100              100            B+
# 15432                          3          79               77            B+
# 15433                          2          40               11            A-
# 15434                          3          78               74            B1
#
#       PUNT_GLOBAL PERCENTIL_GLOBAL  ESTU_ESTADOINVESTIGACION  \
# 0             164                2  VALIDEZ OFICINA JURÍDICA
# 1             202               10                  PUBLICAR
# 2             162                2                  PUBLICAR
# 3             188                6                  PUBLICAR
# 4             274               39                  PUBLICAR
# ...           ...              ...                       ...
# 15430         303               54                  PUBLICAR
# 15431         366               91                  PUBLICAR
# 15432         337               76                  PUBLICAR
# 15433         253               28                  PUBLICAR
# 15434         359               88                  PUBLICAR
#
#               ESTU_GENERACION_E
# 0      GENERACION E - GRATUIDAD
# 1      GENERACION E - GRATUIDAD
# 2      GENERACION E - GRATUIDAD
# 3                            NO
# 4                            NO
# ...                         ...
# 15430                        NO
# 15431                        NO
# 15432                        NO
# 15433  GENERACION E - GRATUIDAD
# 15434                        NO
#
# [15435 rows x 78 columns]

# %% [markdown]
#  Para identificar las columnas que no coinciden entre los tres DataFrames, realizaremos los siguientes pasos:

# %%
# 1: Crear conjuntos de columnas para cada DataFrame:
    # Convertir las columnas de cada DataFrame en conjuntos (sets) para poder realizar operaciones de conjuntos y encontrar las diferencias.

cols_2018_1 = set(df_resultados_2018_1.columns)
cols_2019_2 = set(df_resultados_2019_2.columns)
cols_2020_1 = set(df_resultados_2020_1.columns)
cols_2020_2 = set(df_resultados_2020_2.columns)

# 2: Encontrar las columnas únicas para cada DataFrame:
unique_to_2018_1 = cols_2018_1 - cols_2019_2 - cols_2020_1 - cols_2020_2
unique_to_2019_2 = cols_2019_2 - cols_2020_1 - cols_2020_2 - cols_2018_1
unique_to_2020_1 = cols_2020_1 - cols_2019_2 - cols_2020_2 - cols_2018_1
unique_to_2020_2 = cols_2020_2 - cols_2019_2 - cols_2020_1 - cols_2018_1

# 3: Encontrar las columnas comunes a todos los DataFrames: 
common_cols = cols_2019_2 & cols_2020_1 & cols_2020_2 & cols_2018_1

# Imprimir resultados:
print("Columnas únicas en df_resultados_2018_1:", unique_to_2018_1)
print("Columnas únicas en df_resultados_2019_2:", unique_to_2019_2)
print("Columnas únicas en df_resultados_2020_1:", unique_to_2020_1)
print("Columnas únicas en df_resultados_2020_2:", unique_to_2020_2)
print("Columnas comunes a todos los DataFrames:", common_cols)
# Out:
# Columnas únicas en df_resultados_2018_1: {'ESTU_LIMITA_AUTISMO', 'ESTU_LIMITA_SDOWN', 'ESTU_PILOPAGA', 'ESTU_LIMITA_MOTRIZ', 'ESTU_LIMITA_SORDO', 'ESTU_LIMITA_INVIDENTE', 'ESTU_LIMITA_CONDICIONESPECIAL'}
# Columnas únicas en df_resultados_2019_2: set()
# Columnas únicas en df_resultados_2020_1: set()
# Columnas únicas en df_resultados_2020_2: {'ESTU_GENERACION-E'}
# Columnas comunes a todos los DataFrames: {'COLE_DEPTO_UBICACION', 'PERCENTIL_MATEMATICAS', 'ESTU_TIPOREMUNERACION', 'COLE_JORNADA', 'COLE_GENERO', 'COLE_COD_DANE_ESTABLECIMIENTO', 'PERCENTIL_GLOBAL', 'ESTU_TIPODOCUMENTO', 'PUNT_C_NATURALES', 'ESTU_ESTADOINVESTIGACION', 'COLE_MCPIO_UBICACION', 'PERCENTIL_INGLES', 'FAMI_SITUACIONECONOMICA', 'ESTU_DEPTO_RESIDE', 'PUNT_GLOBAL', 'ESTU_COD_RESIDE_MCPIO', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEHORNOMICROOGAS', 'ESTU_PAIS_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_TIENEETNIA', 'PUNT_MATEMATICAS', 'ESTU_DEDICACIONINTERNET', 'COLE_AREA_UBICACION', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONMADRE', 'ESTU_MCPIO_RESIDE', 'PUNT_LECTURA_CRITICA', 'COLE_COD_DANE_SEDE', 'ESTU_COD_MCPIO_PRESENTACION', 'COLE_COD_MCPIO_UBICACION', 'PUNT_SOCIALES_CIUDADANAS', 'ESTU_MCPIO_PRESENTACION', 'FAMI_NUMLIBROS', 'FAMI_TIENESERVICIOTV', 'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEAUTOMOVIL', 'DESEMP_C_NATURALES', 'PERCENTIL_LECTURA_CRITICA', 'COLE_NOMBRE_ESTABLECIMIENTO', 'FAMI_TIENEMOTOCICLETA', 'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEPTO_PRESENTACION', 'FAMI_COMECARNEPESCADOHUEVO', 'ESTU_PRIVADO_LIBERTAD', 'COLE_COD_DEPTO_UBICACION', 'PERIODO', 'ESTU_FECHANACIMIENTO', 'ESTU_NACIONALIDAD', 'FAMI_TRABAJOLABORPADRE', 'DESEMP_LECTURA_CRITICA', 'COLE_CODIGO_ICFES', 'ESTU_CONSECUTIVO', 'DESEMP_SOCIALES_CIUDADANAS', 'FAMI_TIENEINTERNET', 'FAMI_ESTRATOVIVIENDA', 'FAMI_COMELECHEDERIVADOS', 'COLE_NOMBRE_SEDE', 'ESTU_GENERO', 'FAMI_EDUCACIONPADRE', 'DESEMP_INGLES', 'DESEMP_MATEMATICAS', 'ESTU_ESTUDIANTE', 'PUNT_INGLES', 'FAMI_TIENECONSOLAVIDEOJUEGOS', 'COLE_SEDE_PRINCIPAL', 'FAMI_TIENELAVADORA', 'FAMI_PERSONASHOGAR', 'COLE_BILINGUE', 'PERCENTIL_C_NATURALES', 'COLE_CALENDARIO', 'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_HORASSEMANATRABAJA', 'PERCENTIL_SOCIALES_CIUDADANAS', 'FAMI_COMECEREALFRUTOSLEGUMBRE', 'COLE_CARACTER', 'COLE_NATURALEZA'}

# %% [markdown]
# Basándonos en los resultados obtenidos al identificar las columnas similares y diferentes entre los DataFrames, podemos sacar algunas conclusiones:
#
# 1. Columnas Únicas por DataFrame:
#
# - `df_resultados_2018_1`: La únicas columnas únicas son:
#                          `'ESTU_LIMITA_SDOWN'`
#                          `'ESTU_PILOPAGA'`
#                          `'ESTU_LIMITA_AUTISMO'`
#                          `'ESTU_LIMITA_CONDICIONESPECIAL'`
#                          `'ESTU_LIMITA_MOTRIZ'`
#                          `'ESTU_HORASSEMANATRABAJA'`
#                          `'ESTU_LIMITA_INVIDENTE'`
#                          `'ESTU_LIMITA_SORDO'`
#                           que no está presente en los otros dos DataFrames.
#
# - `df_resultados_2019_2`: La única columna única es `'ESTU_ETNIA'`, que no está presente en los otros dos DataFrames.
# - `df_resultados_2020_1`: No tiene columnas únicas, todas sus columnas están presentes en los otros DataFrames.
# - `df_resultados_2020_2`: La única columna única es `'ESTU_GENERACION-E'` ¿No se encuentra en los otros DataFrames?
#
# 2. Normalización y Estandarización:
#
# - Las diferencias en las columnas entre los DataFrames pueden requerir normalización y estandarización para garantizar que los datos sean comparables y se puedan utilizar en análisis conjuntos. Esto es especialmente relevante para las columnas únicas en cada DataFrame.
#
# 3. Consistencia en Datos Comunes:
#
# - Las columnas comunes a todos los DataFrames pueden ser consideradas como las más estables y consistentes a lo largo del tiempo. Estas columnas podrían ser prioritarias en análisis que requieran datos consistentes entre los años.
#
# 4. Análisis de Datos Únicos:
#
# - Las columnas únicas en cada DataFrame podrían ser de interés para análisis específicos o para entender cambios o adiciones en los datos a lo largo del tiempo. Es importante revisar y entender estas columnas para determinar su relevancia en los análisis.
#
# Basándonos en los resultados obtenidos, realizaremos los ajustes necesarios.

# %% [markdown]
# ### Eliminar columnas de df_resultados_2018_1

# %%
# Eliminar la columna 'ESTU_ETNIA' de df_resultados_2018_1

columnas_a_eliminar = ['ESTU_ESTUDIANTE','ESTU_ETNIA','ESTU_LIMITA_MOTRIZ',
                        'ESTU_LIMITA_INVIDENTE','ESTU_LIMITA_CONDICIONESPECIAL','ESTU_LIMITA_SORDO',
                        'ESTU_LIMITA_SDOWN','ESTU_LIMITA_AUTISMO','ESTU_COD_RESIDE_DEPTO',
                        'ESTU_COD_RESIDE_MCPIO','FAMI_TIENESERVICIOTV','FAMI_TIENELAVADORA',
                        'FAMI_TIENEHORNOMICROOGAS','FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA',
                        'FAMI_COMELECHEDERIVADOS','FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE',
                        'COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_CALENDARIO',
                        'COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE','COLE_SEDE_PRINCIPAL','COLE_COD_MCPIO_UBICACION',
                        'COLE_MCPIO_UBICACION','COLE_COD_DEPTO_UBICACION','COLE_DEPTO_UBICACION',
                        'ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION',
                        'ESTU_COD_DEPTO_PRESENTACION','PERCENTIL_LECTURA_CRITICA','DESEMP_LECTURA_CRITICA',
                        'PERCENTIL_MATEMATICAS','DESEMP_MATEMATICAS','PERCENTIL_C_NATURALES','DESEMP_C_NATURALES',
                        'PERCENTIL_SOCIALES_CIUDADANAS','DESEMP_SOCIALES_CIUDADANAS','PERCENTIL_INGLES',
                        'DESEMP_INGLES','PERCENTIL_GLOBAL','ESTU_INSE_INDIVIDUAL','ESTU_NSE_INDIVIDUAL',
                        'ESTU_ESTADOINVESTIGACION','ESTU_PILOPAGA'
]
try:
    df_resultados_2018_1 = df_resultados_2018_1.drop(columns=columnas_a_eliminar)
    print("Las columnas seleccionadas se eliminaron con éxito.")
except KeyError as e:
    print(f"Error al eliminar las columnas: {e}. Algunas columnas no existen en el DataFrame.")
# Out:
# Las columnas seleccionadas se eliminaron con éxito.

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2018_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 19798 filas y 40 columnas.

# %% [markdown]
# ### Eliminar columnas de df_resultados_2019_2

# %%
# Eliminar la columna 'ESTU_ETNIA' de df_resultados_2019_2

columnas_a_eliminar = ['ESTU_ESTUDIANTE','ESTU_ETNIA','ESTU_COD_RESIDE_DEPTO',
                        'ESTU_COD_RESIDE_MCPIO','FAMI_TIENESERVICIOTV','FAMI_TIENELAVADORA',
                        'FAMI_TIENEHORNOMICROOGAS','FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA',
                        'FAMI_COMELECHEDERIVADOS','FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE',
                        'COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_CALENDARIO',
                        'COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE','COLE_SEDE_PRINCIPAL',
                        'COLE_COD_MCPIO_UBICACION', 'COLE_MCPIO_UBICACION','COLE_COD_DEPTO_UBICACION',
                        'COLE_DEPTO_UBICACION','ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_COD_DEPTO_PRESENTACION',
                        'PERCENTIL_LECTURA_CRITICA','DESEMP_LECTURA_CRITICA',
                        'PERCENTIL_MATEMATICAS','DESEMP_MATEMATICAS',
                        'PERCENTIL_C_NATURALES','DESEMP_C_NATURALES',
                        'PERCENTIL_SOCIALES_CIUDADANAS','DESEMP_SOCIALES_CIUDADANAS',
                        'PERCENTIL_INGLES', 'DESEMP_INGLES',
                        'PERCENTIL_GLOBAL',
                        'ESTU_INSE_INDIVIDUAL','ESTU_NSE_INDIVIDUAL',
                        'ESTU_NSE_ESTABLECIMIENTO','ESTU_ESTADOINVESTIGACION','ESTU_GENERACION_E'
]
try:
    df_resultados_2019_2 = df_resultados_2019_2.drop(columns=columnas_a_eliminar)
    print("Las columnas seleccionadas se eliminaron con éxito.")
except KeyError as e:
    print(f"Error al eliminar las columnas: {e}. Algunas columnas no existen en el DataFrame.")
# Out:
# Las columnas seleccionadas se eliminaron con éxito.

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2019_2.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 546212 filas y 40 columnas.

# %% [markdown]
# ### Eliminar columnas de df_resultados_2020_1

# %%
columnas_a_eliminar = ['ESTU_ESTUDIANTE','ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
                       'FAMI_TIENESERVICIOTV','FAMI_TIENELAVADORA','FAMI_TIENEHORNOMICROOGAS',
                       'FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA',
                       'FAMI_COMELECHEDERIVADOS','FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE',
                       'COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_CALENDARIO',
                       'COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE','COLE_SEDE_PRINCIPAL',
                       'COLE_COD_MCPIO_UBICACION', 'COLE_MCPIO_UBICACION','COLE_COD_DEPTO_UBICACION','COLE_DEPTO_UBICACION',
                       'ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_COD_DEPTO_PRESENTACION',
                       'PERCENTIL_LECTURA_CRITICA','DESEMP_LECTURA_CRITICA',
                       'PERCENTIL_MATEMATICAS','DESEMP_MATEMATICAS',
                       'PERCENTIL_C_NATURALES','DESEMP_C_NATURALES',
                       'PERCENTIL_SOCIALES_CIUDADANAS','DESEMP_SOCIALES_CIUDADANAS',
                       'PERCENTIL_INGLES', 'DESEMP_INGLES',
                       'PERCENTIL_GLOBAL',
                       'ESTU_ESTADOINVESTIGACION','ESTU_GENERACION_E'
]
try:
    df_resultados_2020_1 = df_resultados_2020_1.drop(columns=columnas_a_eliminar)
    print("Las columnas seleccionadas se eliminaron con éxito.")
except KeyError as e:
    print(f"Error al eliminar las columnas: {e}. Algunas columnas no existen en el DataFrame.")
# Out:
# Las columnas seleccionadas se eliminaron con éxito.

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2020_1.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 15435 filas y 40 columnas.

# %% [markdown]
# ### Eliminar columnas de df_resultados_2020_2

# %%
columnas_a_eliminar = ['ESTU_ESTUDIANTE','ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
                       'FAMI_TIENESERVICIOTV','FAMI_TIENELAVADORA','FAMI_TIENEHORNOMICROOGAS',
                       'FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA',
                       'FAMI_COMELECHEDERIVADOS','FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE',
                       'COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_CALENDARIO',
                       'COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE','COLE_SEDE_PRINCIPAL',
                       'COLE_COD_MCPIO_UBICACION', 'COLE_MCPIO_UBICACION','COLE_COD_DEPTO_UBICACION','COLE_DEPTO_UBICACION',
                       'ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_COD_DEPTO_PRESENTACION',
                       'PERCENTIL_LECTURA_CRITICA','DESEMP_LECTURA_CRITICA',
                       'PERCENTIL_MATEMATICAS','DESEMP_MATEMATICAS',
                       'PERCENTIL_C_NATURALES','DESEMP_C_NATURALES',
                       'PERCENTIL_SOCIALES_CIUDADANAS','DESEMP_SOCIALES_CIUDADANAS',
                       'PERCENTIL_INGLES', 'DESEMP_INGLES',
                       'PERCENTIL_GLOBAL',
                       'ESTU_INSE_INDIVIDUAL','ESTU_NSE_INDIVIDUAL','ESTU_NSE_ESTABLECIMIENTO',
                       'ESTU_ESTADOINVESTIGACION','ESTU_GENERACION-E'

]
try:
    df_resultados_2020_2 = df_resultados_2020_2.drop(columns=columnas_a_eliminar)
    print("Las columnas seleccionadas se eliminaron con éxito.")
except KeyError as e:
    print(f"Error al eliminar las columnas: {e}. Algunas columnas no existen en el DataFrame.")
# Out:
# Las columnas seleccionadas se eliminaron con éxito.

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_resultados_2020_2.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 504872 filas y 40 columnas.

# %% [markdown]
# ### Validar normalización de cantidad de columnas

# %% [markdown]
# Si volvemos a validar y reutilizar el código anterior donde ejecutamos los pasos de diferencia y comparación, podemos ver el resultado:

# %%
# 1: Crear conjuntos de columnas para cada DataFrame:
    # Convertir las columnas de cada DataFrame en conjuntos (sets) para poder realizar operaciones de conjuntos y encontrar las diferencias.

cols_2018_1 = set(df_resultados_2018_1.columns)
cols_2019_2 = set(df_resultados_2019_2.columns)
cols_2020_1 = set(df_resultados_2020_1.columns)
cols_2020_2 = set(df_resultados_2020_2.columns)

# 2: Encontrar las columnas únicas para cada DataFrame:
unique_to_2018_1 = cols_2018_1 - cols_2019_2 - cols_2020_1 - cols_2020_2
unique_to_2019_2 = cols_2019_2 - cols_2020_1 - cols_2020_2 - cols_2018_1
unique_to_2020_1 = cols_2020_1 - cols_2019_2 - cols_2020_2 - cols_2018_1
unique_to_2020_2 = cols_2020_2 - cols_2019_2 - cols_2020_1 - cols_2018_1

# 3: Encontrar las columnas comunes a todos los DataFrames: 
common_cols = cols_2019_2 & cols_2020_1 & cols_2020_2 & cols_2018_1

# Imprimir resultados:
print("Columnas únicas en df_resultados_2018_1:", unique_to_2018_1)
print("Columnas únicas en df_resultados_2019_2:", unique_to_2019_2)
print("Columnas únicas en df_resultados_2020_1:", unique_to_2020_1)
print("Columnas únicas en df_resultados_2020_2:", unique_to_2020_2)
print("Columnas comunes a todos los DataFrames:", common_cols)
# Out:
# Columnas únicas en df_resultados_2018_1: set()
# Columnas únicas en df_resultados_2019_2: set()
# Columnas únicas en df_resultados_2020_1: set()
# Columnas únicas en df_resultados_2020_2: set()
# Columnas comunes a todos los DataFrames: {'PUNT_MATEMATICAS', 'PERIODO', 'ESTU_FECHANACIMIENTO', 'ESTU_TIPOREMUNERACION', 'ESTU_DEDICACIONINTERNET', 'ESTU_NACIONALIDAD', 'COLE_AREA_UBICACION', 'COLE_JORNADA', 'FAMI_CUARTOSHOGAR', 'COLE_GENERO', 'FAMI_EDUCACIONMADRE', 'ESTU_TIPODOCUMENTO', 'PUNT_C_NATURALES', 'ESTU_MCPIO_RESIDE', 'FAMI_TRABAJOLABORPADRE', 'PUNT_INGLES', 'FAMI_TIENECONSOLAVIDEOJUEGOS', 'ESTU_CONSECUTIVO', 'PUNT_LECTURA_CRITICA', 'FAMI_PERSONASHOGAR', 'PUNT_SOCIALES_CIUDADANAS', 'COLE_BILINGUE', 'COLE_CARACTER', 'FAMI_SITUACIONECONOMICA', 'FAMI_TIENEINTERNET', 'ESTU_DEPTO_RESIDE', 'PUNT_GLOBAL', 'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENECOMPUTADOR', 'FAMI_NUMLIBROS', 'ESTU_GENERO', 'FAMI_TRABAJOLABORMADRE', 'FAMI_EDUCACIONPADRE', 'ESTU_HORASSEMANATRABAJA', 'ESTU_PAIS_RESIDE', 'COLE_NOMBRE_ESTABLECIMIENTO', 'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_TIENEETNIA', 'ESTU_PRIVADO_LIBERTAD', 'COLE_NATURALEZA'}

# %% [markdown]
# Anexo a eso, podemos consultar la cantidad de registros y columnas para cada DataFrame

# %%
# Conteo de columnas de cada DataFrame
num_cols_2018_1 = df_resultados_2018_1.shape[1]
num_cols_2019_2 = df_resultados_2019_2.shape[1]
num_cols_2020_1 = df_resultados_2020_1.shape[1]
num_cols_2020_2 = df_resultados_2020_2.shape[1]

# Se crea un nuevo DataFrame llamado Saber_11_acumulado.
Saber_11_acumulado = pd.DataFrame({
    # Se define una columna llamada 'Año' con los años 2019-2, 2020-1 y 2020-2.
    'Año': ['2018-1','2019-2', '2020-1', '2020-2'],
    # Se define una columna llamada 'Total registros por año'.
    'Total registros por año': [
        # Cuenta el número de registros únicos de las columnas 'ESTU_CONSECUTIVO' de 2019_2, 2020_1 y 2020_2,
        # y los suma.
        df_resultados_2018_1['ESTU_CONSECUTIVO'].count(),
        df_resultados_2019_2['ESTU_CONSECUTIVO'].count(),
        df_resultados_2020_1['ESTU_CONSECUTIVO'].count(),
        df_resultados_2020_2['ESTU_CONSECUTIVO'].count()
    ],
    # Se define una columna llamada 'Cantidad de columnas'.
    'Cantidad de columnas': [num_cols_2018_1, num_cols_2019_2, num_cols_2020_1, num_cols_2020_2]
})

# Muestra el DataFrame Saber_11_acumulado con la información recopilada.
Saber_11_acumulado
# Out:
#       Año  Total registros por año  Cantidad de columnas
# 0  2018-1                    19798                    40
# 1  2019-2                   546212                    40
# 2  2020-1                    15435                    40
# 3  2020-2                   504872                    40

# %% [markdown]
# `Observaciones:`
#  - Se estandariza la cantidad total de columnas (40) para todos los DataFrame antes mencionados.

# %% [markdown]
# ## Centralización

# %% [markdown]
# `Centralización de datos:` Es el proceso de almacenar todos los datos en un único lugar, lo que facilita su acceso y análisis. Algunas opciones para centralizar datos son:
#
# - Data lakes: almacenes de datos a gran escala que pueden albergar datos de diferentes formatos y estructuras.
# - Data warehouses: almacenes de datos estructurados y optimizados para el análisis.
# - Bases de datos NoSQL: ideales para almacenar datos no estructurados o semiestructurados.

# %% [markdown]
# `Importancia de la recolección, limpieza y centralización de datos:`
#
# - Mejora la calidad de los datos.
# - Facilita el análisis de datos.
# - Aumenta la eficiencia del trabajo científico.
# - Permite tomar mejores decisiones.
#
# `Herramientas para la recolección, limpieza y centralización de datos:`
#
# - `Python:` Lenguaje de programación con librerías como Pandas, NumPy, Scikit-learn y BeautifulSoup.
# - `R:` Lenguaje de programación estadístico con librerías como tidyverse, ggplot2 y dplyr.
# - `SAS:` Software comercial para análisis de datos.
# - `SSIS:` Microsoft SQL Server Integration Services (SSIS) es una plataforma que permite generar soluciones de integración de datos de alto rendimiento

# %%
# Concatenar los DataFrames para crear uno nuevo llamado 'acumulado_saber_11'

Saber_11_acumulado = pd.concat([df_resultados_2018_1, df_resultados_2019_2,
                                df_resultados_2020_1, df_resultados_2020_2, 
                                ])

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = Saber_11_acumulado.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 1086317 filas y 40 columnas.

# %%
# Imprimir columnas
Saber_11_acumulado.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_MCPIO_RESIDE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO',
#        'COLE_NATURALEZA', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_AREA_UBICACION', 'COLE_JORNADA', 'ESTU_PRIVADO_LIBERTAD',
#        'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL'],
#       dtype='object')

# %%
# Exportar el dataframe acumulado_saber_11 en formato CSV

Saber_11_acumulado.to_csv('acumulado_saber_11.csv', index=False)

print(f"El archivo ha sido exportada exitosamente")
# Out:
# El archivo ha sido exportada exitosamente

# %% [markdown]
# # Reconocimiento inicial/básico del proceso de centralización (nuevo DataFrame)

# %%
# Identificación de porcentajes faltantes por columnas

# Se utiliza el método replace para reemplazar cadenas vacías o que contienen solo espacios en blanco (^\s*$) por NaN (Not a Number).
Saber_11_acumulado = Saber_11_acumulado.replace(r'^\s*$', np.nan, regex=True)

# Devuelve el mismo DataFrame Saber_11_acumulado,  pero con valores booleanos (True o False) indicando si cada celda es NaN o no.
# Suma los valores True para cada columna, ya que Python considera True como 1 y False como 0.
# Se multiplica por 100 y se divide por el número total de filas para obtener el porcentaje de valores faltantes por columna.
percent_missing = Saber_11_acumulado.isnull().sum() * 100 / len(Saber_11_acumulado)

# Se crea un nuevo DataFrame (temporal, solo para este propósito) llamado missing_value_df que contiene dos columnas:
    # Columnas: nombres de las columnas del DataFrame original Saber_11_acumulado.
    # Porcentajes_vacios: porcentajes de valores faltantes calculados anteriormente y almacenados en percent_missing.
missing_value_df = pd.DataFrame({'Columnas': Saber_11_acumulado.columns,
                                 'Porcentajes_vacios': percent_missing})
missing_value_df.sort_values(by="Porcentajes_vacios", ascending= False).reset_index(drop=True)
# Out:
#                         Columnas  Porcentajes_vacios
# 0                  COLE_BILINGUE            7.881861
# 1        ESTU_DEDICACIONINTERNET            4.278401
# 2            FAMI_EDUCACIONMADRE            3.312937
# 3          ESTU_TIPOREMUNERACION            3.186179
# 4           FAMI_TIENECOMPUTADOR            2.743306
# 5         FAMI_TRABAJOLABORPADRE            2.695162
# 6                  COLE_CARACTER            2.656039
# 7   FAMI_TIENECONSOLAVIDEOJUEGOS            2.453612
# 8         FAMI_TRABAJOLABORMADRE            2.442013
# 9        FAMI_SITUACIONECONOMICA            2.395525
# 10            FAMI_PERSONASHOGAR            2.305312
# 11                FAMI_NUMLIBROS            2.233234
# 12             FAMI_CUARTOSHOGAR            2.181315
# 13            FAMI_TIENEINTERNET            2.166126
# 14           FAMI_EDUCACIONPADRE            2.101689
# 15       ESTU_HORASSEMANATRABAJA            1.729237
# 16          FAMI_ESTRATOVIVIENDA            1.706316
# 17  ESTU_DEDICACIONLECTURADIARIA            1.531781
# 18               ESTU_TIENEETNIA            0.345847
# 19             ESTU_DEPTO_RESIDE            0.105218
# 20             ESTU_MCPIO_RESIDE            0.105218
# 21                   PUNT_INGLES            0.035809
# 22                   ESTU_GENERO            0.000828
# 23          ESTU_FECHANACIMIENTO            0.000184
# 24              PUNT_MATEMATICAS            0.000000
# 25      PUNT_SOCIALES_CIUDADANAS            0.000000
# 26           COLE_AREA_UBICACION            0.000000
# 27              PUNT_C_NATURALES            0.000000
# 28          PUNT_LECTURA_CRITICA            0.000000
# 29         ESTU_PRIVADO_LIBERTAD            0.000000
# 30                  COLE_JORNADA            0.000000
# 31            ESTU_TIPODOCUMENTO            0.000000
# 32               COLE_NATURALEZA            0.000000
# 33                   COLE_GENERO            0.000000
# 34   COLE_NOMBRE_ESTABLECIMIENTO            0.000000
# 35             ESTU_NACIONALIDAD            0.000000
# 36              ESTU_PAIS_RESIDE            0.000000
# 37              ESTU_CONSECUTIVO            0.000000
# 38                       PERIODO            0.000000
# 39                   PUNT_GLOBAL            0.000000

# %%
# Cantidad, información y tipo de dato de las 82 columnas del dataframe columnas
Saber_11_acumulado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1086317 entries, 0 to 504871
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   ESTU_TIPODOCUMENTO            1086317 non-null  object
#  1   ESTU_NACIONALIDAD             1086317 non-null  object
#  2   ESTU_GENERO                   1086308 non-null  object
#  3   ESTU_FECHANACIMIENTO          1086315 non-null  object
#  4   PERIODO                       1086317 non-null  object
#  5   ESTU_CONSECUTIVO              1086317 non-null  object
#  6   ESTU_PAIS_RESIDE              1086317 non-null  object
#  7   ESTU_TIENEETNIA               1082560 non-null  object
#  8   ESTU_DEPTO_RESIDE             1085174 non-null  object
#  9   ESTU_MCPIO_RESIDE             1085174 non-null  object
#  10  FAMI_ESTRATOVIVIENDA          1067781 non-null  object
#  11  FAMI_PERSONASHOGAR            1061274 non-null  object
#  12  FAMI_CUARTOSHOGAR             1062621 non-null  object
#  13  FAMI_EDUCACIONPADRE           1063486 non-null  object
#  14  FAMI_EDUCACIONMADRE           1050328 non-null  object
#  15  FAMI_TRABAJOLABORPADRE        1057039 non-null  object
#  16  FAMI_TRABAJOLABORMADRE        1059789 non-null  object
#  17  FAMI_TIENEINTERNET            1062786 non-null  object
#  18  FAMI_TIENECOMPUTADOR          1056516 non-null  object
#  19  FAMI_TIENECONSOLAVIDEOJUEGOS  1059663 non-null  object
#  20  FAMI_NUMLIBROS                1062057 non-null  object
#  21  FAMI_SITUACIONECONOMICA       1060294 non-null  object
#  22  ESTU_DEDICACIONLECTURADIARIA  1069677 non-null  object
#  23  ESTU_DEDICACIONINTERNET       1039840 non-null  object
#  24  ESTU_HORASSEMANATRABAJA       1067532 non-null  object
#  25  ESTU_TIPOREMUNERACION         1051705 non-null  object
#  26  COLE_NOMBRE_ESTABLECIMIENTO   1086317 non-null  object
#  27  COLE_GENERO                   1086317 non-null  object
#  28  COLE_NATURALEZA               1086317 non-null  object
#  29  COLE_BILINGUE                 1000695 non-null  object
#  30  COLE_CARACTER                 1057464 non-null  object
#  31  COLE_AREA_UBICACION           1086317 non-null  object
#  32  COLE_JORNADA                  1086317 non-null  object
#  33  ESTU_PRIVADO_LIBERTAD         1086317 non-null  object
#  34  PUNT_LECTURA_CRITICA          1086317 non-null  object
#  35  PUNT_MATEMATICAS              1086317 non-null  object
#  36  PUNT_C_NATURALES              1086317 non-null  object
#  37  PUNT_SOCIALES_CIUDADANAS      1086317 non-null  object
#  38  PUNT_INGLES                   1085928 non-null  object
#  39  PUNT_GLOBAL                   1086317 non-null  object
# dtypes: object(40)
# memory usage: 339.8+ MB
