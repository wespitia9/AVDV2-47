# %% [markdown]
# # La Importancia de la Limpieza, Normalización y Estandarización en la Ciencia de Datos: Un Análisis Detallado

# %% [markdown]
# En el ámbito de la ciencia de datos, las técnicas de limpieza, normalización y estandarización no solo representan pasos esenciales en el preprocesamiento de datos, sino que también constituyen pilares fundamentales para la obtención de resultados precisos y confiables. Estas técnicas, a menudo subestimadas, son cruciales para garantizar la calidad e integridad de los datos, elementos que determinan en gran medida el éxito de cualquier análisis o modelo de aprendizaje automático.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `1. Mejora de la Calidad de los Datos:`
#
# - Limpieza de Datos: Eliminar valores faltantes, duplicados o anómalos mejora la calidad y fiabilidad de los datos, lo que reduce el riesgo de obtener resultados sesgados o incorrectos.
#
# - Normalización y Estandarización: Al escalar o transformar las características, facilitamos la interpretación de los datos y mejoramos la convergencia de los algoritmos, lo que resulta en modelos más precisos y robustos.
#
# `2. Facilita el Análisis Exploratorio:`
#
# - Al limpiar y preparar adecuadamente los datos, es más fácil realizar un análisis exploratorio que proporcione insights y entendimiento sobre los patrones, tendencias y relaciones en los datos.
#
# `3. Preparación para Modelos de Aprendizaje Automático:`
#
# - Normalización y Estandarización: Los algoritmos de aprendizaje automático, como la regresión logística o las máquinas de soporte vectorial, pueden ser sensibles a la escala de las características. Normalizar o estandarizar los datos ayuda a estos modelos a converger más rápido y a tener un mejor rendimiento.
#
# - Limpieza de Datos: Los modelos de aprendizaje automático pueden ser afectados negativamente por datos faltantes o anómalos. Por lo tanto, es crucial tratar estos problemas antes de entrenar un modelo.
#
# `4. Aumento de la Reproducibilidad y Fiabilidad:`
#
# - Al aplicar técnicas sistemáticas de limpieza y transformación, se aumenta la reproducibilidad de los análisis y se obtienen resultados más confiables y consistentes.
#
# `5. Reducción del Tiempo y Costo de Análisis:`
#
# - La limpieza y preparación adecuada de los datos reducen la necesidad de correcciones posteriores y ajustes en los modelos, lo que ahorra tiempo y recursos en el proceso de análisis de datos.
#
# `6. Mejora la Visualización y Comunicación de Resultados:`
#
# - Con datos limpios y bien preparados, las visualizaciones resultantes son más claras e interpretables, facilitando la comunicación de los resultados a stakeholders o audiencias no técnicas.
#
# En resumen, las técnicas de limpieza, normalización y estandarización son esenciales en la ciencia de datos porque aseguran la calidad, fiabilidad y interpretabilidad de los datos, preparándolos para análisis avanzados y modelos de aprendizaje automático. Al aplicar estas técnicas de manera adecuada, podemos obtener insights más precisos, modelos más robustos y resultados más confiables, impulsando así la toma de decisiones basada en datos en diversos campos y aplicaciones.

# %% [markdown]
# Recomendaciones y consejos para llevar a cabo una buena limpieza, estandarización y normalización de datos:
#
# `1. Entender el Contexto y los Datos:` Antes de comenzar, es crucial comprender el contexto y la naturaleza de los datos. Conocer el dominio del problema y las características de los datos te ayudará a tomar decisiones más informadas durante el proceso de limpieza y transformación.
#
# `2. Identificar y Tratar Datos Faltantes:` Detecta y decide cómo tratar los valores faltantes (eliminarlos, imputarlos, etc.) según el tipo de datos y el impacto en el análisis posterior.
#
# `3. Manejar Datos Anómalos o Erróneos:` Identifica y corrige los datos anómalos o erróneos que puedan afectar la calidad de los análisis. Utiliza técnicas como el filtrado estadístico o la corrección basada en reglas.
#
# `4. Estandarizar y Normalizar Características:` Aplica técnicas de estandarización y normalización para escalar las características y asegurar que todas tengan un rango similar, facilitando así la convergencia de los modelos y la interpretación de los datos.
#
# `5. Verificar la Distribución de Datos:` Realiza visualizaciones y estadísticas descriptivas para verificar la distribución de los datos antes y después de la limpieza y transformación. Esto te ayudará a asegurar que los datos se han procesado adecuadamente.
#
# `6. Utilizar Herramientas y Librerías Apropiadas:` Familiarízate con herramientas y librerías de Python como pandas, scikit-learn o NumPy que ofrecen funciones y métodos específicos para limpieza, estandarización y normalización de datos.
#
# `7. Documentar el Proceso de Limpieza y Transformación:` Documenta cada paso del proceso de limpieza y transformación, incluyendo decisiones tomadas, métodos aplicados y cambios realizados. Esto facilitará la reproducibilidad y comprensión del análisis.
#
# `8. Validar los Resultados con Métricas y Visualizaciones:` Utiliza métricas estadísticas y visualizaciones para validar los resultados obtenidos después de la limpieza y transformación. Compara las distribuciones, varianzas y otras características relevantes antes y después del procesamiento.
#
# `9. Considerar el Impacto en el Análisis Posterior:` Piensa en cómo las decisiones de limpieza, estandarización y normalización afectarán el análisis y los modelos posteriores. Asegúrate de que las transformaciones sean adecuadas para los algoritmos y técnicas de análisis que planeas utilizar.
#
# `10. Revisar y Actualizar Regularmente:` La limpieza y transformación de datos no es un proceso único. Revisa y actualiza regularmente los datos, especialmente si provienen de fuentes en constante cambio, para mantener su calidad y relevancia a lo largo del tiempo.

# %% [markdown]
# ## Preparación y configuración del entorno de trabajo

# %% [markdown]
# ### Conexión y consulta a la fuente de datos

# %%
# Importar librerias

import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
import warnings
import sqlite3

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_acumulado_saber_11 = pd.read_csv('C:/Users/espit/OneDrive/Documentos/Cymetria Bootcamps/AVDV2-47/Módulo_1-Refinamiento_de_técnicas_de_análisis_de_datos/acumulado_saber_11.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e:
    
    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:
    
    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# El dataset se cargó exitosamente.

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_acumulado_saber_11 = pd.DataFrame(df_acumulado_saber_11)

# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_acumulado_saber_11.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 1086317 filas y 40 columnas.

# %%
# La función sample, devuelve la cantidad aleatorias de filas/registros solicitada del dataframe
df_acumulado_saber_11.sample(15)
# Out:
#         ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 345497                  TI          COLOMBIA           M
# 494998                  TI          COLOMBIA           M
# 567522                  CC          COLOMBIA           M
# 646129                  TI          COLOMBIA           F
# 338850                  TI          COLOMBIA           F
# 56188                   CC          COLOMBIA           F
# 1013449                 TI          COLOMBIA           M
# 23829                   TI          COLOMBIA           F
# 923822                  TI          COLOMBIA           M
# 134866                  TI          COLOMBIA           M
# 320633                  TI          COLOMBIA           M
# 536220                  TI          COLOMBIA           M
# 802402                  CC          COLOMBIA           M
# 678694                  CC          COLOMBIA           M
# 556185                  TI          COLOMBIA           M
#
#             ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 345497    06/01/2003 12:00:00 AM    20194  SB11201940328739         COLOMBIA
# 494998    10/27/2002 12:00:00 AM    20194  SB11201940261415         COLOMBIA
# 567522   0002-08-06T00:00:00.000    20201  SB11202010049657         COLOMBIA
# 646129    06/11/2003 12:00:00 AM    20204  SB11202040008415         COLOMBIA
# 338850    03/23/2002 12:00:00 AM    20194  SB11201940269228         COLOMBIA
# 56188     07/17/1994 12:00:00 AM    20194  SB11201940179164         COLOMBIA
# 1013449   09/08/2003 12:00:00 AM    20204  SB11202040083606         COLOMBIA
# 23829     08/22/2002 12:00:00 AM    20194  SB11201940434241         COLOMBIA
# 923822    05/20/2004 12:00:00 AM    20204  SB11202040515876         COLOMBIA
# 134866    07/04/2003 12:00:00 AM    20194  SB11201940082677         COLOMBIA
# 320633    06/01/2001 12:00:00 AM    20194  SB11201940269556         COLOMBIA
# 536220    10/17/1999 12:00:00 AM    20194  SB11201940199461         COLOMBIA
# 802402    05/18/2001 12:00:00 AM    20204  SB11202040112574         COLOMBIA
# 678694    10/17/2001 12:00:00 AM    20204  SB11202040475072         COLOMBIA
# 556185    08/20/2002 12:00:00 AM    20194  SB11201940456120         COLOMBIA
#
#         ESTU_TIENEETNIA ESTU_DEPTO_RESIDE    ESTU_MCPIO_RESIDE  ...  \
# 345497               No          CASANARE                YOPAL  ...
# 494998               No              META        VILLAVICENCIO  ...
# 567522               No             VALLE                 CALI  ...
# 646129               No         ATLANTICO               GALAPA  ...
# 338850               No            BOYACA            RAMIRIQUÍ  ...
# 56188                No         ATLANTICO          SABANALARGA  ...
# 1013449              No            BOGOTÁ          BOGOTÁ D.C.  ...
# 23829                No             HUILA             LA PLATA  ...
# 923822               No           BOLIVAR  CARTAGENA DE INDIAS  ...
# 134866               No           QUINDIO           MONTENEGRO  ...
# 320633               No         ANTIOQUIA                BELLO  ...
# 536220               No         MAGDALENA          SANTA MARTA  ...
# 802402               No           BOLIVAR  CARTAGENA DE INDIAS  ...
# 678694               No            BOYACA              DUITAMA  ...
# 556185               No         MAGDALENA          SANTA MARTA  ...
#
#              COLE_CARACTER COLE_AREA_UBICACION COLE_JORNADA  \
# 345497           ACADÉMICO              URBANO       MAÑANA
# 494998   TÉCNICO/ACADÉMICO              URBANO        UNICA
# 567522           ACADÉMICO              URBANO       MAÑANA
# 646129           ACADÉMICO              URBANO       MAÑANA
# 338850             TÉCNICO               RURAL     COMPLETA
# 56188            ACADÉMICO              URBANO        NOCHE
# 1013449          ACADÉMICO              URBANO       MAÑANA
# 23829            ACADÉMICO               RURAL     COMPLETA
# 923822           ACADÉMICO              URBANO       MAÑANA
# 134866   TÉCNICO/ACADÉMICO              URBANO       MAÑANA
# 320633             TÉCNICO              URBANO       MAÑANA
# 536220           ACADÉMICO              URBANO        UNICA
# 802402   TÉCNICO/ACADÉMICO              URBANO       MAÑANA
# 678694   TÉCNICO/ACADÉMICO              URBANO        UNICA
# 556185   TÉCNICO/ACADÉMICO              URBANO       MAÑANA
#
#         ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 345497                      N                   63               65
# 494998                      N                   59               68
# 567522                      N                   43               49
# 646129                      N                   59               53
# 338850                      N                   53               48
# 56188                       N                   30               19
# 1013449                     N                   37               36
# 23829                       N                   51               34
# 923822                      N                   56               51
# 134866                      N                   60               58
# 320633                      N                   70               75
# 536220                      N                   47               60
# 802402                      N                   67               56
# 678694                      N                   69               57
# 556185                      N                   45               30
#
#         PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL
# 345497                66                       64        44.0         315
# 494998                58                       67        54.0         312
# 567522                51                       39        51.0         230
# 646129                58                       51        57.0         277
# 338850                44                       49        41.0         240
# 56188                 25                       33        32.0         136
# 1013449               45                       45        37.0         202
# 23829                 42                       34        41.0         202
# 923822                49                       50        38.0         252
# 134866                50                       56        64.0         283
# 320633                68                       57        61.0         335
# 536220                40                       34        33.0         222
# 802402                56                       59        52.0         295
# 678694                61                       62        44.0         304
# 556185                41                       32        45.0         188
#
# [15 rows x 40 columns]

# %%
df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].value_counts().head(20)
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             164459
# ANTIOQUIA          146584
# VALLE               88016
# CUNDINAMARCA        71566
# ATLANTICO           62113
# BOLIVAR             49838
# SANTANDER           49742
# CORDOBA             39570
# NARIÑO              33438
# TOLIMA              32349
# BOYACA              32197
# MAGDALENA           32086
# NORTE SANTANDER     30653
# CAUCA               28088
# HUILA               26409
# CESAR               26087
# META                24381
# SUCRE               21152
# CALDAS              20881
# RISARALDA           20395
# Name: count, dtype: int64

# %%
# La función columns, devuelve el nombre de las columnas del dataframe
df_acumulado_saber_11.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_MCPIO_RESIDE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO',
#        'COLE_NATURALEZA', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_AREA_UBICACION', 'COLE_JORNADA', 'ESTU_PRIVADO_LIBERTAD',
#        'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL'],
#       dtype='object')

# %% [markdown]
# # Análisis básico inicial del conjunto de datos

# %% [markdown]
# - Revisar la estructura del conjunto de datos para identificar columnas, tipos de datos y posibles problemas.
# - Identificar valores faltantes, valores atípicos y posibles inconsistencias en los datos.

# %%
# Obtener información general del conjunto de datos

df_acumulado_saber_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086317 entries, 0 to 1086316
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   ESTU_TIPODOCUMENTO            1086317 non-null  object
#  1   ESTU_NACIONALIDAD             1086317 non-null  object
#  2   ESTU_GENERO                   1086308 non-null  object
#  3   ESTU_FECHANACIMIENTO          1086315 non-null  object
#  4   PERIODO                       1086317 non-null  int64
#  5   ESTU_CONSECUTIVO              1086317 non-null  object
#  6   ESTU_PAIS_RESIDE              1086317 non-null  object
#  7   ESTU_TIENEETNIA               1082560 non-null  object
#  8   ESTU_DEPTO_RESIDE             1085174 non-null  object
#  9   ESTU_MCPIO_RESIDE             1085174 non-null  object
#  10  FAMI_ESTRATOVIVIENDA          1067781 non-null  object
#  11  FAMI_PERSONASHOGAR            1061274 non-null  object
#  12  FAMI_CUARTOSHOGAR             1062621 non-null  object
#  13  FAMI_EDUCACIONPADRE           1063486 non-null  object
#  14  FAMI_EDUCACIONMADRE           1050328 non-null  object
#  15  FAMI_TRABAJOLABORPADRE        1057039 non-null  object
#  16  FAMI_TRABAJOLABORMADRE        1059789 non-null  object
#  17  FAMI_TIENEINTERNET            1062786 non-null  object
#  18  FAMI_TIENECOMPUTADOR          1056516 non-null  object
#  19  FAMI_TIENECONSOLAVIDEOJUEGOS  1059663 non-null  object
#  20  FAMI_NUMLIBROS                1062057 non-null  object
#  21  FAMI_SITUACIONECONOMICA       1060294 non-null  object
#  22  ESTU_DEDICACIONLECTURADIARIA  1069677 non-null  object
#  23  ESTU_DEDICACIONINTERNET       1039840 non-null  object
#  24  ESTU_HORASSEMANATRABAJA       1067532 non-null  object
#  25  ESTU_TIPOREMUNERACION         1051705 non-null  object
#  26  COLE_NOMBRE_ESTABLECIMIENTO   1086317 non-null  object
#  27  COLE_GENERO                   1086317 non-null  object
#  28  COLE_NATURALEZA               1086317 non-null  object
#  29  COLE_BILINGUE                 1000695 non-null  object
#  30  COLE_CARACTER                 1057464 non-null  object
#  31  COLE_AREA_UBICACION           1086317 non-null  object
#  32  COLE_JORNADA                  1086317 non-null  object
#  33  ESTU_PRIVADO_LIBERTAD         1086317 non-null  object
#  34  PUNT_LECTURA_CRITICA          1086317 non-null  int64
#  35  PUNT_MATEMATICAS              1086317 non-null  int64
#  36  PUNT_C_NATURALES              1086317 non-null  int64
#  37  PUNT_SOCIALES_CIUDADANAS      1086317 non-null  int64
#  38  PUNT_INGLES                   1085928 non-null  float64
#  39  PUNT_GLOBAL                   1086317 non-null  int64
# dtypes: float64(1), int64(6), object(33)
# memory usage: 331.5+ MB

# %%
# Descripción estadística de las variables numéricas
df_acumulado_saber_11.describe()
# Out:
#             PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count  1.086317e+06          1.086317e+06      1.086317e+06      1.086317e+06
# mean   2.019851e+04          5.238752e+01      5.102646e+01      4.848017e+01
# std    5.469084e+00          1.047043e+01      1.198036e+01      1.081123e+01
# min    2.018100e+04          0.000000e+00      0.000000e+00      0.000000e+00
# 25%    2.019400e+04          4.500000e+01      4.200000e+01      4.000000e+01
# 50%    2.019400e+04          5.300000e+01      5.100000e+01      4.800000e+01
# 75%    2.020400e+04          6.000000e+01      5.900000e+01      5.600000e+01
# max    2.020400e+04          1.000000e+02      1.000000e+02      1.000000e+02
#
#        PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count              1.086317e+06  1.085928e+06  1.086317e+06
# mean               4.746889e+01  4.817472e+01  2.485626e+02
# std                1.224824e+01  1.254123e+01  5.107014e+01
# min                0.000000e+00  0.000000e+00  0.000000e+00
# 25%                3.800000e+01  3.900000e+01  2.100000e+02
# 50%                4.700000e+01  4.600000e+01  2.450000e+02
# 75%                5.600000e+01  5.500000e+01  2.840000e+02
# max                1.000000e+02  1.000000e+02  5.000000e+02

# %%
# Descripción estadística de las variables numéricas sin notación científica

# Se configura la forma en que los números flotantes se muestran al imprimir un DataFrame en pandas.
    # Se define función lambda que toma un número x y devuelve ese número formateado con 1 decimal.
pd.set_option('display.float_format', lambda x: '%.1f' % x)

df_acumulado_saber_11.describe()
# Out:
#         PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count 1086317.0             1086317.0         1086317.0         1086317.0
# mean    20198.5                  52.4              51.0              48.5
# std         5.5                  10.5              12.0              10.8
# min     20181.0                   0.0               0.0               0.0
# 25%     20194.0                  45.0              42.0              40.0
# 50%     20194.0                  53.0              51.0              48.0
# 75%     20204.0                  60.0              59.0              56.0
# max     20204.0                 100.0             100.0             100.0
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count                 1086317.0    1085928.0    1086317.0
# mean                       47.5         48.2        248.6
# std                        12.2         12.5         51.1
# min                         0.0          0.0          0.0
# 25%                        38.0         39.0        210.0
# 50%                        47.0         46.0        245.0
# 75%                        56.0         55.0        284.0
# max                       100.0        100.0        500.0

# %% [markdown]
# Observaciones:
#
# `Periodo:`
# - La mayoría de los datos parecen concentrarse en el año 2019 y 2020, ya que los cuartiles y la media están más cerca de estos años.
#
# `Puntuaciones:`
# - Las puntuaciones mínimas para todas las asignaturas son 0, lo que indica que hay estudiantes que obtuvieron la puntuación más baja posible en estas materias.
# - Las medias para todas las puntuaciones de las asignaturas están en un rango similar, alrededor de 45-52, lo que sugiere que los estudiantes, en promedio, tienen un rendimiento medio en estas asignaturas.
# - Las desviaciones estándar son relativamente altas para todas las puntuaciones, lo que indica que hay una variabilidad significativa en las puntuaciones de los estudiantes.
# - Las puntuaciones máximas para todas las materias son 100, lo que sugiere que hay estudiantes que obtuvieron la puntuación máxima posible.
# - Las puntuaciones se encuentran en un rango de 0 a 500 para PUNT_GLOBAL, lo cual es un rango más amplio en comparación con las puntuaciones individuales de las asignaturas. Esto podría indicar que PUNT_GLOBAL es una combinación ponderada de las puntuaciones individuales o posiblemente incluye otros componentes no especificados en el conjunto de datos.
#
# - Existen variabilidades significativas en las puntuaciones de los estudiantes, con algunos obteniendo puntuaciones muy bajas y otros muy altas. Esto podría indicar diferencias en la preparación, el esfuerzo o la capacidad de los estudiantes.
#
# - Sería importante investigar más sobre la columna PUNT_GLOBAL para entender cómo se calcula y qué componentes incluye, ya que tiene un rango más amplio que las puntuaciones individuales de las materias.

# %%
# Descripción de las variables categóricas

df_acumulado_saber_11.describe(include=['object'])
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# count             1086317           1086317     1086308
# unique                 13                57           3
# top                    TI          COLOMBIA           F
# freq               886061           1081623      589970
#
#           ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# count                  1086315           1086317          1086317
# unique                   20993           1086317               57
# top     01/01/1900 12:00:00 AM  SB11201810007354         COLOMBIA
# freq                      1839                 1          1081623
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# count          1082560           1085174           1085174
# unique               3                36              1034
# top                 No            BOGOTÁ       BOGOTÁ D.C.
# freq           1010036            164459            169862
#
#        FAMI_ESTRATOVIVIENDA  ... ESTU_HORASSEMANATRABAJA  \
# count               1067781  ...                 1067532
# unique                    8  ...                       6
# top               Estrato 2  ...                       0
# freq                 376285  ...                  672318
#
#        ESTU_TIPOREMUNERACION                     COLE_NOMBRE_ESTABLECIMIENTO  \
# count                1051705                                         1086317
# unique                     5                                           10313
# top                       No  INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS
# freq                  726749                                            2057
#
#        COLE_GENERO COLE_NATURALEZA COLE_BILINGUE COLE_CARACTER  \
# count      1086317         1086317       1000695       1057464
# unique           3               2             3             5
# top          MIXTO         OFICIAL             N     ACADÉMICO
# freq       1049017          808491        892455        570630
#
#        COLE_AREA_UBICACION COLE_JORNADA ESTU_PRIVADO_LIBERTAD
# count              1086317      1086317               1086317
# unique                   2            6                     2
# top                 URBANO       MAÑANA                     N
# freq                913555       468577               1086029
#
# [4 rows x 33 columns]

# %%
# Identificar valores únicos por columna
print("\nValores únicos por columna:")
for column in df_acumulado_saber_11.columns:
    unique_values = df_acumulado_saber_11[column].unique()
    print(f"\n{column} ({len(unique_values)} valores únicos):\n{unique_values[:10]}")
    if len(unique_values) > 10:
        print("...")
# Out:
# Valores únicos por columna:
#
# ESTU_TIPODOCUMENTO (13 valores únicos):
# ['CC' 'TI' 'CR' 'CE' 'PE' 'PC' 'RC' 'PEP' 'NES' 'CCB']
# ...
#
# ESTU_NACIONALIDAD (57 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_GENERO (4 valores únicos):
# ['F' 'M' '-' nan]
#
# ESTU_FECHANACIMIENTO (20994 valores únicos):
# ['29/09/1999' '19/03/2001' '31/07/2000' '20/01/2002' '23/10/2001'
#  '20/04/2001' '05/04/2000' '05/11/2001' '03/11/2000' '23/09/1999']
# ...
#
# PERIODO (4 valores únicos):
# [20181 20194 20201 20204]
#
# ESTU_CONSECUTIVO (1086317 valores únicos):
# ['SB11201810007354' 'SB11201810018765' 'SB11201810028523'
#  'SB11201810003574' 'SB11201810024346' 'SB11201810006862'
#  'SB11201810017023' 'SB11201810048390' 'SB11201810010098'
#  'SB11201810012063']
# ...
#
# ESTU_PAIS_RESIDE (57 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_TIENEETNIA (4 valores únicos):
# ['No' 'Si' '-' nan]
#
# ESTU_DEPTO_RESIDE (37 valores únicos):
# ['BOGOTA' 'VALLE' 'ATLANTICO' 'CUNDINAMARCA' 'ANTIOQUIA' 'RISARALDA'
#  'CAUCA' 'BOLIVAR' 'CAQUETA' 'NORTE SANTANDER']
# ...
#
# ESTU_MCPIO_RESIDE (1035 valores únicos):
# ['BOGOTÁ D.C.' 'CALI' 'YUMBO' 'SOLEDAD' 'CHÍA' 'ENVIGADO' 'PALMIRA'
#  'BARRANQUILLA' 'EL CERRITO' 'PEREIRA']
# ...
#
# FAMI_ESTRATOVIVIENDA (9 valores únicos):
# ['Estrato 6' 'Estrato 5' 'Estrato 1' 'Estrato 3' 'Estrato 2' 'Sin Estrato'
#  'Estrato 4' '-' nan]
#
# FAMI_PERSONASHOGAR (8 valores únicos):
# ['3 a 4' '1 a 2' '5 a 6' 'Sin Respuesta' '9 o más' '7 a 8' '-' nan]
#
# FAMI_CUARTOSHOGAR (9 valores únicos):
# ['Tres' 'Dos' 'Sin respuesta' 'Cinco' 'Seis o mas' 'Cuatro' 'Uno' nan '-']
#
# FAMI_EDUCACIONPADRE (15 valores únicos):
# ['Educación profesional completa' 'Postgrado'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica incompleta'
#  'Sin respuesta' 'Primaria incompleta'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Primaria completa' 'No sabe']
# ...
#
# FAMI_EDUCACIONMADRE (15 valores únicos):
# ['Educación profesional completa' 'Secundaria (Bachillerato) completa'
#  'Postgrado' 'Técnica o tecnológica incompleta' 'Sin respuesta'
#  'Primaria incompleta' 'Secundaria (Bachillerato) incompleta'
#  'Técnica o tecnológica completa' 'Primaria completa' 'No sabe']
# ...
#
# FAMI_TRABAJOLABORPADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja por cuenta propia (por ejemplo plomero, electricista)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Sin respuesta'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'No aplica' 'Pensionado']
# ...
#
# FAMI_TRABAJOLABORMADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es vendedor o trabaja en atención al público' 'Sin respuesta'
#  'Es agricultor, pesquero o jornalero'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción']
# ...
#
# FAMI_TIENEINTERNET (5 valores únicos):
# ['Si' 'No' 'Sin respuesta' '-' nan]
#
# FAMI_TIENECOMPUTADOR (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_TIENECONSOLAVIDEOJUEGOS (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_NUMLIBROS (6 valores únicos):
# ['MÁS DE 100 LIBROS' '26 A 100 LIBROS' '0 A 10 LIBROS' '11 A 25 LIBROS'
#  '-' nan]
#
# FAMI_SITUACIONECONOMICA (5 valores únicos):
# ['Igual' 'Mejor' 'Peor' '-' nan]
#
# ESTU_DEDICACIONLECTURADIARIA (7 valores únicos):
# ['Entre 1 y 2 horas' 'No leo por entretenimiento' '30 minutos o menos'
#  'Entre 30 y 60 minutos' '-' 'Más de 2 horas' nan]
#
# ESTU_DEDICACIONINTERNET (7 valores únicos):
# ['Entre 1 y 3 horas' 'Entre 30 y 60 minutos' 'Más de 3 horas'
#  '30 minutos o menos' '-' 'No Navega Internet' nan]
#
# ESTU_HORASSEMANATRABAJA (7 valores únicos):
# ['0' 'Entre 11 y 20 horas' '-' 'Menos de 10 horas' 'Más de 30 horas'
#  'Entre 21 y 30 horas' nan]
#
# ESTU_TIPOREMUNERACION (6 valores únicos):
# ['No' 'Si, en efectivo' '-' 'Si, en especie' 'Si, en efectivo y especie'
#  nan]
#
# COLE_NOMBRE_ESTABLECIMIENTO (10313 valores únicos):
# ['GIMN VERMONT' 'COLEGIO PHILADELPHIA INTERNACIONAL'
#  'INST TECNOLG EMPRESARIAL COLOMBIANO' 'SANTA  MARIA STELLA MARIS'
#  'COLEGIO DE SAN LUIS GONZAGA' 'COL COMFANDI - YUMBO' 'COL COLOMBO GALES'
#  'LICEO MIXTO PARA ADULTOS JOSE PRUDENCIO PADILLA'
#  'NUEVO GIMNASIO CRISTIANO' 'CENTRO EDUCATIVO DE ADULTOS CEAM']
# ...
#
# COLE_GENERO (3 valores únicos):
# ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# COLE_NATURALEZA (2 valores únicos):
# ['NO OFICIAL' 'OFICIAL']
#
# COLE_BILINGUE (4 valores únicos):
# ['S' 'N' '-' nan]
#
# COLE_CARACTER (6 valores únicos):
# ['ACADÉMICO' 'NO APLICA' 'TÉCNICO/ACADÉMICO' 'TÉCNICO' '-' nan]
#
# COLE_AREA_UBICACION (2 valores únicos):
# ['URBANO' 'RURAL']
#
# COLE_JORNADA (6 valores únicos):
# ['COMPLETA' 'SABATINA' 'MAÑANA' 'NOCHE' 'TARDE' 'UNICA']
#
# ESTU_PRIVADO_LIBERTAD (2 valores únicos):
# ['N' 'S']
#
# PUNT_LECTURA_CRITICA (67 valores únicos):
# [71 75 42 61 69 49 35 73 43 62]
# ...
#
# PUNT_MATEMATICAS (74 valores únicos):
# [65 77 27 62 75 61 52 49 53 46]
# ...
#
# PUNT_C_NATURALES (66 valores únicos):
# [ 69 100  29  72  67  50  45  61  38  65]
# ...
#
# PUNT_SOCIALES_CIUDADANAS (72 valores únicos):
# [63 81 36 70 65 55 73 41 78 37]
# ...
#
# PUNT_INGLES (75 valores únicos):
# [90. 86. 29. 79. 71. 58. 76. 46. 83. 45.]
# ...
#
# PUNT_GLOBAL (445 valores únicos):
# [344 417 166 336 346 270 214 338 207 226]
# ...

# %%
numeric_cols = df_acumulado_saber_11.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df_acumulado_saber_11, x=col)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
# Análisis de valores faltantes por columna
datos_faltantes = df_acumulado_saber_11.isnull().sum()
porcentajes_faltantes = (df_acumulado_saber_11.isnull().sum() / len(df_acumulado_saber_11)) * 100

faltantes_df = pd.DataFrame({
    'Valores faltantes': datos_faltantes,
    'Porcentaje (%)': porcentajes_faltantes
})

# Ordenar de manera descendente por porcentaje de valores faltantes
faltantes_df = faltantes_df.sort_values(by='Porcentaje (%)', ascending=False)

faltantes_df
# Out:
#                               Valores faltantes  Porcentaje (%)
# COLE_BILINGUE                             85622             7.9
# ESTU_DEDICACIONINTERNET                   46477             4.3
# FAMI_EDUCACIONMADRE                       35989             3.3
# ESTU_TIPOREMUNERACION                     34612             3.2
# FAMI_TIENECOMPUTADOR                      29801             2.7
# FAMI_TRABAJOLABORPADRE                    29278             2.7
# COLE_CARACTER                             28853             2.7
# FAMI_TIENECONSOLAVIDEOJUEGOS              26654             2.5
# FAMI_TRABAJOLABORMADRE                    26528             2.4
# FAMI_SITUACIONECONOMICA                   26023             2.4
# FAMI_PERSONASHOGAR                        25043             2.3
# FAMI_NUMLIBROS                            24260             2.2
# FAMI_CUARTOSHOGAR                         23696             2.2
# FAMI_TIENEINTERNET                        23531             2.2
# FAMI_EDUCACIONPADRE                       22831             2.1
# ESTU_HORASSEMANATRABAJA                   18785             1.7
# FAMI_ESTRATOVIVIENDA                      18536             1.7
# ESTU_DEDICACIONLECTURADIARIA              16640             1.5
# ESTU_TIENEETNIA                            3757             0.3
# ESTU_DEPTO_RESIDE                          1143             0.1
# ESTU_MCPIO_RESIDE                          1143             0.1
# PUNT_INGLES                                 389             0.0
# ESTU_GENERO                                   9             0.0
# ESTU_FECHANACIMIENTO                          2             0.0
# PUNT_MATEMATICAS                              0             0.0
# PUNT_SOCIALES_CIUDADANAS                      0             0.0
# COLE_AREA_UBICACION                           0             0.0
# PUNT_C_NATURALES                              0             0.0
# PUNT_LECTURA_CRITICA                          0             0.0
# ESTU_PRIVADO_LIBERTAD                         0             0.0
# COLE_JORNADA                                  0             0.0
# ESTU_TIPODOCUMENTO                            0             0.0
# COLE_NATURALEZA                               0             0.0
# COLE_GENERO                                   0             0.0
# COLE_NOMBRE_ESTABLECIMIENTO                   0             0.0
# ESTU_NACIONALIDAD                             0             0.0
# ESTU_PAIS_RESIDE                              0             0.0
# ESTU_CONSECUTIVO                              0             0.0
# PERIODO                                       0             0.0
# PUNT_GLOBAL                                   0             0.0

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# - Identificar columnas con valores faltantes y decidir cómo manejarlos (eliminar, imputar, etc.).

# %% [markdown]
# ### Columna ESTU_TIPODOCUMENTO

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_TIPODOCUMENTO'
df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].value_counts()
# Out:
# ESTU_TIPODOCUMENTO
# TI      886061
# CC      183034
# CR       11470
# CE        2527
# NES       2288
# PEP        680
# PE         200
# RC          33
# PC          15
# CCB          4
# V            2
# NUIP         2
# NIP          1
# Name: count, dtype: int64

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_TIPODOCUMENTO'
tipo_documento_counts = df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(12, 4))
ax = tipo_documento_counts.plot(kind='bar', color='blue')

# Añadir la cantidad en cada barra
for i, v in enumerate(tipo_documento_counts):
    ax.text(i, v + 1000, str(v), ha='center', va='bottom', fontsize=10)

# Títulos y etiquetas
plt.title('Frecuencia de Tipos de Documento')
plt.xlabel('Tipo de Documento')
plt.ylabel('Frecuencia')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Columna ESTU_NACIONALIDAD

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df_acumulado_saber_11['ESTU_NACIONALIDAD'].value_counts()
# Out:
# ESTU_NACIONALIDAD
# COLOMBIA                           1081623
# VENEZUELA                             4108
# ESTADOS UNIDOS                         149
# ESPAÑA                                  92
# ECUADOR                                 79
# ARGENTINA                               21
# BRASIL                                  20
# MÉXICO                                  20
# PERÚ                                    17
# CUBA                                    16
# CHILE                                   14
# COSTA RICA                              13
# ITALIA                                  11
# PANAMÁ                                   9
# FRANCIA                                  9
# ALEMANIA                                 9
# BOLIVIA                                  8
# VANUATU                                  8
# REPÚBLICA DOMINICANA                     7
# EL SALVADOR                              7
# HONDURAS                                 6
# NICARAGUA                                5
# PAÍSES BAJOS - HOLANDA                   5
# GUATEMALA                                5
# URUGUAY                                  4
# COREA DEL NORTE                          4
# CHINA                                    4
# JAPÓN                                    3
# COREA DEL SUR                            3
# COMORAS                                  3
# HAITI                                    2
# CURAZAO                                  2
# CABO VERDE                               2
# ARUBA                                    2
# REINO UNIDO                              2
# PORTUGAL                                 2
# SUIZA                                    2
# CANADÁ                                   2
# DINAMARCA                                1
# VIETNAM                                  1
# TURQUÍA                                  1
# PARAGUAY                                 1
# LITUANIA                                 1
# IRÁN                                     1
# EGIPTO                                   1
# RUSIA                                    1
# ARABIA SAUDITA                           1
# ESTADOS FEDERADOS DE MICRONESIA          1
# TERRITORIOS PALESTINOS                   1
# WALLIS Y FUTUNA                          1
# BÉLGICA                                  1
# AUSTRIA                                  1
# CROACIA                                  1
# ALBANIA                                  1
# TAIWAN                                   1
# AFGANISTÁN                               1
# OMÁN                                     1
# Name: count, dtype: int64

# %% [markdown]
# Se puede observar que hay registros con caracteres especiales (tildes) en el nombre. Reto a realizar:
#
# - Elimina (unicamente) las tiles de los registros

# %% [markdown]
# ### Columna ESTU_GENERO

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df_acumulado_saber_11['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# F    589970
# M    496216
# -       122
# Name: count, dtype: int64

# %% [markdown]
# - Los valores etiquetamos como "-", representan un 0.001% del total de registros, estos están representados con el caracter "-".
#
# - Se procederá a reemplazar en el DataFrame original ese caracter con la etiqueta de "No registrado".

# %%
# reemplazar valores "-"
df_acumulado_saber_11['ESTU_GENERO'] = df_acumulado_saber_11['ESTU_GENERO'].replace('-', 'No_informa')

# contar registros de la columna 'ESTU_GENERO'
df_acumulado_saber_11['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# F             589970
# M             496216
# No_informa       122
# Name: count, dtype: int64

# %%
# Cantidad de registros por el tipo de genero

# generar conteo de registros por valor único en la columna ESTU_GENERO
df_genero = df_acumulado_saber_11['ESTU_GENERO'].value_counts()

# establecer etiquetas y colores
etiquetas = ['F', 'M', 'No informado']
colores = ['#FFC0CB', '#6495ED', '#C0C0C0']

# crear gráfico de torta
plt.pie(df_genero, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90)

# agregar leyenda
plt.legend(title='Género', loc='center left', bbox_to_anchor=(1.0, 0.5))

# mostrar gráfico
plt.show()

# imprimir resultados
print(df_genero)
# Out:
# ESTU_GENERO
# F             589970
# M             496216
# No_informa       122
# Name: count, dtype: int64

# %% [markdown]
# ### Columna ESTU_FECHANACIMIENTO

# %%
# contar registros de la columna 'ESTU_GENERO'
df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ESTU_FECHANACIMIENTO
# 01/01/1900 12:00:00 AM     1839
# 03/03/2003 12:00:00 AM     1297
# 01/03/2003 12:00:00 AM     1273
# 09/13/2002 12:00:00 AM     1259
# 09/17/2002 12:00:00 AM     1240
#                            ...
# 0002-04-20T00:00:00.000       1
# 06/03/1986 12:00:00 AM        1
# 0004-05-20T00:00:00.000       1
# 0002-06-20T00:00:00.000       1
# 01/19/1971 12:00:00 AM        1
# Name: count, Length: 20993, dtype: int64

# %% [markdown]
# Al dar un vistazo a la columna 'ESTU_FECHANACIMIENTO' es evidente notar que hay un detalle muy especifico de la fecha de nacimiento de los estudiantes. Se puede ver que los valores están en formato de fecha y hora, para esta columna inicialmente transformaremos a tipo DATE ya que solo capturaremos el año de nacimiento.
#
# Anexo a eso, es evidente también la deformación en fechas de nacimiento, ejemplo:
#
# - 0002-04-20T00:00:00.000
# - 0004-05-20T00:00:00.000
# - 0002-06-20T00:00:00.000
#
# `Reto: ¿Qué opciones/acciones propones para dichas fechas?`

# %%
# Es posible que lleguemos a evidenciar un error "OutOfBoundsDatetime: Out of bounds nanosecond timestamp" cuano ejecutemos el cambio de tipo de dato, indica que en la columna
# de fechas se encuentran valores que no se pueden representar correctamente como objetos de fecha y hora de pandas.

# Para solucionar ese error, debemos identificar los valores problemáticos y limpiarlos antes de convertir la columna al formato de fecha y hora de pandas.
# Una forma de hacerlo es mediante la función "to_datetime()" de pandas, pasando el argumento "errors='coerce'". De esta forma, cualquier valor que no pueda convertirse
# correctamente será reemplazado por "NaT" (valores faltantes en pandas).

# limpiar valores problemáticos
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\r', '')
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\n', '')

# convertir columna 'ESTU_FECHANACIMIENTO' al formato de fecha y hora de pandas
df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df_acumulado_saber_11['ESTU_FECHANACIMIENTO'], errors='coerce')

# obtener solo el año de nacimiento
df_acumulado_saber_11['ANIO_NACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].dt.year

# Si deseamos, tenemos la opción de eliminar o no columnas innecesarias, en este caso la columna 'ESTU_FECHANACIMIENTO' será reemplazada por 'ANIO_NACIMIENTO'
df_acumulado_saber_11 = df_acumulado_saber_11.drop('ESTU_FECHANACIMIENTO', axis=1)

# mostrar resultados
df_acumulado_saber_11.head(3)
# Out:
# C:\Users\espit\AppData\Local\Temp\ipykernel_9988\3606972664.py:13: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df_acumulado_saber_11['ESTU_FECHANACIMIENTO'], errors='coerce')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  ESTU_CONSECUTIVO  \
# 0                 CC          COLOMBIA           F    20181  SB11201810007354
# 1                 TI          COLOMBIA           M    20181  SB11201810018765
# 2                 TI          COLOMBIA           M    20181  SB11201810028523
#
#   ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 0         COLOMBIA              No            BOGOTA       BOGOTÁ D.C.
# 1         COLOMBIA              No             VALLE              CALI
# 2         COLOMBIA              No             VALLE              CALI
#
#   FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION COLE_JORNADA  \
# 0            Estrato 6  ...              URBANO     COMPLETA
# 1            Estrato 5  ...              URBANO     COMPLETA
# 2            Estrato 1  ...               RURAL     SABATINA
#
#   ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 0                     N                   71               65
# 1                     N                   75               77
# 2                     N                   42               27
#
#   PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL  \
# 0               69                       63        90.0         344
# 1              100                       81        86.0         417
# 2               29                       36        29.0         166
#
#   ANIO_NACIMIENTO
# 0          1999.0
# 1          2001.0
# 2          2000.0
#
# [3 rows x 40 columns]

# %% [markdown]
# Podemos observar algunos registros que son Outliers (valores atipicos):
#
# La edad promedio de presentación del examen ICFES es entre los 14 y 20 años, por ende los nacidos entre los años 2009 y 2020, o son datos erroneos o mal diligenciados.
#
# Sin embargo, hay una excepción, ocurrio en el año 2012. Uno de los registros de estudiantes con menor edad en presentar el examen ICFES pertenece a [Juan Sebastián Andrés Pérez Riaño](https://www.elcolombiano.com/colombia/nino-de-doce-anos-presento-el-icfes-y-se-va-a-graduar-GE18585650), un niño de 12 años que estudio en Yopal, Casanare. Esto fue en 2022, con base a este, y generando una hipótesis (que luego deberá ser validada o descartada), se limpiaran datos de los nacidos de 2008 hacía adelante, es decir, los nacidos entre 2009 y 2020, serán registros a eliminar.

# %%
# contar registros de la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ANIO_NACIMIENTO
# 2000.0    6865
# 2001.0    5639
# 1999.0    3448
# 1998.0     914
# 2002.0     864
#           ...
# 1955.0       2
# 1942.0       1
# 1949.0       1
# 1944.0       1
# 1953.0       1
# Name: count, Length: 62, dtype: int64

# %%
# contar registros por año de nacimiento
conteo_por_anio = df_acumulado_saber_11['ANIO_NACIMIENTO'].value_counts()

# filtrar años de interés, iniciaremos por los nacidos entre 1999 y 2019
filtro = (conteo_por_anio.index >= 2009) & (conteo_por_anio.index <= 2020)
conteo_por_anio_filtrado = conteo_por_anio.loc[filtro]

# mostrar resultados
print(conteo_por_anio_filtrado)
plt.show()

print("Entre los años 2009 y 2020, hay un total de:", conteo_por_anio_filtrado.sum())
# Out:
# ANIO_NACIMIENTO
# 2017.0    21
# 2009.0     7
# 2011.0     4
# 2010.0     4
# 2012.0     2
# Name: count, dtype: int64
# Entre los años 2009 y 2020, hay un total de: 38

# %%
# Identificar los índices de los registros a eliminar
indices_eliminar = df_acumulado_saber_11[(df_acumulado_saber_11['ANIO_NACIMIENTO'] >= 2009) & (df_acumulado_saber_11['ANIO_NACIMIENTO'] <= 2020)].index

# Eliminar los registros
df_resultados = df_acumulado_saber_11.drop(indices_eliminar)

print("Se eliminaron:", conteo_por_anio_filtrado.sum(),'registros que pertencen a los outliers de nacidos entre 2009 y 2020, es decir, edades entre 11 y 0 años')
# Out:
# Se eliminaron: 38 registros que pertencen a los outliers de nacidos entre 2009 y 2020, es decir, edades entre 11 y 0 años

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 1066521

# %%
# Calcular el número de registros con valores vacíos en ANIO_NACIMIENTO por grupo
vacios_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.isna().sum())

# Ordenar de mayor a menor
vacios_por_grupo_sorted = vacios_por_grupo.sort_values(ascending=False)

# Imprimir cantidad de valores vacíos ordenados de mayor a menor
for grupo in vacios_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores vacíos: {vacios_por_grupo_sorted.loc[grupo]}")
    print('------------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores vacíos: 871802
# ------------------------------------
# Grupo: CC
# Cantidad de valores vacíos: 178022
# ------------------------------------
# Grupo: CR
# Cantidad de valores vacíos: 11108
# ------------------------------------
# Grupo: CE
# Cantidad de valores vacíos: 2402
# ------------------------------------
# Grupo: NES
# Cantidad de valores vacíos: 2288
# ------------------------------------
# Grupo: PEP
# Cantidad de valores vacíos: 680
# ------------------------------------
# Grupo: PE
# Cantidad de valores vacíos: 168
# ------------------------------------
# Grupo: RC
# Cantidad de valores vacíos: 32
# ------------------------------------
# Grupo: PC
# Cantidad de valores vacíos: 10
# ------------------------------------
# Grupo: CCB
# Cantidad de valores vacíos: 4
# ------------------------------------
# Grupo: NUIP
# Cantidad de valores vacíos: 2
# ------------------------------------
# Grupo: V
# Cantidad de valores vacíos: 2
# ------------------------------------
# Grupo: NIP
# Cantidad de valores vacíos: 1
# ------------------------------------

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df_acumulado_saber_11['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentaje sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('------------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 14259
# Porcentaje sobre el total de valores no nulos: 72.03%
# ------------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 5012
# Porcentaje sobre el total de valores no nulos: 25.32%
# ------------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentaje sobre el total de valores no nulos: 1.83%
# ------------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentaje sobre el total de valores no nulos: 0.63%
# ------------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentaje sobre el total de valores no nulos: 0.16%
# ------------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentaje sobre el total de valores no nulos: 0.03%
# ------------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentaje sobre el total de valores no nulos: 0.01%
# ------------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NIP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NUIP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: V
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------

# %% [markdown]
# Es fundamental distribuir adecuadamente los valores nulos o vacíos en la columna 'ANIO_NACIMIENTO' según el tipo de documento 'ESTU_TIPODOCUMENTO'. Podemos basarnos en la distribución de porcentajes de los valores no nulos como muestra. Por ejemplo, el tipo de documento 'TI' representa el 72.03% de los registros no nulos, mientras que 'CC' representa el 25.32%.
#
# Esto implica que de los 871,802 registros con tipo de documento 'TI', deberíamos asignarlos en los años 2003, 2004, 2005, 2006, 2007 y 2008. La asignación debería distribuirse de la siguiente manera:
#
# - El 50% de los registros se asignarán a los años 2003 y 2004.
# - El 30% de los registros se asignarán al año 2005.
# - El 20% restante se distribuirá entre los años 2006, 2007 y 2008.
# Esta distribución proporciona una manera equitativa y representativa de llenar los valores nulos basándose en la proporción de los registros no nulos para cada tipo de documento.

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'TI' y ANIO_NACIMIENTO es NaN
filtro_ti = (df_acumulado_saber_11['ESTU_TIPODOCUMENTO'] == 'TI') & (df_acumulado_saber_11['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registros_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
    2003: 0.5,
    2004: 0.5,
    2005: 0.3,
    2006: 0.2,
    2007: 0.2,
    2008: 0.2
}

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidades_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items()}

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidades_ajustadas.keys()), size=num_registros_ti, p=list(probabilidades_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución de años asignados para 'TI':")
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución de años asignados para 'TI':
# ANIO_NACIMIENTO
# 2004.0    229716
# 2003.0    229560
# 2005.0    137834
# 2008.0     91754
# 2007.0     91745
# 2006.0     91193
# Name: count, dtype: int64

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
filtro_ti = (df_acumulado_saber_11['ESTU_TIPODOCUMENTO'] == 'CC') & (df_acumulado_saber_11['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registros_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
    2002: 0.5,
    2001: 0.5,
    2000: 0.3,
    1999: 0.1,
    1998: 0.1,
    1997: 0.1,
    1996: 0.1,
    1995: 0.1,
    1994: 0.1
}

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidades_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items()}

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidades_ajustadas.keys()), size=num_registros_ti, p=list(probabilidades_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución éxitosa de años asignados para 'CC':")
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución éxitosa de años asignados para 'CC':
# ANIO_NACIMIENTO
# 2002.0    46859
# 2001.0    46601
# 2000.0    28133
# 1994.0     9496
# 1998.0     9484
# 1996.0     9463
# 1997.0     9361
# 1999.0     9333
# 1995.0     9292
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 16697

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df_acumulado_saber_11['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentaje sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('------------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 886061
# Porcentaje sobre el total de valores no nulos: 82.84%
# ------------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 183034
# Porcentaje sobre el total de valores no nulos: 17.11%
# ------------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentaje sobre el total de valores no nulos: 0.03%
# ------------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentaje sobre el total de valores no nulos: 0.01%
# ------------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NIP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: NUIP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------
# Grupo: V
# Cantidad de valores no nulos: 0
# Porcentaje sobre el total de valores no nulos: 0.00%
# ------------------------------------

# %% [markdown]
# Considerando que existen 16,697 registros sin una asignación de 'ANIO_NACIMIENTO' y teniendo en cuenta el comportamiento de los grupos por año:
#
# `Grupo TI:`
# - Cantidad: 886,061
# - Porcentaje: 82.84%
#
# `Grupo CC:`
# - Cantidad: 183,034
# - Porcentaje: 17.11%
#
# Se procede a asignar de manera aleatoria el 82.84% de los registros hacia las edades de menores de edad, distribuidas de la siguiente manera:
#
# Años y porcentajes para menores de edad:
# - 2003: 0.5
# - 2004: 0.5
# - 2005: 0.3
# - 2006: 0.2
#
# Para los mayores de edad, se asignará de manera aleatoria el 17.11% de los registros, distribuidos así:
#
# Años y porcentajes para mayores de edad:
# - 2002: 0.5
# - 2001: 0.5
# - 2000: 0.3
# - 1999: 0.1
# - 1998: 0.1
# - 1997: 0.1
# - 1996: 0.1

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
tipos_documento = ['V', 'PEP', 'NUIP', 'NIP', 'NES', 'CCB', 'RC', 'PC', 'PE', 'CE', 'CR']
filtro_ti = df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].isin(tipos_documento) & df_acumulado_saber_11['ANIO_NACIMIENTO'].isna()

# Número de registros a asignar
num_registros_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
    2006: 0.20,
    2005: 0.20,
    2004: 0.20,
    2003: 0.20,
    2002: 0.2,
    2001: 0.2,
    2000: 0.2,
    1999: 0.1,
    1998: 0.1,
    1997: 0.1,
    1996: 0.1,
    1995: 0.1,
    1994: 0.1
}

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidades_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items()}

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidades_ajustadas.keys()), size=num_registros_ti, p=list(probabilidades_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución éxitosa de años asignados para 'CC':")
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución éxitosa de años asignados para 'CC':
# ANIO_NACIMIENTO
# 2004.0    1708
# 2005.0    1698
# 2006.0    1687
# 2002.0    1663
# 2000.0    1657
# 2003.0    1647
# 2001.0    1642
# 1996.0     849
# 1997.0     839
# 1994.0     833
# 1998.0     828
# 1995.0     823
# 1999.0     823
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Podemos ver que no hay valores en cero en la columna 'ANIO_NACIMIENTO' con respecto a los valores NaN presentes.

# %%
df_acumulado_saber_11.sample(20)
# Out:
#         ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  \
# 1059734                 TI          COLOMBIA           M    20204
# 102074                  TI          COLOMBIA           F    20194
# 605419                  TI          COLOMBIA           M    20204
# 670665                  CC          COLOMBIA           F    20204
# 113921                  TI          COLOMBIA           M    20194
# 875680                  TI          COLOMBIA           F    20204
# 898140                  TI          COLOMBIA           M    20204
# 293110                  TI          COLOMBIA           M    20194
# 590610                  TI          COLOMBIA           M    20204
# 393194                  TI          COLOMBIA           F    20194
# 856380                  TI          COLOMBIA           M    20204
# 269636                  TI          COLOMBIA           M    20194
# 982407                  TI          COLOMBIA           F    20204
# 215860                  CC          COLOMBIA           M    20194
# 838647                  TI          COLOMBIA           F    20204
# 358576                  TI          COLOMBIA           F    20194
# 738789                  TI          COLOMBIA           F    20204
# 734358                  TI          COLOMBIA           M    20204
# 249432                  TI          COLOMBIA           M    20194
# 1038639                 TI          COLOMBIA           M    20204
#
#          ESTU_CONSECUTIVO ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 1059734  SB11202040029626         COLOMBIA              No            BOGOTÁ
# 102074   SB11201940132286         COLOMBIA              No              META
# 605419   SB11202040344653         COLOMBIA              No          CASANARE
# 670665   SB11202040535928         COLOMBIA              No            TOLIMA
# 113921   SB11201940145904         COLOMBIA              No         MAGDALENA
# 875680   SB11202040455084         COLOMBIA              No             VALLE
# 898140   SB11202040038118         COLOMBIA              No             VALLE
# 293110   SB11201940570074         COLOMBIA              No            BOGOTÁ
# 590610   SB11202040031305         COLOMBIA              No   NORTE SANTANDER
# 393194   SB11201940131264         COLOMBIA              No      CUNDINAMARCA
# 856380   SB11202040045385         COLOMBIA              No              META
# 269636   SB11201940154285         COLOMBIA              No            TOLIMA
# 982407   SB11202040030650         COLOMBIA              No            BOGOTÁ
# 215860   SB11201940421337         COLOMBIA              No         ANTIOQUIA
# 838647   SB11202040382953         COLOMBIA              No           BOLIVAR
# 358576   SB11201940364637         COLOMBIA              No            TOLIMA
# 738789   SB11202040350286         COLOMBIA              No         ANTIOQUIA
# 734358   SB11202040550894         COLOMBIA              Si             VALLE
# 249432   SB11201940251116         COLOMBIA              No              META
# 1038639  SB11202040221958         COLOMBIA              No           BOLIVAR
#
#            ESTU_MCPIO_RESIDE FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION  \
# 1059734          BOGOTÁ D.C.            Estrato 3  ...              URBANO
# 102074     CASTILLA LA NUEVA            Estrato 3  ...              URBANO
# 605419                  MANÍ            Estrato 1  ...              URBANO
# 670665                IBAGUÉ                  NaN  ...              URBANO
# 113921             SANTA ANA            Estrato 1  ...              URBANO
# 875680                  CALI            Estrato 2  ...              URBANO
# 898140                  CALI            Estrato 2  ...              URBANO
# 293110           BOGOTÁ D.C.            Estrato 3  ...              URBANO
# 590610                CÚCUTA                  NaN  ...              URBANO
# 393194               CHOACHÍ            Estrato 2  ...              URBANO
# 856380     CASTILLA LA NUEVA            Estrato 1  ...              URBANO
# 269636                IBAGUÉ            Estrato 2  ...              URBANO
# 982407           BOGOTÁ D.C.            Estrato 2  ...              URBANO
# 215860              MEDELLÍN            Estrato 2  ...               RURAL
# 838647   CARTAGENA DE INDIAS            Estrato 1  ...              URBANO
# 358576                IBAGUÉ            Estrato 2  ...              URBANO
# 738789               NECOCLÍ          Sin Estrato  ...               RURAL
# 734358                  CALI            Estrato 2  ...              URBANO
# 249432          VISTAHERMOSA            Estrato 1  ...              URBANO
# 1038639  CARTAGENA DE INDIAS            Estrato 2  ...              URBANO
#
#         COLE_JORNADA ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA  \
# 1059734        UNICA                     N                   61
# 102074         UNICA                     N                   51
# 605419         TARDE                     N                   48
# 670665         UNICA                     N                   53
# 113921        MAÑANA                     N                   46
# 875680        MAÑANA                     N                   51
# 898140        MAÑANA                     N                   45
# 293110      COMPLETA                     N                   60
# 590610         UNICA                     N                   52
# 393194         UNICA                     N                   44
# 856380         UNICA                     N                   54
# 269636        MAÑANA                     N                   45
# 982407         TARDE                     N                   47
# 215860         UNICA                     N                   48
# 838647        MAÑANA                     N                   52
# 358576         TARDE                     N                   71
# 738789      COMPLETA                     N                   53
# 734358         TARDE                     N                   43
# 249432         TARDE                     N                   33
# 1038639       MAÑANA                     N                   53
#
#         PUNT_MATEMATICAS PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS  \
# 1059734               65               63                       55
# 102074                44               34                       44
# 605419                51               52                       42
# 670665                52               36                       40
# 113921                37               44                       46
# 875680                43               40                       41
# 898140                38               48                       39
# 293110                57               60                       67
# 590610                26               47                       45
# 393194                47               49                       45
# 856380                63               59                       54
# 269636                47               38                       46
# 982407                57               49                       45
# 215860                51               42                       42
# 838647                33               51                       43
# 358576                68               65                       64
# 738789                53               49                       42
# 734358                42               31                       38
# 249432                49               40                       34
# 1038639               45               39                       31
#
#         PUNT_INGLES PUNT_GLOBAL ANIO_NACIMIENTO
# 1059734        66.0         307          2005.0
# 102074         43.0         216          2004.0
# 605419         35.0         236          2004.0
# 670665         35.0         222          2002.0
# 113921         53.0         220          2006.0
# 875680         50.0         221          2006.0
# 898140         40.0         212          2004.0
# 293110         70.0         308          2005.0
# 590610         43.0         213          2003.0
# 393194         50.0         233          2004.0
# 856380         53.0         286          2005.0
# 269636         51.0         223          2008.0
# 982407         47.0         247          2007.0
# 215860         45.0         228          2001.0
# 838647         46.0         224          2008.0
# 358576         65.0         334          2006.0
# 738789         52.0         247          2004.0
# 734358         40.0         193          2007.0
# 249432         39.0         195          2003.0
# 1038639        29.0         205          2006.0
#
# [20 rows x 40 columns]

# %% [markdown]
# ### Columna ESTU_TIENEETNIA

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.

df_etnia = df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts().reset_index()
df_etnia.columns = ['Etnia', 'Cantidad']
df_etnia
# Out:
#   Etnia  Cantidad
# 0    No   1010036
# 1    Si     72130
# 2     -       394

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.
df_etnia = df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts().reset_index()
df_etnia.columns = ['Etnia', 'Cantidad']

# configurar etiquetas
labels = df_etnia['Etnia']
sizes = df_etnia['Cantidad']
explode = (0, 0.1, 0)  # separar una porción del gráfico

# configurar la figura y el eje
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

# crear gráfico de dona
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 14}, wedgeprops={'width': 0.6})

# agregar etiqueta central
ax.text(0, 0, 'Etnia', horizontalalignment='center', verticalalignment='center', fontsize=10, fontweight='bold')

# mostrar resultados
plt.show()

# %%
# Los valores que estan etiquetados como "el signo menos", representan un 0.06% del total de registros, estos estan representados con el caracter "-".
# Se procederá a reemplazar en el DataFrame original ese caracter con la etiqueta de "Desconocido".

# reemplazar valores "-"
df_acumulado_saber_11['ESTU_TIENEETNIA'] = df_acumulado_saber_11['ESTU_TIENEETNIA'].replace('-', 'Desconocido')

# contar registros de la columna 'ESTU_GENERO'
df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts()
# Out:
# ESTU_TIENEETNIA
# No             1010036
# Si               72130
# Desconocido        394
# Name: count, dtype: int64

# %% [markdown]
# ### Columna ESTU_DEPTO_RESIDE

# %%
# generar conteo de registros por valor único en la columna ESTU_DEPTO_RESIDE que hace referencia al departamento de residencia

df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].value_counts()
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             164459
# ANTIOQUIA          146584
# VALLE               88016
# CUNDINAMARCA        71566
# ATLANTICO           62113
# BOLIVAR             49838
# SANTANDER           49742
# CORDOBA             39570
# NARIÑO              33438
# TOLIMA              32349
# BOYACA              32197
# MAGDALENA           32086
# NORTE SANTANDER     30653
# CAUCA               28088
# HUILA               26409
# CESAR               26087
# META                24381
# SUCRE               21152
# CALDAS              20881
# RISARALDA           20395
# LA GUAJIRA          16891
# QUINDIO             12342
# CASANARE            11564
# CHOCO                9215
# CAQUETA              8561
# PUTUMAYO             7785
# ARAUCA               6460
# BOGOTA               5403
# GUAVIARE             1834
# AMAZONAS             1463
# SAN ANDRES           1222
# VICHADA              1015
# VAUPES                675
# GUAINIA               570
# EXTRANJERO            154
# -                      16
# Name: count, dtype: int64

# %% [markdown]
# ### Columna ESTU_MCPIO_RESIDE

# %%
# Generar conteo de registros por valor único en la columna ESTU_MCPIO_RESIDE que hace referencia al municipio de residencia

df_acumulado_saber_11['ESTU_MCPIO_RESIDE'].value_counts()
# Out:
# ESTU_MCPIO_RESIDE
# BOGOTÁ D.C.            169862
# MEDELLÍN                56785
# CALI                    42195
# BARRANQUILLA            33076
# CARTAGENA DE INDIAS     26745
#                         ...
# TUNUNGUÁ                   15
# BUSBANZÁ                   13
# PACOA                      12
# JORDÁN                     12
# MORICHAL                    4
# Name: count, Length: 1034, dtype: int64

# %%
unique_values = df_acumulado_saber_11['ESTU_MCPIO_RESIDE'].unique().tolist()
unique_values
# Out:
# ['BOGOTÁ D.C.',
#  'CALI',
#  'YUMBO',
#  'SOLEDAD',
#  'CHÍA',
#  'ENVIGADO',
#  'PALMIRA',
#  'BARRANQUILLA',
#  'EL CERRITO',
#  'PEREIRA',
#  'POPAYÁN',
#  'GUACARÍ',
#  'MEDELLÍN',
#  'GUADALAJARA DE BUGA',
#  'CARTAGENA DE INDIAS',
#  'EL PAUJÍL',
#  'LOS PATIOS',
#  'MONTERÍA',
#  'LA PLATA',
#  'PASTO',
#  'SOACHA',
#  'BELÉN DE UMBRÍA',
#  'ILES',
#  'MUTATÁ',
#  'ANCUYÁ',
#  'DUITAMA',
#  'PACHO',
#  'CAJICÁ',
#  'GUADALUPE',
#  'ARAUCA',
#  'VICTORIA',
#  'JAMUNDÍ',
#  'ZIPAQUIRÁ',
#  'MANIZALES',
#  'SAN DIEGO',
#  'FLORIDABLANCA',
#  'RESTREPO',
#  '-',
#  'DAGUA',
#  'INÍRIDA',
#  'BUCARAMANGA',
#  'PAMPLONA',
#  'PUERTO TEJADA',
#  'IBAGUÉ',
#  'CARTAGO',
#  'CANDELARIA',
#  'CAICEDONIA',
#  'APARTADÓ',
#  'VALLEDUPAR',
#  'PIEDECUESTA',
#  'TENJO',
#  'SANTA MARTA',
#  'SAN SEBASTIÁN DE MARIQUITA',
#  'MOCOA',
#  'EL CARMEN DE VIBORAL',
#  'GIRÓN',
#  'FUSAGASUGÁ',
#  'FLORIDA',
#  'FUNZA',
#  'PITALITO',
#  'CAMPO DE LA CRUZ',
#  'ARMENIA',
#  'VIJES',
#  'MAGANGUÉ',
#  'MÁLAGA',
#  'LA MESA',
#  'BELLO',
#  'LA CEJA',
#  'NEIVA',
#  'SANDONÁ',
#  'VILLAVICENCIO',
#  'TAME',
#  'LA CUMBRE',
#  'MAICAO',
#  'AGUACHICA',
#  'SANTANDER DE QUILICHAO',
#  'POTOSÍ',
#  'VILLA RICA',
#  'COTA',
#  'PUPIALES',
#  'ROLDANILLO',
#  'MALAMBO',
#  'SAN ANDRÉS',
#  'VISTAHERMOSA',
#  'SABANETA',
#  'SANTA ROSA DE CABAL',
#  'VILLA DEL ROSARIO',
#  'FACATATIVÁ',
#  'TABIO',
#  'MOSQUERA',
#  'MONTELÍBANO',
#  'FLORENCIA',
#  'ACACÍAS',
#  'GIRARDOTA',
#  'EL ZULIA',
#  'MADRID',
#  'VILLAMARÍA',
#  'PAZ DE ARIPORO',
#  'SAN GIL',
#  'TUNJA',
#  'MONTENEGRO',
#  'ALBANIA',
#  'YOPAL',
#  'BUESACO',
#  'MACHETÁ',
#  'GIRARDOT',
#  'SAN JOSÉ DEL GUAVIARE',
#  'CÚCUTA',
#  'GUAPOTÁ',
#  'CIÉNAGA',
#  'PATÍA',
#  'LA UNIÓN',
#  'LA DORADA',
#  'LA ESTRELLA',
#  'ITAGÜÍ',
#  'CABRERA',
#  'BUENAVENTURA',
#  'DOSQUEBRADAS',
#  'PAILITAS',
#  'PUERTO WILCHES',
#  'TOTORÓ',
#  'IPIALES',
#  'CHIQUINQUIRÁ',
#  'TULUÁ',
#  'MANZANARES',
#  'LOURDES',
#  'CALDAS',
#  'VITERBO',
#  'PUERRES',
#  'SOGAMOSO',
#  'SOCOTÁ',
#  'ZAPATOCA',
#  'GUACHENÉ',
#  'CUBARRAL',
#  'MACEO',
#  'PUERTO ASÍS',
#  'BOAVITA',
#  'CHINCHINÁ',
#  'MUTISCUA',
#  'CHOCONTÁ',
#  'CIRCASIA',
#  'LEJANÍAS',
#  'PIENDAMÓ - TUNÍA',
#  'ZARZAL',
#  'SARAVENA',
#  'EL SANTUARIO',
#  'ORITO',
#  'SANTA BÁRBARA',
#  'BOJACÁ',
#  'EBÉJICO',
#  'BETULIA',
#  'TAURAMENA',
#  'QUIBDÓ',
#  'PUERTO COLOMBIA',
#  'GRANADA',
#  'EL ROSAL',
#  'TIERRALTA',
#  'PALOCABILDO',
#  'RIOSUCIO',
#  'COCORNÁ',
#  'PRADERA',
#  'COGUA',
#  'CERRO DE SAN ANTONIO',
#  'LA FLORIDA',
#  'PUERTO LÓPEZ',
#  'PLANADAS',
#  'MARÍA LA BAJA',
#  'SOPÓ',
#  'CUMBAL',
#  'PALMAS DEL SOCORRO',
#  'EL COLEGIO',
#  'FREDONIA',
#  'LA CALERA',
#  'OCAÑA',
#  'SAMANÁ',
#  'IMUÉS',
#  'SAN PELAYO',
#  'DONMATÍAS',
#  'GUAMO',
#  'GUADUAS',
#  'SAN LUIS',
#  'SOCORRO',
#  'CALIMA',
#  'BARBOSA',
#  'RETIRO',
#  'SIBATÉ',
#  'ANDALUCÍA',
#  'YOTOCO',
#  'AGUAZUL',
#  'ARMERO',
#  'GINEBRA',
#  'BUGALAGRANDE',
#  'TOCANCIPÁ',
#  'SAN BERNARDO',
#  'CABUYARO',
#  'CHALÁN',
#  'EXTRANJERO',
#  'LA VICTORIA',
#  'GUARNE',
#  'MARINILLA',
#  'NARIÑO',
#  'SAN VICENTE FERRER',
#  'SUESCA',
#  'JUAN DE ACOSTA',
#  'FONSECA',
#  'PONEDERA',
#  'ANAPOIMA',
#  'SUAZA',
#  'RIONEGRO',
#  'SABANAS DE SAN ÁNGEL',
#  'ALTAMIRA',
#  'ITUANGO',
#  'HATONUEVO',
#  'SINCELEJO',
#  'ACEVEDO',
#  'VILLANUEVA',
#  'VILLA DE SAN DIEGO DE UBATÉ',
#  'SUSACÓN',
#  'ALMAGUER',
#  'BOYACÁ',
#  'SAN FRANCISCO',
#  'BOLÍVAR',
#  'COPACABANA',
#  'ALDANA',
#  'BALBOA',
#  'SANTA ROSA DE OSOS',
#  'TANGUA',
#  'COYAIMA',
#  'REMEDIOS',
#  'PORE',
#  'GUACHETÁ',
#  'MURINDÓ',
#  'ARBELÁEZ',
#  'SAN PEDRO DE LOS MILAGROS',
#  'CAJIBÍO',
#  'VERSALLES',
#  'GUACHUCAL',
#  'SAN PEDRO',
#  'TOLEDO',
#  'SUBACHOQUE',
#  'RICAURTE',
#  'CONCORDIA',
#  'LEBRIJA',
#  'TRINIDAD',
#  'RIVERA',
#  'FILANDIA',
#  'MESETAS',
#  'PUEBLO RICO',
#  'ANSERMA',
#  'FALAN',
#  'YARUMAL',
#  'GARZÓN',
#  'SANTO DOMINGO',
#  'COLOMBIA',
#  'LA VIRGINIA',
#  'OLAYA HERRERA',
#  'EL CASTILLO',
#  'CALARCÁ',
#  'SANTA ANA',
#  'MONTECRISTO',
#  'EL PASO',
#  'GALAPA',
#  'BARANOA',
#  'CORINTO',
#  'VALENCIA',
#  'LORICA',
#  'SABANALARGA',
#  'ARJONA',
#  'PUERTO GAITÁN',
#  'SAN ONOFRE',
#  'EL CARMEN DE BOLÍVAR',
#  'TOLÚ VIEJO',
#  'RIOFRÍO',
#  'SAMPUÉS',
#  'LA APARTADA',
#  'CIÉNAGA DE ORO',
#  'BARRANCAS',
#  'SAHAGÚN',
#  'NOCAIMA',
#  'BARRANCABERMEJA',
#  'TURBACO',
#  'CERETÉ',
#  'GUAPÍ',
#  'SAN MARCOS',
#  'MIRANDA',
#  'EL RETÉN',
#  'AGUSTÍN CODAZZI',
#  'HATILLO DE LOBA',
#  'ARIGUANÍ',
#  'SAN SEBASTIÁN DE BUENAVISTA',
#  'PUEBLO NUEVO',
#  'RIOHACHA',
#  'SAN ANTERO',
#  'AYAPEL',
#  'ACHÍ',
#  'PELAYA',
#  'SAN JUAN DE URABÁ',
#  'CURUMANÍ',
#  'SUAITA',
#  'URIBIA',
#  'BOSCONIA',
#  'PLANETA RICA',
#  'CALDONO',
#  'FUNDACIÓN',
#  'PUERTO LIBERTADOR',
#  'PINILLOS',
#  'MORALES',
#  'UNGUÍA',
#  'COTORRA',
#  'LOS PALMITOS',
#  'ALTO BAUDÓ',
#  'ORTEGA',
#  'GALERAS',
#  'MAHATES',
#  'SOPETRÁN',
#  'SANTA MARÍA',
#  'GUARANDA',
#  'NUEVA GRANADA',
#  'SANTO TOMÁS',
#  'MITÚ',
#  'CHIGORODÓ',
#  'SANTA ROSA',
#  'CAMPOALEGRE',
#  'ALTOS DEL ROSARIO',
#  'SALAMINA',
#  'TIBÚ',
#  'MAJAGUAL',
#  'EL BAGRE',
#  'TORIBÍO',
#  'SAN JUAN NEPOMUCENO',
#  'SANTA ROSALÍA',
#  'PUERTO RICO',
#  'PROVIDENCIA',
#  'TELLO',
#  'SABANAGRANDE',
#  'MARGARITA',
#  'LA ESPERANZA',
#  'ROVIRA',
#  'SAN ANDRÉS DE TUMACO',
#  'PLATO',
#  'FUNES',
#  'SUCRE',
#  'GIGANTE',
#  'PUERTO SANTANDER',
#  'PUENTE NACIONAL',
#  'CUMARIBO',
#  'SAN CRISTÓBAL',
#  'MANAURE BALCÓN DEL CESAR',
#  'PEQUE',
#  'DISTRACCIÓN',
#  'EL PIÑÓN',
#  'LA VEGA',
#  'MOMPÓS',
#  'BARRANCO DE LOBA',
#  'ALGARROBO',
#  'GÁMBITA',
#  'EL ROBLE',
#  'VALLE DE SAN JOSÉ',
#  'TENERIFE',
#  'MOMIL',
#  'SILVIA',
#  'ALBÁN',
#  'YOLOMBÓ',
#  'CÓRDOBA',
#  'LA MONTAÑITA',
#  'SAN VICENTE DEL CAGUÁN',
#  'LIBORINA',
#  'CURILLO',
#  'TURBO',
#  'ENTRERRÍOS',
#  'SAN MARTÍN DE LOBA',
#  'BUENAVISTA',
#  'ANSERMANUEVO',
#  'FUENTEDEORO',
#  'SAN PABLO DE BORBUR',
#  'SAN ANDRÉS DE SOTAVENTO',
#  'ARACATACA',
#  'DIBULLA',
#  'ZONA BANANERA',
#  'TORO',
#  'PIOJÓ',
#  'EL BANCO',
#  nan,
#  'EL PEÑÓN',
#  'SAN JERÓNIMO',
#  'CERRITO',
#  'CAUCASIA',
#  'FRONTINO',
#  'SUPÍA',
#  'QUIMBAYA',
#  'ASTREA',
#  'TALAIGUA NUEVO',
#  'MANATÍ',
#  'JURADÓ',
#  'TUBARÁ',
#  'OVEJAS',
#  'LURUACO',
#  'MANAURE',
#  'SAN JUAN DEL CESAR',
#  'PURIFICACIÓN',
#  'POLICARPA',
#  'CHINÚ',
#  'LA GLORIA',
#  'BECERRIL',
#  'GUALMATÁN',
#  'PUEBLOVIEJO',
#  'CHIMICHAGUA',
#  'LETICIA',
#  'CALAMAR',
#  'TURBANÁ',
#  'SOLITA',
#  'CUASPÚD',
#  'FORTUL',
#  'EL DONCELLO',
#  'LA TOLA',
#  'BAJO BAUDÓ',
#  'CICUCO',
#  'CARTAGENA DEL CHAIRÁ',
#  'PUERTO ESCONDIDO',
#  'COVEÑAS',
#  'SAN PEDRO DE URABÁ',
#  'TOGÜÍ',
#  'ARBOLETES',
#  'BOJAYÁ',
#  'SAN BERNARDO DEL VIENTO',
#  'SAN MARTÍN',
#  'PIAMONTE',
#  'TÁMARA',
#  'HATO COROZAL',
#  'MAGÜÍ',
#  'PUERTO LEGUÍZAMO',
#  'SAN SEBASTIÁN',
#  'PINCHOTE',
#  'CHIRIGUANÁ',
#  'GUAMAL',
#  'VIGÍA DEL FUERTE',
#  'NATAGAIMA',
#  'PUERTO NARIÑO',
#  'LA PRIMAVERA',
#  'CUCUTILLA',
#  'PIVIJAY',
#  'SANTA FÉ DE ANTIOQUIA',
#  'CHAPARRAL',
#  'ZARAGOZA',
#  'ESPINAL',
#  'BARRANCO MINAS',
#  'ATRATO',
#  'LA JAGUA DE IBIRICO',
#  'NECOCLÍ',
#  'LOS CÓRDOBAS',
#  'CONVENCIÓN',
#  'SILVANIA',
#  'TUTA',
#  'SANTA ROSA DE VITERBO',
#  'GUAITARILLA',
#  'MALLAMA',
#  'JARDÍN',
#  'ABRIAQUÍ',
#  'QUINCHÍA',
#  'UBALÁ',
#  'ZAPAYÁN',
#  'CALOTO',
#  'SAN BENITO ABAD',
#  'TAMALAMEQUE',
#  'MOÑITOS',
#  'ISNOS',
#  'ALGECIRAS',
#  'PALMITO',
#  'CUNDAY',
#  'PUERTO BERRÍO',
#  'GRAMALOTE',
#  'TEORAMA',
#  'NOROSÍ',
#  'BARBACOAS',
#  'AQUITANIA',
#  'PURÍSIMA DE LA CONCEPCIÓN',
#  'SIBUNDOY',
#  'TAMINANGO',
#  'INZÁ',
#  'GACHANCIPÁ',
#  'TARAZÁ',
#  'SATIVANORTE',
#  'BERBEO',
#  'LA PAZ',
#  'CHINÁCOTA',
#  'LA PLAYA',
#  'CUCUNUBÁ',
#  'GALÁN',
#  'TARQUI',
#  'PAYA',
#  'EL PEÑOL',
#  'TUCHÍN',
#  'VÉLEZ',
#  'SAN ESTANISLAO',
#  'SANTANA',
#  'YACUANQUER',
#  'AGUADAS',
#  'SAN PABLO',
#  'PAICOL',
#  'PÁEZ',
#  'LA CRUZ',
#  'LÉRIDA',
#  'TIMBÍO',
#  'ROSAS',
#  'JAMBALÓ',
#  'MONGUÍ',
#  'ABEJORRAL',
#  'MOTAVITA',
#  'SANTA HELENA DEL OPÓN',
#  'CHITA',
#  'LOS ANDES',
#  'SANTIAGO DE TOLÚ',
#  'PITAL',
#  'PUERTO GUZMÁN',
#  'CÁQUEZA',
#  'SAN VICENTE DE CHUCURÍ',
#  'LA UVITA',
#  'CÁCERES',
#  'SAN LORENZO',
#  'MORROA',
#  'VALLE DEL GUAMUEZ',
#  'SABOYÁ',
#  'PEÑOL',
#  'SANTA LUCÍA',
#  'SITIONUEVO',
#  'SAN JUAN DE BETULIA',
#  'SUAN',
#  'REPELÓN',
#  'ÁBREGO',
#  'ULLOA',
#  'PURACÉ',
#  'TÚQUERRES',
#  'CHOACHÍ',
#  'RONCESVALLES',
#  'ISTMINA',
#  'MOLAGAVITA',
#  'BELMIRA',
#  'EL DOVIO',
#  'GARAGOA',
#  'SOTARA',
#  'CISNEROS',
#  'CONDOTO',
#  'QUÍPAMA',
#  'CAIMITO',
#  'EL CARMEN',
#  'VIOTÁ',
#  'CARACOLÍ',
#  'ICONONZO',
#  'EL TAMBO',
#  'OLAYA',
#  'SABANA DE TORRES',
#  'SAN ALBERTO',
#  'EL TARRA',
#  'MARQUETALIA',
#  'YACOPÍ',
#  'BUENOS AIRES',
#  'UNE',
#  'PARATEBUENO',
#  'HONDA',
#  'SAN JOSÉ DE PARE',
#  'TRUJILLO',
#  'ÚMBITA',
#  'NUEVO COLÓN',
#  'SIACHOQUE',
#  'CASTILLA LA NUEVA',
#  'VEGACHÍ',
#  'ARAUQUITA',
#  'GONZÁLEZ',
#  'SAN AGUSTÍN',
#  'NOBSA',
#  'ROBERTO PAYÁN',
#  'SAN JACINTO',
#  'PAIPA',
#  'POLONUEVO',
#  'VENTAQUEMADA',
#  'SARDINATA',
#  'CHARALÁ',
#  'LÍBANO',
#  'TOCA',
#  'ÍQUIRA',
#  'VILLAVIEJA',
#  'SAN ANDRÉS DE CUERQUÍA',
#  'CRAVO NORTE',
#  'CANALETE',
#  'YONDÓ',
#  'COROZAL',
#  'GACHALÁ',
#  'LOS SANTOS',
#  'SAN CARLOS DE GUAROA',
#  'MOGOTES',
#  'OSPINA',
#  'MELGAR',
#  'SAN PEDRO DE CARTAGO',
#  'CHITAGÁ',
#  'TIMBIQUÍ',
#  'SAMACÁ',
#  'RAMIRIQUÍ',
#  'PUERTO BOYACÁ',
#  'PUEBLO BELLO',
#  'VILLA CARO',
#  'ATACO',
#  'SALAZAR',
#  'CUMBITARA',
#  'SAN CARLOS',
#  'SESQUILÉ',
#  'UBAQUE',
#  'SORACÁ',
#  'VILLARRICA',
#  'SANTA ROSA DEL SUR',
#  'OTANCHE',
#  'CIMITARRA',
#  'COROMORO',
#  'PANQUEBA',
#  'TOPAIPÍ',
#  'PUEBLORRICO',
#  'SIMIJACA',
#  'TIQUISIO',
#  'MURILLO',
#  'FÚQUENE',
#  'COLÓN',
#  'USIACURÍ',
#  'FLANDES',
#  'CHISCAS',
#  'GAMARRA',
#  'ANDES',
#  'ANORÍ',
#  'CURITÍ',
#  'MILÁN',
#  'PÁRAMO',
#  'TIBIRITA',
#  'PUERTO TRIUNFO',
#  'NECHÍ',
#  'EL TABLÓN DE GÓMEZ',
#  'TENZA',
#  'SAN ZENÓN',
#  'PAUNA',
#  'EL COPEY',
#  'OCAMONTE',
#  'SALADOBLANCO',
#  'CÁCHIRA',
#  'PAJARITO',
#  'SAN ANTONIO',
#  'EL PLAYÓN',
#  'SAN MIGUEL',
#  'PIEDRAS',
#  'SILOS',
#  'RÍO IRÓ',
#  'SAN CALIXTO',
#  'COLOSÓ',
#  'SUPATÁ',
#  'GACHANTIVÁ',
#  'FIRAVITOBA',
#  'LA ARGENTINA',
#  'SEGOVIA',
#  'NORCASIA',
#  'LENGUAZAQUE',
#  'EL COCUY',
#  'LANDÁZURI',
#  'BARICHARA',
#  'HOBO',
#  'PUERTO CONCORDIA',
#  'ARATOCA',
#  'QUEBRADANEGRA',
#  'MANÍ',
#  'SAN CAYETANO',
#  'MONTEBELLO',
#  'SAN ROQUE',
#  'SAN JOAQUÍN',
#  'CHIVOLO',
#  'SÁCHICA',
#  'VILLETA',
#  'SANTA BÁRBARA DE PINTO',
#  'MONIQUIRÁ',
#  'TIBANÁ',
#  'PUERTO CAICEDO',
#  'QUIPILE',
#  'PEDRAZA',
#  'PALERMO',
#  'MISTRATÓ',
#  'VILLA DE LEYVA',
#  'MIRAFLORES',
#  'PASCA',
#  'LA BELLEZA',
#  'REMOLINO',
#  'RAGONVALIA',
#  'SONSÓN',
#  'NEMOCÓN',
#  'RECETOR',
#  'AGUA DE DIOS',
#  'TIMANÁ',
#  'ARBOLEDA',
#  'SUSA',
#  'LA SIERRA',
#  'ARROYOHONDO',
#  'COVARACHÍA',
#  'EL CAIRO',
#  'JENESANO',
#  'PUERTO CARREÑO',
#  'GUAYATÁ',
#  'RÁQUIRA',
#  'EL ESPINO',
#  'TASCO',
#  'CAJAMARCA',
#  'CHIPAQUE',
#  'VILLAPINZÓN',
#  'TIPACOQUE',
#  'TURMEQUÉ',
#  'CAÑASGORDAS',
#  'BELALCÁZAR',
#  'GUÁTICA',
#  'LA PEDRERA',
#  'FOSCA',
#  'CHIPATÁ',
#  'CARCASÍ',
#  'SAN JOSÉ DEL FRAGUA',
#  'NUNCHÍA',
#  'HELICONIA',
#  'EL CARMEN DE ATRATO',
#  'ANZÁ',
#  'PAZ DE RÍO',
#  'TOCAIMA',
#  'BETANIA',
#  'MORELIA',
#  'FRESNO',
#  'VILLAGARZÓN',
#  'CLEMENCIA',
#  'JERICÓ',
#  'TADÓ',
#  'OBANDO',
#  'SAN LUIS DE SINCÉ',
#  'LLORÓ',
#  'VALPARAÍSO',
#  'RÍO VIEJO',
#  'ELÍAS',
#  'ARGELIA',
#  'SAN ANTONIO DEL TEQUENDAMA',
#  'GAMA',
#  'RÍO DE ORO',
#  'VILLAGÓMEZ',
#  'LA TEBAIDA',
#  'GUAYABETAL',
#  'MACANAL',
#  'URRAO',
#  'AIPE',
#  'AGRADO',
#  'BAGADÓ',
#  'PALMAR DE VARELA',
#  'BAHÍA SOLANO',
#  'SAN RAFAEL',
#  'ALCALÁ',
#  'VIRACACHÁ',
#  'LA JAGUA DEL PILAR',
#  'EL ROSARIO',
#  'CARMEN DE CARUPA',
#  'CAPITANEJO',
#  'CIÉNEGA',
#  'SIMACOTA',
#  'GÉNOVA',
#  'CHINAVITA',
#  'PRADO',
#  'TENA',
#  'RISARALDA',
#  'MEDIO BAUDÓ',
#  'TARAPACÁ',
#  'OROCUÉ',
#  'SALDAÑA',
#  'FÓMEQUE',
#  'AMALFI',
#  'SANTIAGO',
#  'SAMANIEGO',
#  'PIJAO',
#  'GUACA',
#  'GUAYABAL DE SÍQUIMA',
#  'LABATECA',
#  'APÍA',
#  'SANTA CATALINA',
#  'CAROLINA',
#  'DABEIBA',
#  'SAN JACINTO DEL CAUCA',
#  'SAN JOSÉ DE URÉ',
#  'SAN JOSÉ DE MIRANDA',
#  'EL LITORAL DEL SAN JUAN',
#  'BOCHALEMA',
#  'ENCISO',
#  'SAN JUAN DE RIOSECO',
#  'URUMITA',
#  'ANGOSTURA',
#  'FRANCISCO PIZARRO',
#  'RÍO QUITO',
#  'MUZO',
#  'MATANZA',
#  'EL RETORNO',
#  'DOLORES',
#  'EL MOLINO',
#  'ANZOÁTEGUI',
#  'SOPLAVIENTO',
#  'CUBARÁ',
#  'VENECIA',
#  'CHACHAGÜÍ',
#  'LA LLANADA',
#  'VERGARA',
#  'SEVILLA',
#  'GUASCA',
#  'SIMITÍ',
#  'PALESTINA',
#  'CUMARAL',
#  'EL ÁGUILA',
#  'CASABIANCA',
#  'LINARES',
#  'CAREPA',
#  'NEIRA',
#  'MONTERREY',
#  'RIOBLANCO',
#  'PÁCORA',
#  'CAICEDO',
#  'ALVARADO',
#  'CIUDAD BOLÍVAR',
#  'CÓMBITA',
#  'ANOLAIMA',
#  'MEDINA',
#  'MARMATO',
#  'GÜEPSA',
#  'SASAIMA',
#  'GÓMEZ PLATA',
#  'ALEJANDRÍA',
#  'SUÁREZ',
#  'TARSO',
#  'AMAGÁ',
#  'PADILLA',
#  'YALÍ',
#  'APULO',
#  'CAMPAMENTO',
#  'YAGUARÁ',
#  'PENSILVANIA',
#  'FILADELFIA',
#  'MARULANDA',
#  'EL CARMEN DE CHUCURÍ',
#  'COELLO',
#  'ARANZAZU',
#  'COPER',
#  'LA MACARENA',
#  'PUERTO NARE',
#  'SALGAR',
#  'SOATÁ',
#  'PISBA',
#  'CHIMÁ',
#  'OIBA',
#  'MARSELLA',
#  'GIRALDO',
#  'LA MERCED',
#  'TERUEL',
#  'ALMEIDA',
#  'SAN FERNANDO',
#  'TÁMESIS',
#  'SANTUARIO',
#  'BITUIMA',
#  'URAMITA',
#  'HISPANIA',
#  'ARENAL',
#  'PUERTO PARRA',
#  'LEIVA',
#  'SAN MIGUEL DE SEMA',
#  'CÉRTEGUI',
#  'GUATEQUE',
#  'PIJIÑO DEL CARMEN',
#  'LA CHORRERA',
#  'CONSACÁ',
#  'PUERTO LLERAS',
#  'ZAMBRANO',
#  'LA PEÑA',
#  'SALENTO',
#  'VALDIVIA',
#  'GUATAPÉ',
#  'CONCEPCIÓN',
#  'CAPARRAPÍ',
#  'BRICEÑO',
#  'TONA',
#  'OPORAPA',
#  'TÓPAGA',
#  'MAPIRIPÁN',
#  'LA CELIA',
#  'MONGUA',
#  'NUQUÍ',
#  'ARBOLEDAS',
#  'SOTAQUIRÁ',
#  'BELÉN DE LOS ANDAQUÍES',
#  'SAN LUIS DE PALENQUE',
#  'NÓVITA',
#  'SAN FELIPE',
#  'GACHETÁ',
#  'PUERTO SALGAR',
#  'MEDIO SAN JUAN',
#  'GÁMEZA',
#  'VALLE DE SAN JUAN',
#  'NILO',
#  'TIBASOSA',
#  'CACHIPAY',
#  'QUETAME',
#  'EL CANTÓN DEL SAN PABLO',
#  'SAN MATEO',
#  'LA SALINA',
#  'ÚTICA',
#  'CONTRATACIÓN',
#  'CUCAITA',
#  'PALMAR',
#  'CHÍQUIZA',
#  'BURITICÁ',
#  'EL GUAMO',
#  'NÁTAGA',
#  'PESCA',
#  'TITIRIBÍ',
#  'VENADILLO',
#  'SAPUYES',
#  'LA PALMA',
#  'NIMAIMA',
#  'SAN JOSÉ',
#  'TINJACÁ',
#  'SANTACRUZ',
#  'SAN JOSÉ DE LA MONTAÑA',
#  'SAN BENITO',
#  'CARURÚ',
#  'EL CHARCO',
#  'GUATAVITA',
#  'ARCABUCO',
#  'ZETAQUIRA',
#  'GUATAQUÍ',
#  'MERCADERES',
#  'SAN JUAN DE ARAMA',
#  'SUTATAUSA',
#  'SOLANO',
#  'LA PINTADA',
#  'TESALIA',
#  'BELÉN',
#  'ZIPACÓN',
#  'HERVEO',
#  'CHITARAQUE',
#  'CARMEN DE APICALÁ',
#  'AGUADA',
#  'TAUSA',
#  'UNIÓN PANAMERICANA',
#  'SAN LUIS DE GACENO',
#  'SOCHA',
#  'TARAIRA',
#  'GUACAMAYAS',
#  'CHIVATÁ',
#  'SURATÁ',
#  'EL DORADO',
#  'ANGELÓPOLIS',
#  'AMBALEMA',
#  'CARMEN DEL DARIÉN',
#  'VIANÍ',
#  'SORA',
#  'TUTAZÁ',
#  'DURANIA',
#  'CONTADERO',
#  'EL CALVARIO',
#  'PUERTO RONDÓN',
#  'BARRANCA DE UPÍA',
#  'MANTA',
#  'LÓPEZ DE MICAY',
#  'FLORIÁN',
#  'MIRITÍ - PARANÁ',
#  'CERINZA',
#  'CONFINES',
#  'JERUSALÉN',
#  'GUTIÉRREZ',
#  'GÜICÁN DE LA SIERRA',
#  'PAMPLONITA',
#  'CHAGUANÍ',
#  'MARIPÍ',
#  'HACARÍ',
#  'PULÍ',
#  'SAN JUANITO',
#  'SAN JOSÉ DEL PALMAR',
#  'SANTA SOFÍA',
#  'SUTAMARCHÁN',
#  'JORDÁN',
#  'JUNÍN',
#  'CARAMANTA',
#  'CHIMA',
#  'OICATÁ',
#  'VILLAHERMOSA',
#  'LA CAPILLA',
#  'TIBACUY',
#  'MACARAVITA',
#  'GUAVATÁ',
#  'PANDI',
#  'CHIVOR',
#  'TUNUNGUÁ',
#  'ACANDÍ',
#  'BARAYA',
#  'CÁCOTA',
#  'SAN EDUARDO',
#  'EL GUACAMAYO',
#  'FLORESTA',
#  'CHÁMEZA',
#  'CEPITÁ',
#  'SUTATENZA',
#  'BUSBANZÁ',
#  'PAIME',
#  ...]

# %% [markdown]
# ### Columna FAMI_ESTRATOVIVIENDA

# %%
# generar conteo de registros por valor único en la columna FAMI_ESTRATOVIVIENDAA que hace referencia al estrato de la vivienda de los estudiantes.

df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 2      376285
# Estrato 1      315139
# Estrato 3      220252
# Estrato 4       55282
# Sin Estrato     34575
# -               34481
# Estrato 5       20264
# Estrato 6       11503
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-': 'No sabe',
                    'Estrato 1': '1',
                    'Estrato 2': '2',
                    'Estrato 3': '3',
                    'Estrato 4': '4',
                    'Estrato 5': '5',
                    'Estrato 6': '6',
                    'Sin Estrato': 'No sabe'
                }

# Implementar la función .replace
df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# FAMI_ESTRATOVIVIENDA
# 2          376285
# 1          315139
# 3          220252
# No sabe     69056
# 4           55282
# 5           20264
# 6           11503
# Name: count, dtype: int64

# %% [markdown]
# ### FAMI_PERSONASHOGAR

# %%
df_acumulado_saber_11['FAMI_PERSONASHOGAR'].value_counts()
# Out:
# FAMI_PERSONASHOGAR
# 3 a 4            517704
# 5 a 6            333383
# 7 a 8             87376
# 1 a 2             80038
# 9 o más           34530
# -                  7530
# Sin Respuesta       713
# Name: count, dtype: int64

# %% [markdown]
# `Reto: ¿Qué opciones/acciones propones para los fami_personashogar?`

# %% [markdown]
# ### FAMI_CUARTOSHOGAR

# %%
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# FAMI_CUARTOSHOGAR
# Tres             411499
# Dos              368634
# Cuatro           143888
# Uno               54741
# Cinco             46665
# Seis o mas        25843
# -                 10740
# Sin respuesta       611
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    'Uno'               : '1',
                    'Dos'               : '2',
                    'Tres'              : '3',
                    'Cuatro'            : '4',
                    'Cinco'             : '5',
                    'Seis o mas'        : '6',
                    '-'                 : 'No responde',
                    'Sin respuesta'     : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# FAMI_CUARTOSHOGAR
# 3              411499
# 2              368634
# 4              143888
# 1               54741
# 5               46665
# 6               25843
# No responde     11351
# Name: count, dtype: int64

# %% [markdown]
# ### FAMI_NUMLIBROS

# %%
df_acumulado_saber_11['FAMI_NUMLIBROS'].value_counts()
# Out:
# FAMI_NUMLIBROS
# 0 A 10 LIBROS        420890
# 11 A 25 LIBROS       313333
# 26 A 100 LIBROS      216923
# MÁS DE 100 LIBROS     73580
# -                     37331
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0 A 10 LIBROS'     : '0-10',
                    '11 A 25 LIBROS'    : '11-25',
                    '26 A 100 LIBROS'   : '26-100',
                    'MÁS DE 100 LIBROS' : '>100',
                    '-'                 : 'No sabe'
                }

# Implementar la función .replace
df_acumulado_saber_11['FAMI_NUMLIBROS'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_NUMLIBROS'].value_counts()
# Out:
# FAMI_NUMLIBROS
# 0-10       420890
# 11-25      313333
# 26-100     216923
# >100        73580
# No sabe     37331
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_DEDICACIONLECTURADIARIA

# %%
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# ESTU_DEDICACIONLECTURADIARIA
# 30 minutos o menos            399420
# Entre 30 y 60 minutos         285771
# No leo por entretenimiento    198528
# Entre 1 y 2 horas             110274
# Más de 2 horas                 43204
# -                              32480
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 2 horas'             : '1h-2h',
                    'Más de 2 horas'                : '>2h',
                    'No leo por entretenimiento'    : 'No lee',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# ESTU_DEDICACIONLECTURADIARIA
# <30            399420
# 30-60          285771
# No lee         198528
# 1h-2h          110274
# >2h             43204
# No responde     32480
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_DEDICACIONINTERNET

# %%
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# ESTU_DEDICACIONINTERNET
# Entre 1 y 3 horas        319673
# Entre 30 y 60 minutos    249883
# Más de 3 horas           245794
# 30 minutos o menos       159993
# No Navega Internet        60447
# -                          4050
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 3 horas'             : '1h-3h',
                    'Más de 3 horas'                : '>3h',
                    'No Navega Internet'            : 'No navega',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# ESTU_DEDICACIONINTERNET
# 1h-3h          319673
# 30-60          249883
# >3h            245794
# <30            159993
# No navega       60447
# No responde      4050
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_HORASSEMANATRABAJA

# %%
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# ESTU_HORASSEMANATRABAJA
# 0                      672318
# Menos de 10 horas      197106
# Entre 11 y 20 horas     94807
# Más de 30 horas         48205
# Entre 21 y 30 horas     38005
# -                       17091
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0'                     : '0',
                    'Menos de 10 horas'     : '<10',
                    'Entre 11 y 20 horas'   : '11-20',
                    'Entre 21 y 30 horas'   : '21-30',
                    'Más de 30 horas'       : '>30',
                    '-'                     : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# ESTU_HORASSEMANATRABAJA
# 0              672318
# <10            197106
# 11-20           94807
# >30             48205
# 21-30           38005
# No responde     17091
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_TIPOREMUNERACION

# %%
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# ESTU_TIPOREMUNERACION
# No                           726749
# Si, en efectivo              284066
# Si, en especie                20379
# Si, en efectivo y especie     17261
# -                              3250
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'Prefiero no responder'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# ESTU_TIPOREMUNERACION
# No                           726749
# Si, en efectivo              284066
# Si, en especie                20379
# Si, en efectivo y especie     17261
# Prefiero no responder          3250
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_BILINGUE

# %%
df_acumulado_saber_11['COLE_BILINGUE'].value_counts()
# Out:
# COLE_BILINGUE
# N    892455
# -     90863
# S     17377
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['COLE_BILINGUE'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['COLE_BILINGUE'].value_counts()
# Out:
# COLE_BILINGUE
# N              892455
# No responde     90863
# S               17377
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_CARACTER

# %%
df_acumulado_saber_11['COLE_CARACTER'].value_counts()
# Out:
# COLE_CARACTER
# ACADÉMICO            570630
# TÉCNICO/ACADÉMICO    352959
# TÉCNICO              117579
# NO APLICA             14100
# -                      2196
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'NO RESPONDE'
                }

# Implementar la función .replace
df_acumulado_saber_11['COLE_CARACTER'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['COLE_CARACTER'].value_counts()
# Out:
# COLE_CARACTER
# ACADÉMICO            570630
# TÉCNICO/ACADÉMICO    352959
# TÉCNICO              117579
# NO APLICA             14100
# NO RESPONDE            2196
# Name: count, dtype: int64

# %% [markdown]
# `Reto: ¿Qué opciones/acciones propones para los COLE_CARACTER referente a los campos TÉCNICO Y TÉCNICO/ACADÉMICO?`

# %% [markdown]
# ### COLE_NATURALEZA

# %%
df_acumulado_saber_11['COLE_NATURALEZA'].value_counts()
# Out:
# COLE_NATURALEZA
# OFICIAL       808491
# NO OFICIAL    277826
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_JORNADA

# %%
df_acumulado_saber_11['COLE_JORNADA'].value_counts()
# Out:
# COLE_JORNADA
# MAÑANA      468577
# UNICA       199778
# COMPLETA    183558
# TARDE       108871
# SABATINA     67852
# NOCHE        57681
# Name: count, dtype: int64

# %%
# Exportar el dataframe acumulado_saber_11 en formato CSV

df_acumulado_saber_11.to_csv('acumulado_saber_11.csv', index=False)

print(f"El archivo ha sido exportado exitosamente.")
# Out:
# El archivo ha sido exportado exitosamente.

# %% [markdown]
# # Conclusiones

# %% [markdown]
# El análisis técnico de limpieza de datos es una tarea esencial en cualquier proyecto de análisis de datos, ya que permite obtener datos de alta calidad y precisión. A partir de la limpieza de datos realizada, se pueden obtener diversas conclusiones, entre ellas:
#
# - No se identificaron muchos valores atípicos, en algunas columnas, solo habían registros que no indicaban una respuesta concreta (Si o No) al titulo de la columna.
#
# - Se mejoro la calidad del DataFrame, la limpieza permitio eliminar inconsistencias y actualizar algunas. Con datos de alta calidad, se pueden obtener resultados más precisos y confiables.
#
# - Con dicha limpieza, se asegura integridad de los datos, este análisis técnico de limpieza de datos ya permitio ayudar a garantizar la integridad de los datos, asegurando que estos se mantengan precisos y confiables para posteriores actividades como pueden ser construcciones de analisis exploratorios de datos, pruebas de hipótesis, construcción de tableros de analitica, modelos predictivos, entre otros.
#
# - También se mininizo el riesgo de errores para fututos análisis, al limpiar los datos antes de analizarlos, se puede reducir el riesgo de errores en el análisis, lo que puede llevar a conclusiones incorrectas.
#
# El Dataframe "acumulado_saber_11" se encuentra en condiciones para seguir con diferentes actividades y técnicas que la Ciencia de Datos permite.

# %% [markdown]
# # Actividad a realizar en sesión

# %% [markdown]
# 1.	Revisar y ajustar las siguientes columnas:
#
# -	ESTU_FECHANACIMIENTO:
# -	FAMI_EDUCACIONPADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	 FAMI_EDUCACIONMADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	FAMI_TRABAJOLABORPADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	FAMI_TRABAJOLABORMADRE: Generar una “categoría” para agrupar los registros de la columna.
